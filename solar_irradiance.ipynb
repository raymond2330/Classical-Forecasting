# %% [markdown]
# ## Solar Irradiance

# %% [markdown]
# ### 1DCNN

# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load solar irradiance dataset
    df = pd.read_csv('NASA-DATASET/solar_forecasting.csv', parse_dates=['DATETIME'], index_col='DATETIME').fillna(0)
    df.index = pd.to_datetime(df.index, format='mixed', errors='raise')
    
    # Rename target variable for consistency with original code structure
    target_col = 'ALLSKY_SFC_SW_DWN'  # Solar irradiance target
    df['TARGET'] = df[target_col]
    
    # Handle missing values
    df['TARGET'] = df['TARGET'].interpolate(method='time')
    df['TARGET'] = df['TARGET'].bfill().ffill()

    # Cadence sanity check
    _ = infer_5min_freq(df.index)

    # Window sizes for solar forecasting
    W = 7 * 24 * 12   # one week lookback (7 days) - 5 minute resolution  
    H = 1 * 24 * 12   # 24h horizon - 5 minute resolution

    # ----------------------------
    # Feature engineering (LEAK-FREE) - adapted for solar data
    # ----------------------------
    steps_per_hour = 12
    steps_1h  = 1  * steps_per_hour       # 12
    steps_6h  = 6  * steps_per_hour       # 72
    steps_24h = 24 * steps_per_hour       # 288

    # Seasonal lags for solar patterns (daily and yearly cycles)
    season_lags = [52560]
    for L in season_lags:
        if L < len(df):
            df[f'TARGET_lag{L}'] = df['TARGET'].shift(L)

    # Solar-specific features: Clear sky detection and variability
    # Clear sky indicator: low variability in recent irradiance
    win_2h = 2 * 12  # 2 hours
    irr_rolling_std = df['TARGET'].rolling(win_2h, min_periods=win_2h//2).std()
    df['clear_sky_indicator'] = (irr_rolling_std < irr_rolling_std.quantile(0.3)).astype(int).shift(1).fillna(0)

    # Solar angle and cloud interaction (past-only)
    if 'SZA' in df.columns and 'CLOUD_AMT' in df.columns:
        # Effective cloudiness considering sun angle
        df['effective_cloud'] = (df['CLOUD_AMT'] * np.cos(np.radians(df['SZA'].clip(0, 90)))).shift(1).fillna(0)
        
    # Temperature-irradiance interaction (past-only)
    if 'T2M' in df.columns:
        df['temp_irr_interaction'] = (df['T2M'] * df['TARGET']).shift(1).fillna(0)

    # Rolling statistics on lagged target (past-only)
    target_shifted = df['TARGET'].shift(1)
    df['irr_mean_1h']  = target_shifted.rolling(steps_1h,  min_periods=steps_1h//2).mean()
    df['irr_std_1h']   = target_shifted.rolling(steps_1h,  min_periods=steps_1h//2).std()
    df['irr_mean_6h']  = target_shifted.rolling(steps_6h,  min_periods=steps_6h//2).mean()
    df['irr_std_6h']   = target_shifted.rolling(steps_6h,  min_periods=steps_6h//2).std()
    df['irr_max_24h']  = target_shifted.rolling(steps_24h, min_periods=steps_24h//2).max()
    df['irr_mean_24h'] = target_shifted.rolling(steps_24h, min_periods=steps_24h//2).mean()

    # Solar momentum (change rates) - past-only
    def safe_div(num, den, eps=1e-6):
        den = den.copy()
        den = den.where(den.abs() > eps, eps)
        return num / den

    m1_num = df['TARGET'].shift(1)
    m1_den_1h = df['TARGET'].shift(1 + steps_1h)
    m6_den_6h = df['TARGET'].shift(1 + steps_6h)

    df['irr_momentum_1h'] = safe_div(m1_num, m1_den_1h) - 1.0
    df['irr_momentum_6h'] = safe_div(m1_num, m6_den_6h) - 1.0
    df['irr_momentum_1h'] = df['irr_momentum_1h'].clip(-3, 3)
    df['irr_momentum_6h'] = df['irr_momentum_6h'].clip(-3, 3)

    # Calendar features
    cal = make_calendar_features(df.index)
    
    # Meteorological features (already present in dataset)
    met_cols = ['T2M', 'RH2M', 'WS50M', 'PS', 'PRECTOTCORR', 'CLOUD_AMT', 'AOD_55', 'SZA']
    available_met_cols = [col for col in met_cols if col in df.columns]

    # Solar-specific engineered features
    solar_eng_cols = ['clear_sky_indicator']
    if 'effective_cloud' in df.columns:
        solar_eng_cols.append('effective_cloud')
    if 'temp_irr_interaction' in df.columns:
        solar_eng_cols.append('temp_irr_interaction')

    # Assemble feature blocks
    lag_cols = [f'TARGET_lag{L}' for L in season_lags if f'TARGET_lag{L}' in df.columns]
    roll_cols = ['irr_mean_1h', 'irr_std_1h', 'irr_mean_6h', 'irr_std_6h', 
                 'irr_max_24h', 'irr_mean_24h']
    mom_cols = ['irr_momentum_1h', 'irr_momentum_6h']

    feat_blocks = [cal]
    if available_met_cols:
        feat_blocks.append(df[available_met_cols])
    if lag_cols:
        feat_blocks.append(df[lag_cols])
    feat_blocks.append(df[solar_eng_cols])
    feat_blocks.append(df[roll_cols + mom_cols])

    X_exo = pd.concat(feat_blocks, axis=1)

    # ----------------------------
    # Finite-only sanitization BEFORE scaling
    # ----------------------------
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps (each sample's last target time) AFTER filtering
    times = df.index[W + H - 1 :]
    
    # df.to_csv('Dataset/solar_forecasting_processed.csv')

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # ----------------------------
    # SCALING (leak-free)
    # ----------------------------
    train_mask_for_scaler = df.index <= train_end
    if not train_mask_for_scaler.any():
        raise ValueError("No rows on/before train_end available to fit the scaler.")

    feat_scaler = MinMaxScaler()

    # Clean TRAIN slice for fit
    X_train = X_exo.loc[train_mask_for_scaler].copy()
    X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
    good_train_rows = np.isfinite(X_train.to_numpy()).all(axis=1)
    X_train = X_train.loc[good_train_rows]

    if X_train.empty:
        raise ValueError("No finite rows remain in training features after sanitization.")

    feat_scaler.fit(X_train.to_numpy())

    # Clean FULL for transform
    X_full = X_exo.copy()
    X_full.replace([np.inf, -np.inf], np.nan, inplace=True)
    if X_full.isna().any().any():
        X_full = X_full.bfill().ffill()

    keep_mask_full = np.isfinite(X_full.to_numpy()).all(axis=1)
    if not keep_mask_full.all():
        X_full = X_full.loc[keep_mask_full]
        df     = df.loc[X_full.index]
        times  = df.index[W + H - 1 :]

    X_feats_scaled = feat_scaler.transform(X_full.to_numpy())

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']].to_numpy())
    y_scaled = tgt_scaler.transform(df[['TARGET']].to_numpy())

    # Final data array: [features..., target_scaled] with target LAST
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # = F_feat + 1
    
    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 9
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for solar forecasting (emphasize daytime predictions)
    weights = torch.linspace(0.5, 1.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Solar Irradiance)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (tail-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, W/m²): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Solar Irradiance')
    plt.plot(times[test_idx], inv_p, label='Predicted Solar Irradiance', alpha=0.7)
    plt.title("24h-Ahead Solar Irradiance Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Solar Irradiance (W/m²)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Solar Irradiance')
            plt.plot(tgrid, pred_i, label='Predicted Solar Irradiance', alpha=0.8)
            plt.title(f"Full 24h Solar Irradiance Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Solar Irradiance (W/m²)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 5393, Validation windows: 10752, Test windows: 8352
# First window ts: 2023-07-10 11:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 8314016
# Ep01 Train=0.1185 | Val=0.1188 | Val(last) RMSE=252.3 MAE=197.5 MAPE=138.22% R²=0.251 | Val(full) RMSE=325.1 MAE=236.4 MAPE=163.72% | LR=0.000050 | Time=2.1s
# Ep02 Train=0.0948 | Val=0.0977 | Val(last) RMSE=244.3 MAE=180.0 MAPE=142.38% R²=0.298 | Val(full) RMSE=297.3 MAE=217.1 MAPE=153.09% | LR=0.000075 | Time=1.6s
# Ep03 Train=0.0832 | Val=0.0941 | Val(last) RMSE=205.7 MAE=152.1 MAPE=135.13% R²=0.502 | Val(full) RMSE=291.8 MAE=210.6 MAPE=151.39% | LR=0.000100 | Time=1.6s
# Ep04 Train=0.0698 | Val=0.0606 | Val(last) RMSE=189.3 MAE=145.6 MAPE=129.87% R²=0.578 | Val(full) RMSE=233.1 MAE=170.4 MAPE=137.40% | LR=0.000125 | Time=1.6s
# Ep05 Train=0.0497 | Val=0.0506 | Val(last) RMSE=160.9 MAE=104.4 MAPE=123.39% R²=0.695 | Val(full) RMSE=206.5 MAE=139.7 MAPE=133.08% | LR=0.000150 | Time=1.6s
# Ep06 Train=0.0375 | Val=0.0257 | Val(last) RMSE=163.0 MAE=98.1 MAPE=123.49% R²=0.687 | Val(full) RMSE=147.9 MAE=98.5 MAPE=122.02% | LR=0.000175 | Time=1.6s
# Ep07 Train=0.0271 | Val=0.0405 | Val(last) RMSE=210.0 MAE=124.3 MAPE=128.56% R²=0.481 | Val(full) RMSE=179.0 MAE=108.4 MAPE=125.91% | LR=0.000200 | Time=1.6s
# Ep08 Train=0.0216 | Val=0.0312 | Val(last) RMSE=195.5 MAE=117.3 MAPE=128.24% R²=0.550 | Val(full) RMSE=160.8 MAE=96.2 MAPE=122.32% | LR=0.000225 | Time=1.6s
# Ep09 Train=0.0183 | Val=0.0261 | Val(last) RMSE=158.9 MAE=94.4 MAPE=118.58% R²=0.703 | Val(full) RMSE=146.4 MAE=86.7 MAPE=118.93% | LR=0.000250 | Time=1.6s
# Ep10 Train=0.0172 | Val=0.0231 | Val(last) RMSE=163.4 MAE=97.9 MAPE=123.04% R²=0.686 | Val(full) RMSE=136.6 MAE=81.1 MAPE=117.50% | LR=0.000275 | Time=1.6s
# Ep11 Train=0.0157 | Val=0.0182 | Val(last) RMSE=127.5 MAE=76.0 MAPE=115.52% R²=0.809 | Val(full) RMSE=121.4 MAE=72.6 MAPE=114.92% | LR=0.000300 | Time=1.6s
# Ep12 Train=0.0154 | Val=0.0245 | Val(last) RMSE=152.2 MAE=97.2 MAPE=119.53% R²=0.727 | Val(full) RMSE=143.5 MAE=86.7 MAPE=117.55% | LR=0.000325 | Time=1.6s
# Ep13 Train=0.0152 | Val=0.0171 | Val(last) RMSE=113.7 MAE=71.0 MAPE=113.78% R²=0.848 | Val(full) RMSE=119.5 MAE=71.0 MAPE=113.99% | LR=0.000350 | Time=1.6s
# Ep14 Train=0.0153 | Val=0.0195 | Val(last) RMSE=115.1 MAE=73.3 MAPE=114.32% R²=0.844 | Val(full) RMSE=127.0 MAE=78.1 MAPE=115.06% | LR=0.000375 | Time=1.6s
# Ep15 Train=0.0149 | Val=0.0163 | Val(last) RMSE=111.3 MAE=70.0 MAPE=113.51% R²=0.854 | Val(full) RMSE=115.7 MAE=69.6 MAPE=114.00% | LR=0.000400 | Time=1.6s
# Ep16 Train=0.0148 | Val=0.0222 | Val(last) RMSE=144.0 MAE=88.6 MAPE=117.66% R²=0.756 | Val(full) RMSE=135.8 MAE=84.1 MAPE=116.23% | LR=0.000425 | Time=1.6s
# Ep17 Train=0.0142 | Val=0.0253 | Val(last) RMSE=129.6 MAE=87.9 MAPE=116.57% R²=0.802 | Val(full) RMSE=143.3 MAE=90.4 MAPE=117.56% | LR=0.000450 | Time=1.6s
# Ep18 Train=0.0149 | Val=0.0191 | Val(last) RMSE=122.6 MAE=81.5 MAPE=116.25% R²=0.823 | Val(full) RMSE=124.5 MAE=78.9 MAPE=115.71% | LR=0.000475 | Time=1.6s
# Ep19 Train=0.0149 | Val=0.0170 | Val(last) RMSE=114.0 MAE=70.7 MAPE=113.47% R²=0.847 | Val(full) RMSE=119.5 MAE=73.1 MAPE=114.08% | LR=0.000500 | Time=1.6s
# Ep20 Train=0.0146 | Val=0.0175 | Val(last) RMSE=104.3 MAE=70.7 MAPE=113.72% R²=0.872 | Val(full) RMSE=118.5 MAE=78.8 MAPE=115.15% | LR=0.000500 | Time=1.6s
# Ep21 Train=0.0145 | Val=0.0177 | Val(last) RMSE=120.5 MAE=83.9 MAPE=116.36% R²=0.829 | Val(full) RMSE=121.0 MAE=78.5 MAPE=115.20% | LR=0.000500 | Time=1.6s
# Ep22 Train=0.0145 | Val=0.0239 | Val(last) RMSE=166.7 MAE=101.9 MAPE=120.83% R²=0.673 | Val(full) RMSE=139.9 MAE=90.3 MAPE=117.27% | LR=0.000499 | Time=1.6s
# Ep23 Train=0.0145 | Val=0.0181 | Val(last) RMSE=114.2 MAE=73.8 MAPE=114.19% R²=0.847 | Val(full) RMSE=122.0 MAE=77.8 MAPE=115.06% | LR=0.000498 | Time=1.6s
# Ep24 Train=0.0143 | Val=0.0197 | Val(last) RMSE=138.2 MAE=88.0 MAPE=117.61% R²=0.775 | Val(full) RMSE=128.1 MAE=83.1 MAPE=115.92% | LR=0.000497 | Time=1.7s
# Ep25 Train=0.0149 | Val=0.0228 | Val(last) RMSE=129.2 MAE=87.4 MAPE=117.59% R²=0.804 | Val(full) RMSE=135.5 MAE=86.2 MAPE=116.82% | LR=0.000495 | Time=1.7s
# Ep26 Train=0.0141 | Val=0.0180 | Val(last) RMSE=107.8 MAE=69.3 MAPE=112.56% R²=0.863 | Val(full) RMSE=120.1 MAE=78.0 MAPE=114.74% | LR=0.000493 | Time=1.6s
# Ep27 Train=0.0144 | Val=0.0218 | Val(last) RMSE=141.4 MAE=93.8 MAPE=119.09% R²=0.765 | Val(full) RMSE=133.9 MAE=88.8 MAPE=116.74% | LR=0.000491 | Time=1.6s
# Ep28 Train=0.0137 | Val=0.0285 | Val(last) RMSE=148.5 MAE=104.1 MAPE=117.96% R²=0.741 | Val(full) RMSE=151.2 MAE=100.4 MAPE=118.78% | LR=0.000488 | Time=1.6s
# Ep29 Train=0.0164 | Val=0.0163 | Val(last) RMSE=105.4 MAE=67.5 MAPE=112.56% R²=0.869 | Val(full) RMSE=117.0 MAE=73.2 MAPE=114.29% | LR=0.000485 | Time=1.6s
# Ep30 Train=0.0151 | Val=0.0146 | Val(last) RMSE=115.0 MAE=76.0 MAPE=115.63% R²=0.844 | Val(full) RMSE=109.7 MAE=72.4 MAPE=114.11% | LR=0.000481 | Time=1.6s
# Ep31 Train=0.0146 | Val=0.0179 | Val(last) RMSE=103.2 MAE=74.6 MAPE=113.25% R²=0.875 | Val(full) RMSE=122.5 MAE=83.2 MAPE=115.68% | LR=0.000477 | Time=1.6s
# Ep32 Train=0.0142 | Val=0.0203 | Val(last) RMSE=134.9 MAE=89.1 MAPE=117.15% R²=0.786 | Val(full) RMSE=130.3 MAE=85.3 MAPE=116.26% | LR=0.000473 | Time=1.6s
# Ep33 Train=0.0141 | Val=0.0254 | Val(last) RMSE=131.7 MAE=95.7 MAPE=117.55% R²=0.796 | Val(full) RMSE=146.3 MAE=98.0 MAPE=118.42% | LR=0.000468 | Time=1.6s
# Ep34 Train=0.0140 | Val=0.0204 | Val(last) RMSE=136.1 MAE=85.5 MAPE=116.56% R²=0.782 | Val(full) RMSE=127.9 MAE=81.6 MAPE=116.08% | LR=0.000463 | Time=1.6s
# Ep35 Train=0.0144 | Val=0.0241 | Val(last) RMSE=138.3 MAE=90.8 MAPE=118.26% R²=0.775 | Val(full) RMSE=140.7 MAE=92.1 MAPE=117.58% | LR=0.000458 | Time=1.6s
# Ep36 Train=0.0146 | Val=0.0216 | Val(last) RMSE=125.4 MAE=84.2 MAPE=115.97% R²=0.815 | Val(full) RMSE=135.2 MAE=86.1 MAPE=116.65% | LR=0.000452 | Time=1.6s
# Ep37 Train=0.0148 | Val=0.0233 | Val(last) RMSE=144.8 MAE=93.6 MAPE=118.44% R²=0.753 | Val(full) RMSE=139.7 MAE=93.4 MAPE=117.55% | LR=0.000446 | Time=1.6s
# Ep38 Train=0.0141 | Val=0.0176 | Val(last) RMSE=108.3 MAE=75.5 MAPE=113.75% R²=0.862 | Val(full) RMSE=121.5 MAE=77.9 MAPE=115.13% | LR=0.000440 | Time=1.6s
# Ep39 Train=0.0142 | Val=0.0176 | Val(last) RMSE=110.7 MAE=75.8 MAPE=113.86% R²=0.856 | Val(full) RMSE=119.6 MAE=76.6 MAPE=114.69% | LR=0.000434 | Time=1.6s
# Ep40 Train=0.0140 | Val=0.0159 | Val(last) RMSE=99.9 MAE=66.9 MAPE=113.10% R²=0.883 | Val(full) RMSE=115.3 MAE=75.0 MAPE=114.44% | LR=0.000427 | Time=1.6s
# Ep41 Train=0.0145 | Val=0.0207 | Val(last) RMSE=128.3 MAE=82.9 MAPE=116.41% R²=0.806 | Val(full) RMSE=129.9 MAE=82.2 MAPE=115.70% | LR=0.000420 | Time=1.6s
# Ep42 Train=0.0144 | Val=0.0196 | Val(last) RMSE=127.8 MAE=81.1 MAPE=115.67% R²=0.808 | Val(full) RMSE=126.5 MAE=79.4 MAPE=115.51% | LR=0.000412 | Time=1.6s
# Ep43 Train=0.0134 | Val=0.0227 | Val(last) RMSE=126.8 MAE=85.3 MAPE=115.90% R²=0.811 | Val(full) RMSE=137.6 MAE=89.5 MAPE=117.13% | LR=0.000405 | Time=1.6s
# Ep44 Train=0.0143 | Val=0.0207 | Val(last) RMSE=128.6 MAE=93.3 MAPE=116.38% R²=0.805 | Val(full) RMSE=132.3 MAE=87.4 MAPE=116.58% | LR=0.000397 | Time=1.6s
# Ep45 Train=0.0146 | Val=0.0164 | Val(last) RMSE=123.5 MAE=77.4 MAPE=115.17% R²=0.821 | Val(full) RMSE=116.5 MAE=76.3 MAPE=114.90% | LR=0.000389 | Time=1.6s
# Ep46 Train=0.0144 | Val=0.0216 | Val(last) RMSE=126.9 MAE=88.3 MAPE=117.83% R²=0.810 | Val(full) RMSE=132.3 MAE=91.3 MAPE=116.89% | LR=0.000381 | Time=1.6s
# Ep47 Train=0.0141 | Val=0.0219 | Val(last) RMSE=121.3 MAE=84.1 MAPE=116.06% R²=0.827 | Val(full) RMSE=132.5 MAE=85.4 MAPE=116.25% | LR=0.000372 | Time=1.6s
# Ep48 Train=0.0139 | Val=0.0223 | Val(last) RMSE=122.7 MAE=81.9 MAPE=116.12% R²=0.823 | Val(full) RMSE=134.5 MAE=85.7 MAPE=116.57% | LR=0.000363 | Time=1.6s
# Ep49 Train=0.0142 | Val=0.0248 | Val(last) RMSE=132.1 MAE=87.1 MAPE=116.42% R²=0.795 | Val(full) RMSE=141.6 MAE=91.4 MAPE=117.27% | LR=0.000355 | Time=1.6s
# Ep50 Train=0.0140 | Val=0.0210 | Val(last) RMSE=125.4 MAE=81.3 MAPE=115.95% R²=0.815 | Val(full) RMSE=130.9 MAE=83.6 MAPE=116.01% | LR=0.000346 | Time=1.6s
# Ep51 Train=0.0139 | Val=0.0201 | Val(last) RMSE=102.9 MAE=70.1 MAPE=113.53% R²=0.875 | Val(full) RMSE=127.3 MAE=79.3 MAPE=115.38% | LR=0.000337 | Time=1.6s
# Ep52 Train=0.0139 | Val=0.0176 | Val(last) RMSE=122.1 MAE=80.7 MAPE=114.93% R²=0.824 | Val(full) RMSE=121.2 MAE=79.7 MAPE=115.07% | LR=0.000327 | Time=1.6s
# Ep53 Train=0.0140 | Val=0.0212 | Val(last) RMSE=118.9 MAE=80.0 MAPE=114.79% R²=0.834 | Val(full) RMSE=132.4 MAE=86.5 MAPE=116.30% | LR=0.000318 | Time=1.6s
# Ep54 Train=0.0139 | Val=0.0185 | Val(last) RMSE=122.9 MAE=83.4 MAPE=116.62% R²=0.822 | Val(full) RMSE=124.4 MAE=79.0 MAPE=115.16% | LR=0.000308 | Time=1.6s
# Ep55 Train=0.0137 | Val=0.0211 | Val(last) RMSE=136.9 MAE=91.7 MAPE=117.77% R²=0.779 | Val(full) RMSE=131.7 MAE=85.6 MAPE=116.46% | LR=0.000299 | Time=1.7s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (tail-weighted MSE): 0.0055
#
# Final Test Metrics (last step, W/m²): MSE=3816.88, RMSE=61.78, MAE=47.84, R²=0.9284, Adj R²=0.9282
# Final Test Metrics (full 24h path): RMSE=68.21, MAE=54.53
# Hourly-averaged RMSE by lead hour (0→23):
# [60.96, 65.  , 68.52, 67.99, 65.76, 64.73, 66.18, 71.51, 74.85, 73.46,
#  69.09, 66.39, 69.7 , 74.52, 73.85, 70.46, 67.16, 65.01, 64.96, 67.65,
#  70.67, 68.76, 65.08, 62.15]
# Avg inference latency: 0.21 ms/batch • 0.21 ms/sample

# %% [markdown]
# ### 2DCNN

# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model: 2D CNN forecaster (two Conv2d blocks)
# ----------------------------
class CNN2D_Forecaster(nn.Module):
    """
    Input [B, W, F]
      -> Unsqueeze -> [B,1,W,F]
      -> Conv2d(k_t1 x k_f1) + ReLU -> AvgPool2d(time only) -> BN -> Dropout
      -> Conv2d(k_t2 x k_f2) + ReLU -> AvgPool2d(time only) -> BN -> Dropout
      -> Flatten
      -> Concatenate with last-step raw features [B, F]
      -> MLP head -> horizon
      -> Output [B, H, 1]
    """
    def __init__(
        self,
        n_features: int,
        window: int,
        horizon: int,
        # block 1
        channels1: int = 64,
        ksize_t1: int = 9,
        ksize_f1: int = 3,
        pool_t1: int = 2,
        # block 2
        channels2: int = 64,
        ksize_t2: int = 5,
        ksize_f2: int = 3,
        pool_t2: int = 2,
        # head/regularization
        p_drop: float = 0.2,
        hidden: int = 256,
    ):
        super().__init__()
        if pool_t1 < 1 or pool_t2 < 1:
            raise ValueError("pool_t1 and pool_t2 must be >= 1")
        if (window // (pool_t1 * pool_t2)) <= 0:
            raise ValueError("window must be >= pool_t1 * pool_t2")

        self.n_features = n_features
        self.window = window
        self.horizon = horizon

        # -------- Block 1 --------
        pad_t1 = (ksize_t1 - 1) // 2
        pad_f1 = (ksize_f1 - 1) // 2
        self.conv1 = nn.Conv2d(
            in_channels=1,
            out_channels=channels1,
            kernel_size=(ksize_t1, ksize_f1),
            padding=(pad_t1, pad_f1),
            bias=True,
        )
        self.act1  = nn.ReLU(inplace=True)
        self.pool1 = nn.AvgPool2d(kernel_size=(pool_t1, 1))  # downsample time only
        self.bn1   = nn.BatchNorm2d(channels1)
        self.do1   = nn.Dropout(p_drop)

        # -------- Block 2 --------
        pad_t2 = (ksize_t2 - 1) // 2
        pad_f2 = (ksize_f2 - 1) // 2
        self.conv2 = nn.Conv2d(
            in_channels=channels1,
            out_channels=channels2,
            kernel_size=(ksize_t2, ksize_f2),
            padding=(pad_t2, pad_f2),
            bias=True,
        )
        self.act2  = nn.ReLU(inplace=True)
        self.pool2 = nn.AvgPool2d(kernel_size=(pool_t2, 1))  # downsample time only
        self.bn2   = nn.BatchNorm2d(channels2)
        self.do2   = nn.Dropout(p_drop)

        # Flattened size after both pools
        conv_T = window // (pool_t1 * pool_t2)  # time length after two pools
        flat_dim = channels2 * conv_T * n_features

        # Head (concat flattened conv features with last-step raw features)
        concat_dim = flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon),
        )

        # Init
        for m in [self.conv1, self.conv2]:
            nn.init.kaiming_uniform_(m.weight, a=math.sqrt(5))
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        for m in self.head:
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: [B, W, F]
        B, W, F = x.shape
        h = x.unsqueeze(1)      # [B,1,W,F]

        # Block 1
        h = self.conv1(h)
        h = self.act1(h)
        h = self.pool1(h)
        h = self.bn1(h)
        h = self.do1(h)

        # Block 2
        h = self.conv2(h)
        h = self.act2(h)
        h = self.pool2(h)
        h = self.bn2(h)
        h = self.do2(h)

        # Flatten
        h = h.reshape(B, -1)

        # Concatenate with last-step raw features
        x_last = x[:, -1, :]      # [B,F]
        z = torch.cat([h, x_last], dim=1)

        # Head
        yhat = self.head(z)       # [B,H]
        return yhat.unsqueeze(-1) # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load solar irradiance dataset
    df = pd.read_csv('NASA-DATASET/solar_forecasting.csv', parse_dates=['DATETIME'], index_col='DATETIME').fillna(0)
    df.index = pd.to_datetime(df.index, format='mixed', errors='raise')
    
    # Rename target variable for consistency with original code structure
    target_col = 'ALLSKY_SFC_SW_DWN'  # Solar irradiance target
    df['TARGET'] = df[target_col]
    
    # Handle missing values
    df['TARGET'] = df['TARGET'].interpolate(method='time')
    df['TARGET'] = df['TARGET'].bfill().ffill()

    # Cadence sanity check
    _ = infer_5min_freq(df.index)

    # Window sizes for solar forecasting
    W = 7 * 24 * 12   # one week lookback (7 days) - 5 minute resolution  
    H = 1 * 24 * 12   # 24h horizon - 5 minute resolution

    # ----------------------------
    # Feature engineering (LEAK-FREE) - adapted for solar data
    # ----------------------------
    steps_per_hour = 12
    steps_1h  = 1  * steps_per_hour       # 12
    steps_6h  = 6  * steps_per_hour       # 72
    steps_24h = 24 * steps_per_hour       # 288

    # Seasonal lags for solar patterns (daily and yearly cycles)
    season_lags = [52560]
    for L in season_lags:
        if L < len(df):
            df[f'TARGET_lag{L}'] = df['TARGET'].shift(L)

    # Solar-specific features: Clear sky detection and variability
    # Clear sky indicator: low variability in recent irradiance
    win_2h = 2 * 12  # 2 hours
    irr_rolling_std = df['TARGET'].rolling(win_2h, min_periods=win_2h//2).std()
    df['clear_sky_indicator'] = (irr_rolling_std < irr_rolling_std.quantile(0.3)).astype(int).shift(1).fillna(0)

    # Solar angle and cloud interaction (past-only)
    if 'SZA' in df.columns and 'CLOUD_AMT' in df.columns:
        # Effective cloudiness considering sun angle
        df['effective_cloud'] = (df['CLOUD_AMT'] * np.cos(np.radians(df['SZA'].clip(0, 90)))).shift(1).fillna(0)
        
    # Temperature-irradiance interaction (past-only)
    if 'T2M' in df.columns:
        df['temp_irr_interaction'] = (df['T2M'] * df['TARGET']).shift(1).fillna(0)

    # Rolling statistics on lagged target (past-only)
    target_shifted = df['TARGET'].shift(1)
    df['irr_mean_1h']  = target_shifted.rolling(steps_1h,  min_periods=steps_1h//2).mean()
    df['irr_std_1h']   = target_shifted.rolling(steps_1h,  min_periods=steps_1h//2).std()
    df['irr_mean_6h']  = target_shifted.rolling(steps_6h,  min_periods=steps_6h//2).mean()
    df['irr_std_6h']   = target_shifted.rolling(steps_6h,  min_periods=steps_6h//2).std()
    df['irr_max_24h']  = target_shifted.rolling(steps_24h, min_periods=steps_24h//2).max()
    df['irr_mean_24h'] = target_shifted.rolling(steps_24h, min_periods=steps_24h//2).mean()

    # Solar momentum (change rates) - past-only
    def safe_div(num, den, eps=1e-6):
        den = den.copy()
        den = den.where(den.abs() > eps, eps)
        return num / den

    m1_num = df['TARGET'].shift(1)
    m1_den_1h = df['TARGET'].shift(1 + steps_1h)
    m6_den_6h = df['TARGET'].shift(1 + steps_6h)

    df['irr_momentum_1h'] = safe_div(m1_num, m1_den_1h) - 1.0
    df['irr_momentum_6h'] = safe_div(m1_num, m6_den_6h) - 1.0
    df['irr_momentum_1h'] = df['irr_momentum_1h'].clip(-3, 3)
    df['irr_momentum_6h'] = df['irr_momentum_6h'].clip(-3, 3)

    # Calendar features
    cal = make_calendar_features(df.index)
    
    # Meteorological features (already present in dataset)
    met_cols = ['T2M', 'RH2M', 'WS50M', 'PS', 'PRECTOTCORR', 'CLOUD_AMT', 'AOD_55', 'SZA']
    available_met_cols = [col for col in met_cols if col in df.columns]

    # Solar-specific engineered features
    solar_eng_cols = ['clear_sky_indicator']
    if 'effective_cloud' in df.columns:
        solar_eng_cols.append('effective_cloud')
    if 'temp_irr_interaction' in df.columns:
        solar_eng_cols.append('temp_irr_interaction')

    # Assemble feature blocks
    lag_cols = [f'TARGET_lag{L}' for L in season_lags if f'TARGET_lag{L}' in df.columns]
    roll_cols = ['irr_mean_1h', 'irr_std_1h', 'irr_mean_6h', 'irr_std_6h', 
                 'irr_max_24h', 'irr_mean_24h']
    mom_cols = ['irr_momentum_1h', 'irr_momentum_6h']

    feat_blocks = [cal]
    if available_met_cols:
        feat_blocks.append(df[available_met_cols])
    if lag_cols:
        feat_blocks.append(df[lag_cols])
    feat_blocks.append(df[solar_eng_cols])
    feat_blocks.append(df[roll_cols + mom_cols])

    X_exo = pd.concat(feat_blocks, axis=1)

    # ----------------------------
    # Finite-only sanitization BEFORE scaling
    # ----------------------------
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps (each sample's last target time) AFTER filtering
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # ----------------------------
    # SCALING (leak-free)
    # ----------------------------
    train_mask_for_scaler = df.index <= train_end
    if not train_mask_for_scaler.any():
        raise ValueError("No rows on/before train_end available to fit the scaler.")

    feat_scaler = MinMaxScaler()

    # Clean TRAIN slice for fit
    X_train = X_exo.loc[train_mask_for_scaler].copy()
    X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
    good_train_rows = np.isfinite(X_train.to_numpy()).all(axis=1)
    X_train = X_train.loc[good_train_rows]

    if X_train.empty:
        raise ValueError("No finite rows remain in training features after sanitization.")

    feat_scaler.fit(X_train.to_numpy())

    # Clean FULL for transform
    X_full = X_exo.copy()
    X_full.replace([np.inf, -np.inf], np.nan, inplace=True)
    if X_full.isna().any().any():
        X_full = X_full.bfill().ffill()

    keep_mask_full = np.isfinite(X_full.to_numpy()).all(axis=1)
    if not keep_mask_full.all():
        X_full = X_full.loc[keep_mask_full]
        df     = df.loc[X_full.index]
        times  = df.index[W + H - 1 :]

    X_feats_scaled = feat_scaler.transform(X_full.to_numpy())

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']].to_numpy())
    y_scaled = tgt_scaler.transform(df[['TARGET']].to_numpy())

    # Final data array: [features..., target_scaled] with target LAST
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # = F_feat + 1

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 9
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # 2D-CNN model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN2D_Forecaster(
        n_features=n_features,
        window=W,
        horizon=H,
        channels1=64, ksize_t1=9, ksize_f1=3, pool_t1=2,
        channels2=64, ksize_t2=5, ksize_f2=3, pool_t2=2,
        p_drop=0.2, hidden=256
    ).to(device)

    # (Optional) tighter BN momentum for long sequences
    for m in model.modules():
        if isinstance(m, nn.BatchNorm2d):
            m.momentum = 0.05

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for solar forecasting (emphasize daytime predictions)
    weights = torch.linspace(0.5, 1.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Solar Irradiance)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (tail-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, W/m²): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Solar Irradiance')
    plt.plot(times[test_idx], inv_p, label='Predicted Solar Irradiance', alpha=0.7)
    plt.title("24h-Ahead Solar Irradiance Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Solar Irradiance (W/m²)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Solar Irradiance')
            plt.plot(tgrid, pred_i, label='Predicted Solar Irradiance', alpha=0.8)
            plt.title(f"Full 24h Solar Irradiance Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Solar Irradiance (W/m²)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 5393, Validation windows: 10752, Test windows: 8352
# First window ts: 2023-07-10 11:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 223098208
# Ep01 Train=0.1441 | Val=0.2020 | Val(last) RMSE=357.5 MAE=224.3 MAPE=180.79% R²=-0.504 | Val(full) RMSE=414.1 MAE=258.1 MAPE=185.59% | LR=0.000050 | Time=32.2s
# Ep02 Train=0.1195 | Val=0.2237 | Val(last) RMSE=360.4 MAE=229.6 MAPE=174.90% R²=-0.529 | Val(full) RMSE=435.9 MAE=270.2 MAPE=179.83% | LR=0.000075 | Time=32.6s
# Ep03 Train=0.1156 | Val=0.2591 | Val(last) RMSE=455.0 MAE=273.1 MAPE=178.08% R²=-1.437 | Val(full) RMSE=470.6 MAE=264.7 MAPE=175.58% | LR=0.000100 | Time=32.3s
# Ep04 Train=0.1107 | Val=0.2926 | Val(last) RMSE=485.1 MAE=282.8 MAPE=173.22% R²=-1.770 | Val(full) RMSE=500.5 MAE=272.2 MAPE=170.44% | LR=0.000125 | Time=33.0s
# Ep05 Train=0.1052 | Val=0.2804 | Val(last) RMSE=475.9 MAE=281.9 MAPE=168.64% R²=-1.665 | Val(full) RMSE=489.9 MAE=271.2 MAPE=165.68% | LR=0.000150 | Time=32.4s
# Ep06 Train=0.0996 | Val=0.2736 | Val(last) RMSE=470.8 MAE=283.0 MAPE=164.43% R²=-1.609 | Val(full) RMSE=484.0 MAE=272.2 MAPE=161.42% | LR=0.000175 | Time=32.5s
# Ep07 Train=0.0943 | Val=0.2705 | Val(last) RMSE=468.8 MAE=285.8 MAPE=160.91% R²=-1.586 | Val(full) RMSE=481.3 MAE=274.7 MAPE=157.68% | LR=0.000200 | Time=32.2s
# Ep08 Train=0.0897 | Val=0.2628 | Val(last) RMSE=463.1 MAE=287.5 MAPE=157.67% R²=-1.524 | Val(full) RMSE=474.5 MAE=276.4 MAPE=154.43% | LR=0.000225 | Time=32.4s
# Ep09 Train=0.0860 | Val=0.2600 | Val(last) RMSE=461.5 MAE=290.7 MAPE=155.00% R²=-1.507 | Val(full) RMSE=472.1 MAE=279.4 MAPE=151.72% | LR=0.000250 | Time=31.6s
# Ep10 Train=0.0833 | Val=0.2569 | Val(last) RMSE=459.6 MAE=293.5 MAPE=152.71% R²=-1.486 | Val(full) RMSE=469.3 MAE=282.2 MAPE=149.51% | LR=0.000275 | Time=31.5s
# Ep11 Train=0.0815 | Val=0.2522 | Val(last) RMSE=456.2 MAE=295.4 MAPE=150.84% R²=-1.450 | Val(full) RMSE=465.0 MAE=284.2 MAPE=147.78% | LR=0.000300 | Time=32.1s
# Ep12 Train=0.0804 | Val=0.2487 | Val(last) RMSE=453.9 MAE=297.1 MAPE=149.52% R²=-1.424 | Val(full) RMSE=461.8 MAE=286.0 MAPE=146.49% | LR=0.000325 | Time=32.8s
# Ep13 Train=0.0798 | Val=0.2497 | Val(last) RMSE=455.2 MAE=299.5 MAPE=148.58% R²=-1.439 | Val(full) RMSE=462.8 MAE=288.3 MAPE=145.60% | LR=0.000350 | Time=30.8s
# Ep14 Train=0.0796 | Val=0.2506 | Val(last) RMSE=456.4 MAE=301.1 MAPE=147.99% R²=-1.451 | Val(full) RMSE=463.6 MAE=289.9 MAPE=145.03% | LR=0.000375 | Time=31.0s
# Ep15 Train=0.0795 | Val=0.2477 | Val(last) RMSE=454.0 MAE=301.1 MAPE=147.62% R²=-1.425 | Val(full) RMSE=460.9 MAE=290.1 MAPE=144.64% | LR=0.000400 | Time=30.7s
# Ep16 Train=0.0795 | Val=0.2504 | Val(last) RMSE=456.5 MAE=302.5 MAPE=147.39% R²=-1.452 | Val(full) RMSE=463.4 MAE=291.3 MAPE=144.46% | LR=0.000425 | Time=32.0s
# Ep17 Train=0.0795 | Val=0.2481 | Val(last) RMSE=454.5 MAE=302.2 MAPE=147.24% R²=-1.431 | Val(full) RMSE=461.3 MAE=291.0 MAPE=144.35% | LR=0.000450 | Time=32.3s
# Ep18 Train=0.0795 | Val=0.2510 | Val(last) RMSE=457.1 MAE=303.2 MAPE=147.20% R²=-1.459 | Val(full) RMSE=464.0 MAE=291.8 MAPE=144.31% | LR=0.000475 | Time=32.5s
# Ep19 Train=0.0795 | Val=0.2472 | Val(last) RMSE=453.8 MAE=302.2 MAPE=147.12% R²=-1.423 | Val(full) RMSE=460.5 MAE=291.0 MAPE=144.28% | LR=0.000500 | Time=31.1s
# Ep20 Train=0.0795 | Val=0.2486 | Val(last) RMSE=455.1 MAE=302.9 MAPE=147.05% R²=-1.437 | Val(full) RMSE=461.8 MAE=291.3 MAPE=144.26% | LR=0.000500 | Time=31.2s
# Ep21 Train=0.0795 | Val=0.2486 | Val(last) RMSE=455.1 MAE=302.8 MAPE=147.08% R²=-1.437 | Val(full) RMSE=461.7 MAE=291.3 MAPE=144.27% | LR=0.000500 | Time=30.1s
# Ep22 Train=0.0795 | Val=0.2481 | Val(last) RMSE=454.6 MAE=302.4 MAPE=147.16% R²=-1.432 | Val(full) RMSE=461.3 MAE=291.1 MAPE=144.30% | LR=0.000499 | Time=30.5s
# Ep23 Train=0.0795 | Val=0.2475 | Val(last) RMSE=454.0 MAE=302.2 MAPE=147.18% R²=-1.426 | Val(full) RMSE=460.7 MAE=291.0 MAPE=144.30% | LR=0.000498 | Time=31.2s
# Ep24 Train=0.0795 | Val=0.2529 | Val(last) RMSE=459.0 MAE=303.5 MAPE=147.33% R²=-1.479 | Val(full) RMSE=465.8 MAE=292.3 MAPE=144.29% | LR=0.000497 | Time=29.8s
# Ep25 Train=0.0795 | Val=0.2474 | Val(last) RMSE=453.9 MAE=302.1 MAPE=147.21% R²=-1.425 | Val(full) RMSE=460.6 MAE=291.0 MAPE=144.25% | LR=0.000495 | Time=32.9s
# Ep26 Train=0.0795 | Val=0.2450 | Val(last) RMSE=452.0 MAE=301.6 MAPE=147.13% R²=-1.404 | Val(full) RMSE=458.4 MAE=290.4 MAPE=144.27% | LR=0.000493 | Time=32.6s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (tail-weighted MSE): 0.0967
#
# Final Test Metrics (last step, W/m²): MSE=81773.85, RMSE=285.96, MAE=172.26, R²=-0.5338, Adj R²=-0.5386
# Final Test Metrics (full 24h path): RMSE=286.30, MAE=172.46
# Hourly-averaged RMSE by lead hour (0→23):
# [286.79, 286.81, 286.84, 286.86, 286.86, 286.86, 286.85, 286.79, 286.67,
#  286.51, 286.32, 286.15, 286.04, 285.94, 285.9 , 285.88, 285.88, 285.88,
#  285.89, 285.9 , 285.89, 285.9 , 285.9 , 285.93]
# Avg inference latency: 3.21 ms/batch • 3.21 ms/sample

# %% [markdown]
# ### LSTM

# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# LSTM Model
# ----------------------------
class LSTM_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 enc1=256, enc2=128,
                 latent_dim=64, p_drop=0.2):
        super().__init__()
        self.n_features = n_features
        self.window = window
        self.horizon = horizon

        # Encoder
        self.enc1 = nn.LSTM(input_size=n_features, hidden_size=enc1, batch_first=True)
        self.enc2 = nn.LSTM(input_size=enc1,       hidden_size=enc2, batch_first=True)
        self.enc_ln = nn.LayerNorm(enc2)

        # Attention pooling over encoder sequence -> context
        self.attn = nn.Sequential(
            nn.Linear(enc2, enc2),
            nn.Tanh(),
            nn.Linear(enc2, 1)
        )

        # context -> latent
        self.to_latent = nn.Sequential(
            nn.Linear(enc2, latent_dim),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(latent_dim, latent_dim)
        )

        # Forecast head (TOTAL for H steps)
        # condition on [latent || last_observed_features] to anchor short-term
        f_in = latent_dim + n_features
        self.forecast = nn.Sequential(
            nn.Linear(f_in, 128),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(128, horizon)  # -> [B, H]
        )

    def forward(self, x):
        """
        x: [B, W, F]
        return: yhat [B, H, 1]  (forecast output)
        """
        B, W, F = x.shape

        # Encode
        h1, _ = self.enc1(x)               # [B,W,enc1]
        h2, _ = self.enc2(h1)              # [B,W,enc2]
        h2 = self.enc_ln(h2)

        # Attention pooling across time
        a = self.attn(h2)                  # [B,W,1]
        a = torch.softmax(a, dim=1)
        ctx = (a * h2).sum(dim=1)          # [B,enc2]

        # Latent
        z = self.to_latent(ctx)            # [B,latent]

        # Forecast
        x_last = x[:, -1, :]               # [B,F]
        f_in = torch.cat([z, x_last], dim=1)   # [B,latent+F]
        yhat = self.forecast(f_in).unsqueeze(-1)  # [B,H,1]
        return yhat

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load solar irradiance dataset
    df = pd.read_csv('NASA-DATASET/solar_forecasting.csv', parse_dates=['DATETIME'], index_col='DATETIME').fillna(0)
    df.index = pd.to_datetime(df.index, format='mixed', errors='raise')
    
    # Rename target variable for consistency with original code structure
    target_col = 'ALLSKY_SFC_SW_DWN'  # Solar irradiance target
    df['TARGET'] = df[target_col]
    
    # Handle missing values
    df['TARGET'] = df['TARGET'].interpolate(method='time')
    df['TARGET'] = df['TARGET'].bfill().ffill()

    # Cadence sanity check
    _ = infer_5min_freq(df.index)

    # Window sizes for solar forecasting
    W = 7 * 24 * 12   # one week lookback (7 days) - 5 minute resolution  
    H = 1 * 24 * 12   # 24h horizon - 5 minute resolution

    # ----------------------------
    # Feature engineering (LEAK-FREE) - adapted for solar data
    # ----------------------------
    steps_per_hour = 12
    steps_1h  = 1  * steps_per_hour       # 12
    steps_6h  = 6  * steps_per_hour       # 72
    steps_24h = 24 * steps_per_hour       # 288

    # Seasonal lags for solar patterns (daily and yearly cycles)
    season_lags = [52560]
    for L in season_lags:
        if L < len(df):
            df[f'TARGET_lag{L}'] = df['TARGET'].shift(L)

    # Solar-specific features: Clear sky detection and variability
    # Clear sky indicator: low variability in recent irradiance
    win_2h = 2 * 12  # 2 hours
    irr_rolling_std = df['TARGET'].rolling(win_2h, min_periods=win_2h//2).std()
    df['clear_sky_indicator'] = (irr_rolling_std < irr_rolling_std.quantile(0.3)).astype(int).shift(1).fillna(0)

    # Solar angle and cloud interaction (past-only)
    if 'SZA' in df.columns and 'CLOUD_AMT' in df.columns:
        # Effective cloudiness considering sun angle
        df['effective_cloud'] = (df['CLOUD_AMT'] * np.cos(np.radians(df['SZA'].clip(0, 90)))).shift(1).fillna(0)
        
    # Temperature-irradiance interaction (past-only)
    if 'T2M' in df.columns:
        df['temp_irr_interaction'] = (df['T2M'] * df['TARGET']).shift(1).fillna(0)

    # Rolling statistics on lagged target (past-only)
    target_shifted = df['TARGET'].shift(1)
    df['irr_mean_1h']  = target_shifted.rolling(steps_1h,  min_periods=steps_1h//2).mean()
    df['irr_std_1h']   = target_shifted.rolling(steps_1h,  min_periods=steps_1h//2).std()
    df['irr_mean_6h']  = target_shifted.rolling(steps_6h,  min_periods=steps_6h//2).mean()
    df['irr_std_6h']   = target_shifted.rolling(steps_6h,  min_periods=steps_6h//2).std()
    df['irr_max_24h']  = target_shifted.rolling(steps_24h, min_periods=steps_24h//2).max()
    df['irr_mean_24h'] = target_shifted.rolling(steps_24h, min_periods=steps_24h//2).mean()

    # Solar momentum (change rates) - past-only
    def safe_div(num, den, eps=1e-6):
        den = den.copy()
        den = den.where(den.abs() > eps, eps)
        return num / den

    m1_num = df['TARGET'].shift(1)
    m1_den_1h = df['TARGET'].shift(1 + steps_1h)
    m6_den_6h = df['TARGET'].shift(1 + steps_6h)

    df['irr_momentum_1h'] = safe_div(m1_num, m1_den_1h) - 1.0
    df['irr_momentum_6h'] = safe_div(m1_num, m6_den_6h) - 1.0
    df['irr_momentum_1h'] = df['irr_momentum_1h'].clip(-3, 3)
    df['irr_momentum_6h'] = df['irr_momentum_6h'].clip(-3, 3)

    # Calendar features
    cal = make_calendar_features(df.index)
    
    # Meteorological features (already present in dataset)
    met_cols = ['T2M', 'RH2M', 'WS50M', 'PS', 'PRECTOTCORR', 'CLOUD_AMT', 'AOD_55', 'SZA']
    available_met_cols = [col for col in met_cols if col in df.columns]

    # Solar-specific engineered features
    solar_eng_cols = ['clear_sky_indicator']
    if 'effective_cloud' in df.columns:
        solar_eng_cols.append('effective_cloud')
    if 'temp_irr_interaction' in df.columns:
        solar_eng_cols.append('temp_irr_interaction')

    # Assemble feature blocks
    lag_cols = [f'TARGET_lag{L}' for L in season_lags if f'TARGET_lag{L}' in df.columns]
    roll_cols = ['irr_mean_1h', 'irr_std_1h', 'irr_mean_6h', 'irr_std_6h', 
                 'irr_max_24h', 'irr_mean_24h']
    mom_cols = ['irr_momentum_1h', 'irr_momentum_6h']

    feat_blocks = [cal]
    if available_met_cols:
        feat_blocks.append(df[available_met_cols])
    if lag_cols:
        feat_blocks.append(df[lag_cols])
    feat_blocks.append(df[solar_eng_cols])
    feat_blocks.append(df[roll_cols + mom_cols])

    X_exo = pd.concat(feat_blocks, axis=1)

    # ----------------------------
    # Finite-only sanitization BEFORE scaling
    # ----------------------------
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps (each sample's last target time) AFTER filtering
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # ----------------------------
    # SCALING (leak-free)
    # ----------------------------
    train_mask_for_scaler = df.index <= train_end
    if not train_mask_for_scaler.any():
        raise ValueError("No rows on/before train_end available to fit the scaler.")

    feat_scaler = MinMaxScaler()

    # Clean TRAIN slice for fit
    X_train = X_exo.loc[train_mask_for_scaler].copy()
    X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
    good_train_rows = np.isfinite(X_train.to_numpy()).all(axis=1)
    X_train = X_train.loc[good_train_rows]

    if X_train.empty:
        raise ValueError("No finite rows remain in training features after sanitization.")

    feat_scaler.fit(X_train.to_numpy())

    # Clean FULL for transform
    X_full = X_exo.copy()
    X_full.replace([np.inf, -np.inf], np.nan, inplace=True)
    if X_full.isna().any().any():
        X_full = X_full.bfill().ffill()

    keep_mask_full = np.isfinite(X_full.to_numpy()).all(axis=1)
    if not keep_mask_full.all():
        X_full = X_full.loc[keep_mask_full]
        df     = df.loc[X_full.index]
        times  = df.index[W + H - 1 :]

    X_feats_scaled = feat_scaler.transform(X_full.to_numpy())

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']].to_numpy())
    y_scaled = tgt_scaler.transform(df[['TARGET']].to_numpy())

    # Final data array: [features..., target_scaled] with target LAST
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # = F_feat + 1

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 9
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # LSTM model
    # ----------------------------
    model = LSTM_Forecaster(n_features=n_features, window=W, horizon=H,
        enc1=256, enc2=128, latent_dim=64, p_drop=0.2
        ).to(device)

    # (Optional) tighter BN momentum for long sequences
    for m in model.modules():
        if isinstance(m, nn.BatchNorm2d):
            m.momentum = 0.05

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for solar forecasting (emphasize daytime predictions)
    weights = torch.linspace(0.5, 1.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Solar Irradiance)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (tail-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, W/m²): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Solar Irradiance')
    plt.plot(times[test_idx], inv_p, label='Predicted Solar Irradiance', alpha=0.7)
    plt.title("24h-Ahead Solar Irradiance Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Solar Irradiance (W/m²)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Solar Irradiance')
            plt.plot(tgrid, pred_i, label='Predicted Solar Irradiance', alpha=0.8)
            plt.title(f"Full 24h Solar Irradiance Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Solar Irradiance (W/m²)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 5393, Validation windows: 10752, Test windows: 8352
# First window ts: 2023-07-10 11:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 567713
# Ep01 Train=0.1173 | Val=0.1256 | Val(last) RMSE=317.3 MAE=205.4 MAPE=168.91% R²=-0.185 | Val(full) RMSE=328.0 MAE=235.7 MAPE=161.51% | LR=0.000050 | Time=20.2s
# Ep02 Train=0.0858 | Val=0.0922 | Val(last) RMSE=237.2 MAE=175.4 MAPE=136.79% R²=0.338 | Val(full) RMSE=281.8 MAE=218.7 MAPE=143.30% | LR=0.000075 | Time=20.0s
# Ep03 Train=0.0629 | Val=0.0623 | Val(last) RMSE=152.4 MAE=102.1 MAPE=121.99% R²=0.727 | Val(full) RMSE=232.9 MAE=176.4 MAPE=133.67% | LR=0.000100 | Time=20.3s
# Ep04 Train=0.0425 | Val=0.0421 | Val(last) RMSE=115.1 MAE=81.5 MAPE=117.00% R²=0.844 | Val(full) RMSE=191.8 MAE=140.5 MAPE=127.40% | LR=0.000125 | Time=20.1s
# Ep05 Train=0.0305 | Val=0.0321 | Val(last) RMSE=105.9 MAE=70.7 MAPE=116.43% R²=0.868 | Val(full) RMSE=167.2 MAE=123.2 MAPE=123.88% | LR=0.000150 | Time=20.3s
# Ep06 Train=0.0240 | Val=0.0255 | Val(last) RMSE=90.2 MAE=61.3 MAPE=113.25% R²=0.904 | Val(full) RMSE=149.5 MAE=109.9 MAPE=121.24% | LR=0.000175 | Time=20.5s
# Ep07 Train=0.0195 | Val=0.0207 | Val(last) RMSE=80.2 MAE=52.8 MAPE=109.29% R²=0.924 | Val(full) RMSE=135.2 MAE=96.9 MAPE=118.96% | LR=0.000200 | Time=20.3s
# Ep08 Train=0.0160 | Val=0.0148 | Val(last) RMSE=66.5 MAE=45.5 MAPE=107.14% R²=0.948 | Val(full) RMSE=114.9 MAE=82.4 MAPE=116.31% | LR=0.000225 | Time=20.5s
# Ep09 Train=0.0126 | Val=0.0136 | Val(last) RMSE=72.5 MAE=51.0 MAPE=107.55% R²=0.938 | Val(full) RMSE=109.8 MAE=75.2 MAPE=114.60% | LR=0.000250 | Time=20.5s
# Ep10 Train=0.0103 | Val=0.0116 | Val(last) RMSE=72.2 MAE=45.7 MAPE=105.78% R²=0.939 | Val(full) RMSE=101.2 MAE=66.9 MAPE=112.48% | LR=0.000275 | Time=20.5s
# Ep11 Train=0.0090 | Val=0.0092 | Val(last) RMSE=70.1 MAE=42.7 MAPE=107.26% R²=0.942 | Val(full) RMSE=90.6 MAE=60.9 MAPE=111.50% | LR=0.000300 | Time=20.5s
# Ep12 Train=0.0083 | Val=0.0079 | Val(last) RMSE=65.6 MAE=39.3 MAPE=105.65% R²=0.949 | Val(full) RMSE=83.0 MAE=56.1 MAPE=110.42% | LR=0.000325 | Time=20.4s
# Ep13 Train=0.0077 | Val=0.0091 | Val(last) RMSE=73.5 MAE=46.4 MAPE=106.45% R²=0.936 | Val(full) RMSE=89.7 MAE=59.6 MAPE=111.01% | LR=0.000350 | Time=20.2s
# Ep14 Train=0.0070 | Val=0.0100 | Val(last) RMSE=74.0 MAE=45.8 MAPE=106.74% R²=0.935 | Val(full) RMSE=93.0 MAE=60.0 MAPE=110.96% | LR=0.000375 | Time=20.6s
# Ep15 Train=0.0074 | Val=0.0083 | Val(last) RMSE=66.4 MAE=41.5 MAPE=106.16% R²=0.948 | Val(full) RMSE=85.6 MAE=55.5 MAPE=109.98% | LR=0.000400 | Time=20.6s
# Ep16 Train=0.0066 | Val=0.0077 | Val(last) RMSE=67.9 MAE=40.3 MAPE=106.43% R²=0.946 | Val(full) RMSE=82.6 MAE=52.6 MAPE=109.20% | LR=0.000425 | Time=20.5s
# Ep17 Train=0.0061 | Val=0.0070 | Val(last) RMSE=64.3 MAE=37.7 MAPE=105.46% R²=0.951 | Val(full) RMSE=77.8 MAE=49.1 MAPE=108.75% | LR=0.000450 | Time=20.2s
# Ep18 Train=0.0061 | Val=0.0109 | Val(last) RMSE=77.1 MAE=45.8 MAPE=107.10% R²=0.930 | Val(full) RMSE=95.7 MAE=59.3 MAPE=111.41% | LR=0.000475 | Time=20.5s
# Ep19 Train=0.0056 | Val=0.0086 | Val(last) RMSE=73.1 MAE=44.2 MAPE=107.01% R²=0.937 | Val(full) RMSE=85.9 MAE=53.6 MAPE=110.01% | LR=0.000500 | Time=20.4s
# Ep20 Train=0.0056 | Val=0.0080 | Val(last) RMSE=72.7 MAE=41.3 MAPE=105.92% R²=0.938 | Val(full) RMSE=82.2 MAE=49.9 MAPE=109.28% | LR=0.000500 | Time=20.4s
# Ep21 Train=0.0054 | Val=0.0075 | Val(last) RMSE=73.4 MAE=42.2 MAPE=106.79% R²=0.937 | Val(full) RMSE=79.1 MAE=48.4 MAPE=108.53% | LR=0.000500 | Time=19.9s
# Ep22 Train=0.0051 | Val=0.0069 | Val(last) RMSE=57.9 MAE=33.6 MAPE=103.79% R²=0.961 | Val(full) RMSE=76.8 MAE=48.0 MAPE=108.60% | LR=0.000499 | Time=20.1s
# Ep23 Train=0.0049 | Val=0.0090 | Val(last) RMSE=72.9 MAE=42.5 MAPE=105.09% R²=0.937 | Val(full) RMSE=87.2 MAE=53.1 MAPE=109.47% | LR=0.000498 | Time=20.1s
# Ep24 Train=0.0050 | Val=0.0060 | Val(last) RMSE=59.5 MAE=34.0 MAPE=104.33% R²=0.958 | Val(full) RMSE=71.1 MAE=43.1 MAPE=107.23% | LR=0.000497 | Time=20.2s
# Ep25 Train=0.0048 | Val=0.0070 | Val(last) RMSE=69.6 MAE=40.8 MAPE=105.48% R²=0.943 | Val(full) RMSE=76.8 MAE=46.1 MAPE=107.73% | LR=0.000495 | Time=20.2s
# Ep26 Train=0.0047 | Val=0.0087 | Val(last) RMSE=77.3 MAE=43.9 MAPE=106.99% R²=0.930 | Val(full) RMSE=85.6 MAE=51.3 MAPE=109.72% | LR=0.000493 | Time=20.3s
# Ep27 Train=0.0047 | Val=0.0098 | Val(last) RMSE=84.1 MAE=48.8 MAPE=107.97% R²=0.917 | Val(full) RMSE=90.1 MAE=53.7 MAPE=110.05% | LR=0.000491 | Time=20.2s
# Ep28 Train=0.0045 | Val=0.0066 | Val(last) RMSE=64.3 MAE=37.3 MAPE=105.62% R²=0.951 | Val(full) RMSE=75.2 MAE=45.0 MAPE=108.07% | LR=0.000488 | Time=20.3s
# Ep29 Train=0.0044 | Val=0.0077 | Val(last) RMSE=66.2 MAE=38.8 MAPE=106.04% R²=0.948 | Val(full) RMSE=80.4 MAE=47.9 MAPE=108.67% | LR=0.000485 | Time=20.3s
# Ep30 Train=0.0043 | Val=0.0105 | Val(last) RMSE=86.8 MAE=51.9 MAPE=111.30% R²=0.911 | Val(full) RMSE=92.9 MAE=55.8 MAPE=111.41% | LR=0.000481 | Time=20.2s
# Ep31 Train=0.0043 | Val=0.0102 | Val(last) RMSE=81.6 MAE=47.1 MAPE=107.71% R²=0.922 | Val(full) RMSE=91.6 MAE=53.7 MAPE=110.43% | LR=0.000477 | Time=20.2s
# Ep32 Train=0.0047 | Val=0.0075 | Val(last) RMSE=71.8 MAE=43.0 MAPE=106.28% R²=0.939 | Val(full) RMSE=78.3 MAE=47.0 MAPE=108.20% | LR=0.000473 | Time=20.1s
# Ep33 Train=0.0041 | Val=0.0078 | Val(last) RMSE=72.3 MAE=42.3 MAPE=106.48% R²=0.938 | Val(full) RMSE=80.5 MAE=47.4 MAPE=108.70% | LR=0.000468 | Time=20.0s
# Ep34 Train=0.0039 | Val=0.0080 | Val(last) RMSE=68.4 MAE=39.8 MAPE=104.87% R²=0.945 | Val(full) RMSE=81.6 MAE=47.7 MAPE=108.36% | LR=0.000463 | Time=20.1s
# Ep35 Train=0.0039 | Val=0.0075 | Val(last) RMSE=70.2 MAE=42.4 MAPE=107.74% R²=0.942 | Val(full) RMSE=79.4 MAE=48.6 MAPE=109.16% | LR=0.000458 | Time=20.1s
# Ep36 Train=0.0040 | Val=0.0077 | Val(last) RMSE=76.0 MAE=44.4 MAPE=107.84% R²=0.932 | Val(full) RMSE=80.5 MAE=47.2 MAPE=108.46% | LR=0.000452 | Time=20.2s
# Ep37 Train=0.0040 | Val=0.0065 | Val(last) RMSE=65.9 MAE=38.1 MAPE=106.18% R²=0.949 | Val(full) RMSE=73.9 MAE=43.6 MAPE=107.49% | LR=0.000446 | Time=20.2s
# Ep38 Train=0.0039 | Val=0.0071 | Val(last) RMSE=71.5 MAE=43.5 MAPE=106.70% R²=0.940 | Val(full) RMSE=76.1 MAE=45.4 MAPE=107.68% | LR=0.000440 | Time=20.1s
# Ep39 Train=0.0039 | Val=0.0067 | Val(last) RMSE=70.4 MAE=40.5 MAPE=106.29% R²=0.942 | Val(full) RMSE=74.6 MAE=43.8 MAPE=107.41% | LR=0.000434 | Time=20.2s
# Ep40 Train=0.0037 | Val=0.0073 | Val(last) RMSE=71.7 MAE=42.2 MAPE=105.49% R²=0.940 | Val(full) RMSE=78.5 MAE=46.1 MAPE=108.04% | LR=0.000427 | Time=20.2s
# Ep41 Train=0.0039 | Val=0.0109 | Val(last) RMSE=83.2 MAE=48.8 MAPE=107.70% R²=0.919 | Val(full) RMSE=95.1 MAE=56.0 MAPE=111.10% | LR=0.000420 | Time=20.1s
# Ep42 Train=0.0038 | Val=0.0070 | Val(last) RMSE=65.5 MAE=38.4 MAPE=105.54% R²=0.950 | Val(full) RMSE=76.3 MAE=44.6 MAPE=107.63% | LR=0.000412 | Time=20.2s
# Ep43 Train=0.0037 | Val=0.0085 | Val(last) RMSE=72.9 MAE=43.7 MAPE=106.69% R²=0.937 | Val(full) RMSE=83.4 MAE=49.0 MAPE=109.31% | LR=0.000405 | Time=20.1s
# Ep44 Train=0.0037 | Val=0.0073 | Val(last) RMSE=75.8 MAE=45.0 MAPE=106.90% R²=0.932 | Val(full) RMSE=77.1 MAE=45.6 MAPE=107.88% | LR=0.000397 | Time=20.1s
# Ep45 Train=0.0036 | Val=0.0075 | Val(last) RMSE=75.3 MAE=44.0 MAPE=107.67% R²=0.933 | Val(full) RMSE=78.5 MAE=45.6 MAPE=108.07% | LR=0.000389 | Time=20.1s
# Ep46 Train=0.0035 | Val=0.0094 | Val(last) RMSE=82.5 MAE=49.0 MAPE=107.36% R²=0.920 | Val(full) RMSE=87.4 MAE=51.2 MAPE=109.60% | LR=0.000381 | Time=20.1s
# Ep47 Train=0.0035 | Val=0.0075 | Val(last) RMSE=75.5 MAE=44.8 MAPE=108.24% R²=0.933 | Val(full) RMSE=78.2 MAE=45.9 MAPE=108.24% | LR=0.000372 | Time=20.1s
# Ep48 Train=0.0037 | Val=0.0075 | Val(last) RMSE=74.4 MAE=43.7 MAPE=107.34% R²=0.935 | Val(full) RMSE=78.8 MAE=46.2 MAPE=108.11% | LR=0.000363 | Time=20.1s
# Ep49 Train=0.0035 | Val=0.0086 | Val(last) RMSE=84.2 MAE=50.1 MAPE=109.45% R²=0.917 | Val(full) RMSE=83.2 MAE=49.1 MAPE=109.03% | LR=0.000355 | Time=20.1s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (tail-weighted MSE): 0.0019
#
# Final Test Metrics (last step, W/m²): MSE=603.70, RMSE=24.57, MAE=19.26, R²=0.9887, Adj R²=0.9886
# Final Test Metrics (full 24h path): RMSE=41.17, MAE=26.94
# Hourly-averaged RMSE by lead hour (0→23):
# [24.58, 32.63, 40.27, 47.04, 48.04, 47.58, 46.21, 44.58, 42.65, 42.29,
#  44.2 , 45.57, 50.27, 53.86, 53.94, 53.91, 49.2 , 41.78, 32.69, 26.44,
#  21.1 , 18.67, 18.38, 21.45]
# Avg inference latency: 17.29 ms/batch • 17.29 ms/sample

# %% [markdown]
# ### Transformer

# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model: Transformer forecaster
# ----------------------------
class PositionalEncoding(nn.Module):
    """Standard sinusoidal PE (batch_first: [B, T, D])."""
    def __init__(self, d_model: int, max_len: int = 10000, dropout: float = 0.0):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        pe = torch.zeros(max_len, d_model)  # [T, D]
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)  # [T, 1]
        div_term = torch.exp(torch.arange(0, d_model, 2, dtype=torch.float32) * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # even
        pe[:, 1::2] = torch.cos(position * div_term)  # odd
        pe = pe.unsqueeze(0)  # [1, T, D]
        self.register_buffer('pe', pe, persistent=False)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: [B, T, D]
        T = x.size(1)
        x = x + self.pe[:, :T, :]
        return self.dropout(x)

class TransformerForecaster(nn.Module):
    """
    Encoder-only Transformer:
      - Input: [B, W, F]
      - Linear embed: F -> d_model
      - Add positional encodings
      - TransformerEncoder (batch_first)
      - Temporal mean pool -> [B, d_model]
      - Concatenate with raw last-step features [B, F]
      - MLP head -> horizon
      - Output: [B, H, 1]
    """
    def __init__(
        self,
        n_features: int,
        window: int,
        horizon: int,
        d_model: int = 128,
        nhead: int = 8,
        num_layers: int = 4,
        dim_feedforward: int = 256,
        p_drop: float = 0.1
    ):
        super().__init__()
        assert d_model % nhead == 0, "d_model must be divisible by nhead"
        self.n_features = n_features
        self.window = window
        self.horizon = horizon
        self.d_model = d_model

        self.input_proj = nn.Linear(n_features, d_model)
        self.pos_enc = PositionalEncoding(d_model=d_model, max_len=window, dropout=p_drop)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=p_drop,
            batch_first=True,
            activation='gelu',
            norm_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.enc_ln = nn.LayerNorm(d_model)

        # Head after pooling + concat(last-step raw features)
        concat_dim = d_model + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, 2 * d_model),
            nn.GELU(),
            nn.Dropout(p_drop),
            nn.Linear(2 * d_model, horizon)
        )

        # Initialize
        self._reset_parameters()

    def _reset_parameters(self):
        nn.init.xavier_uniform_(self.input_proj.weight)
        nn.init.zeros_(self.input_proj.bias)
        for m in self.head:
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: [B, W, F]
        B, W, F = x.shape
        h = self.input_proj(x)            # [B, W, D]
        h = self.pos_enc(h)               # [B, W, D]
        h = self.encoder(h)               # [B, W, D]
        h = self.enc_ln(h)

        # Temporal mean pooling
        h_pool = h.mean(dim=1)            # [B, D]

        # Skip: last-step raw features
        x_last = x[:, -1, :]              # [B, F]
        z = torch.cat([h_pool, x_last], dim=1)  # [B, D+F]

        yhat = self.head(z)               # [B, H]
        return yhat.unsqueeze(-1)         # [B, H, 1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load solar irradiance dataset
    df = pd.read_csv('NASA-DATASET/solar_forecasting.csv', parse_dates=['DATETIME'], index_col='DATETIME').fillna(0)
    df.index = pd.to_datetime(df.index, format='mixed', errors='raise')
    
    # Rename target variable for consistency with original code structure
    target_col = 'ALLSKY_SFC_SW_DWN'  # Solar irradiance target
    df['TARGET'] = df[target_col]
    
    # Handle missing values
    df['TARGET'] = df['TARGET'].interpolate(method='time')
    df['TARGET'] = df['TARGET'].bfill().ffill()

    # Cadence sanity check
    _ = infer_5min_freq(df.index)

    # Window sizes for solar forecasting
    W = 7 * 24 * 12   # one week lookback (7 days) - 5 minute resolution  
    H = 1 * 24 * 12   # 24h horizon - 5 minute resolution

    # ----------------------------
    # Feature engineering (LEAK-FREE) - adapted for solar data
    # ----------------------------
    steps_per_hour = 12
    steps_1h  = 1  * steps_per_hour       # 12
    steps_6h  = 6  * steps_per_hour       # 72
    steps_24h = 24 * steps_per_hour       # 288

    # Seasonal lags for solar patterns (daily and yearly cycles)
    season_lags = [52560]
    for L in season_lags:
        if L < len(df):
            df[f'TARGET_lag{L}'] = df['TARGET'].shift(L)

    # Solar-specific features: Clear sky detection and variability
    # Clear sky indicator: low variability in recent irradiance
    win_2h = 2 * 12  # 2 hours
    irr_rolling_std = df['TARGET'].rolling(win_2h, min_periods=win_2h//2).std()
    df['clear_sky_indicator'] = (irr_rolling_std < irr_rolling_std.quantile(0.3)).astype(int).shift(1).fillna(0)

    # Solar angle and cloud interaction (past-only)
    if 'SZA' in df.columns and 'CLOUD_AMT' in df.columns:
        # Effective cloudiness considering sun angle
        df['effective_cloud'] = (df['CLOUD_AMT'] * np.cos(np.radians(df['SZA'].clip(0, 90)))).shift(1).fillna(0)
        
    # Temperature-irradiance interaction (past-only)
    if 'T2M' in df.columns:
        df['temp_irr_interaction'] = (df['T2M'] * df['TARGET']).shift(1).fillna(0)

    # Rolling statistics on lagged target (past-only)
    target_shifted = df['TARGET'].shift(1)
    df['irr_mean_1h']  = target_shifted.rolling(steps_1h,  min_periods=steps_1h//2).mean()
    df['irr_std_1h']   = target_shifted.rolling(steps_1h,  min_periods=steps_1h//2).std()
    df['irr_mean_6h']  = target_shifted.rolling(steps_6h,  min_periods=steps_6h//2).mean()
    df['irr_std_6h']   = target_shifted.rolling(steps_6h,  min_periods=steps_6h//2).std()
    df['irr_max_24h']  = target_shifted.rolling(steps_24h, min_periods=steps_24h//2).max()
    df['irr_mean_24h'] = target_shifted.rolling(steps_24h, min_periods=steps_24h//2).mean()

    # Solar momentum (change rates) - past-only
    def safe_div(num, den, eps=1e-6):
        den = den.copy()
        den = den.where(den.abs() > eps, eps)
        return num / den

    m1_num = df['TARGET'].shift(1)
    m1_den_1h = df['TARGET'].shift(1 + steps_1h)
    m6_den_6h = df['TARGET'].shift(1 + steps_6h)

    df['irr_momentum_1h'] = safe_div(m1_num, m1_den_1h) - 1.0
    df['irr_momentum_6h'] = safe_div(m1_num, m6_den_6h) - 1.0
    df['irr_momentum_1h'] = df['irr_momentum_1h'].clip(-3, 3)
    df['irr_momentum_6h'] = df['irr_momentum_6h'].clip(-3, 3)

    # Calendar features
    cal = make_calendar_features(df.index)
    
    # Meteorological features (already present in dataset)
    met_cols = ['T2M', 'RH2M', 'WS50M', 'PS', 'PRECTOTCORR', 'CLOUD_AMT', 'AOD_55', 'SZA']
    available_met_cols = [col for col in met_cols if col in df.columns]

    # Solar-specific engineered features
    solar_eng_cols = ['clear_sky_indicator']
    if 'effective_cloud' in df.columns:
        solar_eng_cols.append('effective_cloud')
    if 'temp_irr_interaction' in df.columns:
        solar_eng_cols.append('temp_irr_interaction')

    # Assemble feature blocks
    lag_cols = [f'TARGET_lag{L}' for L in season_lags if f'TARGET_lag{L}' in df.columns]
    roll_cols = ['irr_mean_1h', 'irr_std_1h', 'irr_mean_6h', 'irr_std_6h', 
                 'irr_max_24h', 'irr_mean_24h']
    mom_cols = ['irr_momentum_1h', 'irr_momentum_6h']

    feat_blocks = [cal]
    if available_met_cols:
        feat_blocks.append(df[available_met_cols])
    if lag_cols:
        feat_blocks.append(df[lag_cols])
    feat_blocks.append(df[solar_eng_cols])
    feat_blocks.append(df[roll_cols + mom_cols])

    X_exo = pd.concat(feat_blocks, axis=1)

    # ----------------------------
    # Finite-only sanitization BEFORE scaling
    # ----------------------------
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps (each sample's last target time) AFTER filtering
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # ----------------------------
    # SCALING (leak-free)
    # ----------------------------
    train_mask_for_scaler = df.index <= train_end
    if not train_mask_for_scaler.any():
        raise ValueError("No rows on/before train_end available to fit the scaler.")

    feat_scaler = MinMaxScaler()

    # Clean TRAIN slice for fit
    X_train = X_exo.loc[train_mask_for_scaler].copy()
    X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
    good_train_rows = np.isfinite(X_train.to_numpy()).all(axis=1)
    X_train = X_train.loc[good_train_rows]

    if X_train.empty:
        raise ValueError("No finite rows remain in training features after sanitization.")

    feat_scaler.fit(X_train.to_numpy())

    # Clean FULL for transform
    X_full = X_exo.copy()
    X_full.replace([np.inf, -np.inf], np.nan, inplace=True)
    if X_full.isna().any().any():
        X_full = X_full.bfill().ffill()

    keep_mask_full = np.isfinite(X_full.to_numpy()).all(axis=1)
    if not keep_mask_full.all():
        X_full = X_full.loc[keep_mask_full]
        df     = df.loc[X_full.index]
        times  = df.index[W + H - 1 :]

    X_feats_scaled = feat_scaler.transform(X_full.to_numpy())

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']].to_numpy())
    y_scaled = tgt_scaler.transform(df[['TARGET']].to_numpy())

    # Final data array: [features..., target_scaled] with target LAST
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # = F_feat + 1

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 9
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Transformer model + optimizer + loss + scheduler
    # ----------------------------
    model = TransformerForecaster(
        n_features=n_features, window=W, horizon=H,
        d_model=128, nhead=8, num_layers=4, dim_feedforward=256, p_drop=0.1
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for solar forecasting (emphasize daytime predictions)
    weights = torch.linspace(0.5, 1.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Solar Irradiance)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (tail-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, W/m²): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Solar Irradiance')
    plt.plot(times[test_idx], inv_p, label='Predicted Solar Irradiance', alpha=0.7)
    plt.title("24h-Ahead Solar Irradiance Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Solar Irradiance (W/m²)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Solar Irradiance')
            plt.plot(tgrid, pred_i, label='Predicted Solar Irradiance', alpha=0.8)
            plt.title(f"Full 24h Solar Irradiance Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Solar Irradiance (W/m²)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 5393, Validation windows: 10752, Test windows: 8352
# First window ts: 2023-07-10 11:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 647712
# /home/MAIN_USER/Desktop/Classical-Forecasting/venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# Ep01 Train=0.1212 | Val=0.1199 | Val(last) RMSE=356.1 MAE=256.1 MAPE=165.02% R²=-0.493 | Val(full) RMSE=319.8 MAE=243.8 MAPE=153.90% | LR=0.000050 | Time=180.1s
# Ep02 Train=0.0790 | Val=0.0892 | Val(last) RMSE=297.1 MAE=222.1 MAPE=148.26% R²=-0.039 | Val(full) RMSE=276.1 MAE=221.5 MAPE=140.53% | LR=0.000075 | Time=179.3s
# Ep03 Train=0.0472 | Val=0.0317 | Val(last) RMSE=147.8 MAE=114.3 MAPE=117.33% R²=0.743 | Val(full) RMSE=167.9 MAE=130.4 MAPE=122.48% | LR=0.000100 | Time=179.0s
# Ep04 Train=0.0220 | Val=0.0192 | Val(last) RMSE=127.7 MAE=102.8 MAPE=117.09% R²=0.808 | Val(full) RMSE=131.4 MAE=98.4 MAPE=117.23% | LR=0.000125 | Time=179.1s
# Ep05 Train=0.0142 | Val=0.0123 | Val(last) RMSE=106.3 MAE=83.2 MAPE=115.48% R²=0.867 | Val(full) RMSE=104.7 MAE=76.2 MAPE=114.61% | LR=0.000150 | Time=178.5s
# Ep06 Train=0.0107 | Val=0.0111 | Val(last) RMSE=122.0 MAE=98.5 MAPE=120.18% R²=0.825 | Val(full) RMSE=97.1 MAE=72.3 MAPE=114.54% | LR=0.000175 | Time=178.9s
# Ep07 Train=0.0095 | Val=0.0103 | Val(last) RMSE=107.4 MAE=80.8 MAPE=115.99% R²=0.864 | Val(full) RMSE=93.2 MAE=65.9 MAPE=113.43% | LR=0.000200 | Time=178.7s
# Ep08 Train=0.0086 | Val=0.0094 | Val(last) RMSE=101.7 MAE=79.0 MAPE=114.98% R²=0.878 | Val(full) RMSE=89.0 MAE=64.1 MAPE=113.71% | LR=0.000225 | Time=178.5s
# Ep09 Train=0.0080 | Val=0.0088 | Val(last) RMSE=95.5 MAE=75.7 MAPE=115.29% R²=0.893 | Val(full) RMSE=85.7 MAE=62.5 MAPE=113.62% | LR=0.000250 | Time=178.5s
# Ep10 Train=0.0073 | Val=0.0090 | Val(last) RMSE=90.9 MAE=71.3 MAPE=113.25% R²=0.903 | Val(full) RMSE=86.7 MAE=61.9 MAPE=113.02% | LR=0.000275 | Time=178.3s
# Ep11 Train=0.0071 | Val=0.0086 | Val(last) RMSE=103.2 MAE=79.9 MAPE=117.46% R²=0.875 | Val(full) RMSE=84.8 MAE=61.3 MAPE=113.50% | LR=0.000300 | Time=179.3s
# Ep12 Train=0.0067 | Val=0.0084 | Val(last) RMSE=77.3 MAE=55.2 MAPE=109.62% R²=0.930 | Val(full) RMSE=84.6 MAE=62.8 MAPE=114.63% | LR=0.000325 | Time=178.8s
# Ep13 Train=0.0064 | Val=0.0099 | Val(last) RMSE=87.3 MAE=63.1 MAPE=114.00% R²=0.910 | Val(full) RMSE=88.1 MAE=60.4 MAPE=114.66% | LR=0.000350 | Time=178.8s
# Ep14 Train=0.0063 | Val=0.0085 | Val(last) RMSE=104.9 MAE=77.9 MAPE=120.99% R²=0.871 | Val(full) RMSE=84.1 MAE=59.4 MAPE=114.22% | LR=0.000375 | Time=178.8s
# Ep15 Train=0.0061 | Val=0.0115 | Val(last) RMSE=87.3 MAE=55.9 MAPE=110.52% R²=0.910 | Val(full) RMSE=98.1 MAE=64.7 MAPE=116.45% | LR=0.000400 | Time=179.0s
# Ep16 Train=0.0058 | Val=0.0096 | Val(last) RMSE=81.4 MAE=60.1 MAPE=111.04% R²=0.922 | Val(full) RMSE=87.8 MAE=63.1 MAPE=112.44% | LR=0.000425 | Time=178.9s
# Ep17 Train=0.0059 | Val=0.0091 | Val(last) RMSE=85.5 MAE=56.5 MAPE=113.07% R²=0.914 | Val(full) RMSE=87.1 MAE=58.3 MAPE=114.75% | LR=0.000450 | Time=178.0s
# Ep18 Train=0.0054 | Val=0.0096 | Val(last) RMSE=95.1 MAE=64.1 MAPE=116.26% R²=0.894 | Val(full) RMSE=87.5 MAE=60.3 MAPE=113.83% | LR=0.000475 | Time=178.5s
# Ep19 Train=0.0055 | Val=0.0095 | Val(last) RMSE=86.4 MAE=48.7 MAPE=109.85% R²=0.912 | Val(full) RMSE=87.0 MAE=57.6 MAPE=113.28% | LR=0.000500 | Time=178.0s
# Ep20 Train=0.0052 | Val=0.0115 | Val(last) RMSE=102.8 MAE=66.6 MAPE=119.80% R²=0.876 | Val(full) RMSE=96.3 MAE=60.9 MAPE=115.77% | LR=0.000500 | Time=178.5s
# Ep21 Train=0.0049 | Val=0.0089 | Val(last) RMSE=86.3 MAE=53.0 MAPE=115.57% R²=0.912 | Val(full) RMSE=84.4 MAE=53.2 MAPE=112.10% | LR=0.000500 | Time=178.6s
# Ep22 Train=0.0046 | Val=0.0123 | Val(last) RMSE=107.3 MAE=68.8 MAPE=118.42% R²=0.864 | Val(full) RMSE=97.9 MAE=59.0 MAPE=113.86% | LR=0.000499 | Time=177.8s
# Ep23 Train=0.0043 | Val=0.0130 | Val(last) RMSE=123.8 MAE=88.7 MAPE=126.71% R²=0.820 | Val(full) RMSE=101.7 MAE=64.0 MAPE=116.83% | LR=0.000498 | Time=177.7s
# Ep24 Train=0.0039 | Val=0.0123 | Val(last) RMSE=100.7 MAE=56.8 MAPE=112.78% R²=0.881 | Val(full) RMSE=100.1 MAE=59.4 MAPE=113.69% | LR=0.000497 | Time=177.5s
# Ep25 Train=0.0038 | Val=0.0133 | Val(last) RMSE=119.9 MAE=73.4 MAPE=121.43% R²=0.831 | Val(full) RMSE=102.9 MAE=61.8 MAPE=114.48% | LR=0.000495 | Time=178.5s
# Ep26 Train=0.0034 | Val=0.0166 | Val(last) RMSE=128.4 MAE=79.6 MAPE=122.43% R²=0.806 | Val(full) RMSE=115.1 MAE=69.4 MAPE=117.25% | LR=0.000493 | Time=179.3s
# Ep27 Train=0.0031 | Val=0.0190 | Val(last) RMSE=143.0 MAE=79.4 MAPE=120.72% R²=0.759 | Val(full) RMSE=121.2 MAE=71.5 MAPE=118.23% | LR=0.000491 | Time=178.8s
# Ep28 Train=0.0027 | Val=0.0193 | Val(last) RMSE=131.6 MAE=72.0 MAPE=117.37% R²=0.796 | Val(full) RMSE=123.9 MAE=71.1 MAPE=118.01% | LR=0.000488 | Time=177.8s
# Ep29 Train=0.0025 | Val=0.0221 | Val(last) RMSE=155.8 MAE=87.1 MAPE=125.47% R²=0.714 | Val(full) RMSE=133.1 MAE=77.3 MAPE=119.06% | LR=0.000485 | Time=178.2s
# Ep30 Train=0.0024 | Val=0.0170 | Val(last) RMSE=142.0 MAE=76.1 MAPE=120.69% R²=0.763 | Val(full) RMSE=115.2 MAE=66.1 MAPE=114.88% | LR=0.000481 | Time=178.4s
# Ep31 Train=0.0021 | Val=0.0197 | Val(last) RMSE=142.5 MAE=78.8 MAPE=122.30% R²=0.761 | Val(full) RMSE=125.1 MAE=71.2 MAPE=116.85% | LR=0.000477 | Time=177.5s
# Ep32 Train=0.0018 | Val=0.0263 | Val(last) RMSE=171.8 MAE=93.4 MAPE=127.26% R²=0.653 | Val(full) RMSE=146.2 MAE=81.3 MAPE=120.80% | LR=0.000473 | Time=177.4s
# Ep33 Train=0.0018 | Val=0.0244 | Val(last) RMSE=176.0 MAE=95.8 MAPE=129.20% R²=0.636 | Val(full) RMSE=138.9 MAE=78.6 MAPE=121.00% | LR=0.000468 | Time=177.6s
# Ep34 Train=0.0016 | Val=0.0254 | Val(last) RMSE=173.7 MAE=94.3 MAPE=127.49% R²=0.645 | Val(full) RMSE=140.8 MAE=78.5 MAPE=119.78% | LR=0.000463 | Time=178.4s
# Ep35 Train=0.0015 | Val=0.0263 | Val(last) RMSE=180.9 MAE=99.6 MAPE=130.76% R²=0.615 | Val(full) RMSE=144.7 MAE=82.3 MAPE=122.43% | LR=0.000458 | Time=177.9s
# Ep36 Train=0.0014 | Val=0.0225 | Val(last) RMSE=162.8 MAE=88.9 MAPE=123.56% R²=0.688 | Val(full) RMSE=134.2 MAE=74.1 MAPE=118.15% | LR=0.000452 | Time=177.6s
# Ep37 Train=0.0014 | Val=0.0261 | Val(last) RMSE=173.5 MAE=96.6 MAPE=129.06% R²=0.646 | Val(full) RMSE=145.9 MAE=82.2 MAPE=122.81% | LR=0.000446 | Time=177.3s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (tail-weighted MSE): 0.0039
#
# Final Test Metrics (last step, W/m²): MSE=1636.44, RMSE=40.45, MAE=33.21, R²=0.9693, Adj R²=0.9692
# Final Test Metrics (full 24h path): RMSE=58.82, MAE=48.50
# Hourly-averaged RMSE by lead hour (0→23):
# [45.68, 55.36, 60.88, 66.18, 63.43, 68.64, 63.53, 59.36, 68.26, 58.32,
#  61.68, 59.39, 58.82, 58.9 , 58.69, 54.61, 56.22, 61.56, 64.46, 63.84,
#  55.24, 45.92, 35.17, 36.72]
# Avg inference latency: 5.83 ms/batch • 5.83 ms/sample
