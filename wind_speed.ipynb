# %% [markdown]
# ## Wind Speed

# %% [markdown]
# ### 1DCNN

# %%
# T2M, QV2M, and Air Density
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).fillna(0)

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        r2_all  = r2_score(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% R²={r2_all:.3f} | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    mape = smape(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)
    mape_all = smape(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, MAPE={mape:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}, MAPE={mape_all:.2f}, R²={r2_all:.4f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 174913, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-02 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 8300640
# Ep01 Train=0.0103 | Val=0.0030 | Val(last) RMSE=1.5 MAE=1.2 MAPE=27.96% R²=0.435 | Val(full) RMSE=1.4 MAE=1.1 MAPE=26.44% R²=0.526 | LR=0.000050 | Time=39.2s
# Ep02 Train=0.0032 | Val=0.0024 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.73% R²=0.456 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.84% R²=0.614 | LR=0.000075 | Time=36.8s
# Ep03 Train=0.0028 | Val=0.0025 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.22% R²=0.436 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.00% R²=0.607 | LR=0.000100 | Time=38.2s
# Ep04 Train=0.0028 | Val=0.0026 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.63% R²=0.433 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.81% R²=0.583 | LR=0.000125 | Time=36.9s
# Ep05 Train=0.0027 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.84% R²=0.446 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.58% R²=0.621 | LR=0.000150 | Time=39.0s
# Ep06 Train=0.0027 | Val=0.0025 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.62% R²=0.430 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.35% R²=0.602 | LR=0.000175 | Time=38.3s
# Ep07 Train=0.0027 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.79% R²=0.462 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.52% R²=0.628 | LR=0.000200 | Time=37.6s
# Ep08 Train=0.0027 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.46% R²=0.462 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.96% R²=0.640 | LR=0.000225 | Time=38.0s
# Ep09 Train=0.0027 | Val=0.0024 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.32% R²=0.441 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.96% R²=0.609 | LR=0.000250 | Time=36.3s
# Ep10 Train=0.0027 | Val=0.0028 | Val(last) RMSE=1.6 MAE=1.2 MAPE=29.53% R²=0.387 | Val(full) RMSE=1.3 MAE=1.0 MAPE=25.10% R²=0.562 | LR=0.000275 | Time=36.1s
# Ep11 Train=0.0027 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.36% R²=0.437 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.45% R²=0.626 | LR=0.000300 | Time=35.3s
# Ep12 Train=0.0027 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.35% R²=0.472 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.31% R²=0.634 | LR=0.000325 | Time=36.6s
# Ep13 Train=0.0027 | Val=0.0027 | Val(last) RMSE=1.6 MAE=1.2 MAPE=29.24% R²=0.402 | Val(full) RMSE=1.3 MAE=1.0 MAPE=25.36% R²=0.565 | LR=0.000350 | Time=36.7s
# Ep14 Train=0.0026 | Val=0.0027 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.55% R²=0.430 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.96% R²=0.570 | LR=0.000375 | Time=36.0s
# Ep15 Train=0.0026 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.43% R²=0.471 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.65% R²=0.647 | LR=0.000400 | Time=33.4s
# Ep16 Train=0.0026 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.18% R²=0.480 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.14% R²=0.640 | LR=0.000425 | Time=35.0s
# Ep17 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.07% R²=0.443 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.38% R²=0.626 | LR=0.000450 | Time=33.7s
# Ep18 Train=0.0025 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.67% R²=0.456 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.09% R²=0.633 | LR=0.000475 | Time=37.2s
# Ep19 Train=0.0024 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.07% R²=0.476 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.50% R²=0.670 | LR=0.000500 | Time=38.9s
# Ep20 Train=0.0022 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.08% R²=0.482 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.44% R²=0.672 | LR=0.000500 | Time=32.0s
# Ep21 Train=0.0021 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.78% R²=0.480 | Val(full) RMSE=1.2 MAE=0.8 MAPE=21.09% R²=0.675 | LR=0.000500 | Time=33.7s
# Ep22 Train=0.0020 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.93% R²=0.475 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.45% R²=0.668 | LR=0.000499 | Time=34.6s
# Ep23 Train=0.0019 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.81% R²=0.460 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.50% R²=0.662 | LR=0.000498 | Time=35.6s
# Ep24 Train=0.0019 | Val=0.0018 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.56% R²=0.486 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.64% R²=0.687 | LR=0.000497 | Time=32.1s
# Ep25 Train=0.0019 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.44% R²=0.503 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.56% R²=0.672 | LR=0.000495 | Time=33.6s
# Ep26 Train=0.0019 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.90% R²=0.472 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.34% R²=0.663 | LR=0.000493 | Time=33.3s
# Ep27 Train=0.0018 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.53% R²=0.498 | Val(full) RMSE=1.2 MAE=0.8 MAPE=21.00% R²=0.676 | LR=0.000491 | Time=32.9s
# Ep28 Train=0.0018 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.13% R²=0.503 | Val(full) RMSE=1.1 MAE=0.8 MAPE=21.14% R²=0.679 | LR=0.000488 | Time=33.6s
# Ep29 Train=0.0018 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.16% R²=0.508 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.60% R²=0.692 | LR=0.000485 | Time=34.3s
# Ep30 Train=0.0018 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.88% R²=0.485 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.71% R²=0.686 | LR=0.000481 | Time=33.7s
# Ep31 Train=0.0018 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=25.88% R²=0.510 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.24% R²=0.695 | LR=0.000477 | Time=32.7s
# Ep32 Train=0.0017 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.27% R²=0.497 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.65% R²=0.687 | LR=0.000473 | Time=33.2s
# Ep33 Train=0.0017 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.58% R²=0.490 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.81% R²=0.687 | LR=0.000468 | Time=33.0s
# Ep34 Train=0.0017 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=25.94% R²=0.511 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.50% R²=0.692 | LR=0.000463 | Time=32.2s
# Ep35 Train=0.0017 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.38% R²=0.489 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.68% R²=0.679 | LR=0.000458 | Time=33.6s
# Ep36 Train=0.0017 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.31% R²=0.496 | Val(full) RMSE=1.1 MAE=0.8 MAPE=21.12% R²=0.685 | LR=0.000452 | Time=34.0s
# Ep37 Train=0.0017 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.61% R²=0.488 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.67% R²=0.677 | LR=0.000446 | Time=38.3s
# Ep38 Train=0.0017 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.14% R²=0.508 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.77% R²=0.686 | LR=0.000440 | Time=34.8s
# Ep39 Train=0.0017 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.69% R²=0.483 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.88% R²=0.675 | LR=0.000434 | Time=35.3s
# Ep40 Train=0.0017 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.31% R²=0.505 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.41% R²=0.693 | LR=0.000427 | Time=34.8s
# Ep41 Train=0.0017 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.28% R²=0.499 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.42% R²=0.690 | LR=0.000420 | Time=33.4s
# Ep42 Train=0.0016 | Val=0.0018 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.67% R²=0.483 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.50% R²=0.687 | LR=0.000412 | Time=35.0s
# Ep43 Train=0.0016 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.39% R²=0.507 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.67% R²=0.689 | LR=0.000405 | Time=36.0s
# Ep44 Train=0.0016 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.78% R²=0.488 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.97% R²=0.664 | LR=0.000397 | Time=33.0s
# Ep45 Train=0.0016 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.24% R²=0.505 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.16% R²=0.700 | LR=0.000389 | Time=36.0s
# Ep46 Train=0.0016 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.41% R²=0.469 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.08% R²=0.673 | LR=0.000381 | Time=34.7s
# Ep47 Train=0.0016 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.56% R²=0.497 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.54% R²=0.695 | LR=0.000372 | Time=34.2s
# Ep48 Train=0.0016 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.75% R²=0.490 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.69% R²=0.686 | LR=0.000363 | Time=33.0s
# Ep49 Train=0.0016 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.29% R²=0.502 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.49% R²=0.690 | LR=0.000355 | Time=34.9s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (front-weighted MSE): 0.0011
#
# Final Test Metrics (last step, m/s): MSE=1.37, RMSE=1.17, MAE=0.92, MAPE=15.59, R²=0.2662, Adj R²=0.2656
# Final Test Metrics (full 24h path): RMSE=0.89, MAE=0.68, MAPE=11.54, R²=0.6900
# Hourly-averaged RMSE by lead hour (0→23):
# [0.31, 0.33, 0.42, 0.52, 0.62, 0.71, 0.77, 0.82, 0.86, 0.88, 0.89, 0.89,
#  0.9 , 0.93, 0.95, 0.98, 1.  , 1.02, 1.05, 1.08, 1.11, 1.13, 1.14, 1.16]
# Avg inference latency: 0.45 ms/batch • 0.45 ms/sample

# %%
# Marked the days that experienced spikes during typhoons manaually
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final_withTyphoon.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).fillna(0)

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        r2_all  = r2_score(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% R²={r2_all:.3f} | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    mape = smape(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)
    mape_all = smape(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, MAPE={mape:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}, MAPE={mape_all:.2f}, R²={r2_all:.4f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 174913, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-02 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 8303456
# Ep01 Train=0.0104 | Val=0.0033 | Val(last) RMSE=1.6 MAE=1.2 MAPE=29.39% R²=0.377 | Val(full) RMSE=1.5 MAE=1.1 MAPE=27.64% R²=0.477 | LR=0.000050 | Time=38.1s
# Ep02 Train=0.0031 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.34% R²=0.459 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.03% R²=0.634 | LR=0.000075 | Time=35.2s
# Ep03 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.68% R²=0.468 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.57% R²=0.624 | LR=0.000100 | Time=32.8s
# Ep04 Train=0.0026 | Val=0.0024 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.00% R²=0.447 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.78% R²=0.614 | LR=0.000125 | Time=32.3s
# Ep05 Train=0.0026 | Val=0.0025 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.66% R²=0.416 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.82% R²=0.606 | LR=0.000150 | Time=35.4s
# Ep06 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.72% R²=0.453 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.31% R²=0.622 | LR=0.000175 | Time=37.3s
# Ep07 Train=0.0026 | Val=0.0025 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.83% R²=0.414 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.27% R²=0.592 | LR=0.000200 | Time=39.3s
# Ep08 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.49% R²=0.470 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.37% R²=0.627 | LR=0.000225 | Time=34.2s
# Ep09 Train=0.0026 | Val=0.0024 | Val(last) RMSE=1.5 MAE=1.2 MAPE=27.92% R²=0.449 | Val(full) RMSE=1.3 MAE=0.9 MAPE=23.53% R²=0.616 | LR=0.000250 | Time=34.6s
# Ep10 Train=0.0026 | Val=0.0026 | Val(last) RMSE=1.6 MAE=1.3 MAPE=29.44% R²=0.336 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.25% R²=0.575 | LR=0.000275 | Time=34.9s
# Ep11 Train=0.0025 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.25% R²=0.476 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.17% R²=0.635 | LR=0.000300 | Time=33.4s
# Ep12 Train=0.0025 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.53% R²=0.463 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.89% R²=0.639 | LR=0.000325 | Time=33.6s
# Ep13 Train=0.0025 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.29% R²=0.473 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.78% R²=0.644 | LR=0.000350 | Time=36.9s
# Ep14 Train=0.0024 | Val=0.0021 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.54% R²=0.465 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.50% R²=0.646 | LR=0.000375 | Time=41.3s
# Ep15 Train=0.0024 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.31% R²=0.473 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.62% R²=0.645 | LR=0.000400 | Time=43.0s
# Ep16 Train=0.0024 | Val=0.0021 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.29% R²=0.475 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.54% R²=0.647 | LR=0.000425 | Time=34.1s
# Ep17 Train=0.0024 | Val=0.0021 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.30% R²=0.471 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.60% R²=0.646 | LR=0.000450 | Time=35.2s
# Ep18 Train=0.0024 | Val=0.0021 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.51% R²=0.464 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.61% R²=0.647 | LR=0.000475 | Time=34.0s
# Ep19 Train=0.0023 | Val=0.0021 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.03% R²=0.483 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.38% R²=0.655 | LR=0.000500 | Time=35.1s
# Ep20 Train=0.0023 | Val=0.0029 | Val(last) RMSE=1.6 MAE=1.2 MAPE=29.44% R²=0.388 | Val(full) RMSE=1.4 MAE=1.1 MAPE=26.15% R²=0.540 | LR=0.000500 | Time=33.1s
# Ep21 Train=0.0022 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.97% R²=0.476 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.34% R²=0.646 | LR=0.000500 | Time=33.8s
# Ep22 Train=0.0022 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.83% R²=0.486 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.40% R²=0.670 | LR=0.000499 | Time=32.6s
# Ep23 Train=0.0022 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.57% R²=0.489 | Val(full) RMSE=1.1 MAE=0.8 MAPE=21.10% R²=0.679 | LR=0.000498 | Time=33.8s
# Ep24 Train=0.0021 | Val=0.0021 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.21% R²=0.475 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.29% R²=0.656 | LR=0.000497 | Time=34.8s
# Ep25 Train=0.0021 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.35% R²=0.503 | Val(full) RMSE=1.1 MAE=0.8 MAPE=21.24% R²=0.677 | LR=0.000495 | Time=33.2s
# Ep26 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.98% R²=0.483 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.44% R²=0.667 | LR=0.000493 | Time=34.3s
# Ep27 Train=0.0021 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.44% R²=0.456 | Val(full) RMSE=1.3 MAE=0.9 MAPE=23.00% R²=0.616 | LR=0.000491 | Time=32.9s
# Ep28 Train=0.0021 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.27% R²=0.498 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.97% R²=0.679 | LR=0.000488 | Time=35.0s
# Ep29 Train=0.0021 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.57% R²=0.494 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.86% R²=0.686 | LR=0.000485 | Time=34.4s
# Ep30 Train=0.0021 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.54% R²=0.495 | Val(full) RMSE=1.1 MAE=0.9 MAPE=21.28% R²=0.678 | LR=0.000481 | Time=32.6s
# Ep31 Train=0.0020 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.93% R²=0.486 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.42% R²=0.671 | LR=0.000477 | Time=32.7s
# Ep32 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.30% R²=0.499 | Val(full) RMSE=1.1 MAE=0.8 MAPE=21.02% R²=0.681 | LR=0.000473 | Time=33.5s
# Ep33 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.34% R²=0.496 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.93% R²=0.682 | LR=0.000468 | Time=34.6s
# Ep34 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.80% R²=0.485 | Val(full) RMSE=1.2 MAE=0.8 MAPE=21.07% R²=0.676 | LR=0.000463 | Time=37.9s
# Ep35 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.57% R²=0.486 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.77% R²=0.685 | LR=0.000458 | Time=39.0s
# Ep36 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.32% R²=0.502 | Val(full) RMSE=1.1 MAE=0.8 MAPE=21.05% R²=0.678 | LR=0.000452 | Time=40.1s
# Ep37 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.46% R²=0.496 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.76% R²=0.686 | LR=0.000446 | Time=35.3s
# Ep38 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.90% R²=0.474 | Val(full) RMSE=1.2 MAE=0.8 MAPE=21.03% R²=0.674 | LR=0.000440 | Time=38.5s
# Ep39 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.16% R²=0.511 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.75% R²=0.683 | LR=0.000434 | Time=34.7s
# Ep40 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.33% R²=0.499 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.86% R²=0.685 | LR=0.000427 | Time=39.1s
# Ep41 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.57% R²=0.491 | Val(full) RMSE=1.1 MAE=0.8 MAPE=21.04% R²=0.681 | LR=0.000420 | Time=37.5s
# Ep42 Train=0.0019 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.52% R²=0.492 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.18% R²=0.674 | LR=0.000412 | Time=38.6s
# Ep43 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.49% R²=0.487 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.83% R²=0.680 | LR=0.000405 | Time=39.7s
# Ep44 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.32% R²=0.493 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.75% R²=0.684 | LR=0.000397 | Time=37.6s
# Ep45 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.66% R²=0.479 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.73% R²=0.681 | LR=0.000389 | Time=39.0s
# Ep46 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.87% R²=0.453 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.74% R²=0.673 | LR=0.000381 | Time=41.8s
# Ep47 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.55% R²=0.492 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.90% R²=0.680 | LR=0.000372 | Time=36.9s
# Ep48 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.42% R²=0.491 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.90% R²=0.677 | LR=0.000363 | Time=36.8s
# Ep49 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.62% R²=0.465 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.77% R²=0.673 | LR=0.000355 | Time=36.3s
# Ep50 Train=0.0019 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.60% R²=0.481 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.25% R²=0.666 | LR=0.000346 | Time=36.3s
# Ep51 Train=0.0019 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.41% R²=0.493 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.91% R²=0.682 | LR=0.000337 | Time=33.4s
# Ep52 Train=0.0019 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.23% R²=0.489 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.41% R²=0.687 | LR=0.000327 | Time=34.3s
# Ep53 Train=0.0019 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.15% R²=0.493 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.42% R²=0.687 | LR=0.000318 | Time=37.1s
# Ep54 Train=0.0019 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.05% R²=0.501 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.41% R²=0.689 | LR=0.000308 | Time=35.0s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (front-weighted MSE): 0.0013
#
# Final Test Metrics (last step, m/s): MSE=1.38, RMSE=1.17, MAE=0.91, MAPE=15.37, R²=0.2609, Adj R²=0.2600
# Final Test Metrics (full 24h path): RMSE=0.94, MAE=0.71, MAPE=12.04, R²=0.6888
# Hourly-averaged RMSE by lead hour (0→23):
# [0.28, 0.3 , 0.43, 0.55, 0.66, 0.74, 0.8 , 0.85, 0.88, 0.91, 0.93, 0.94,
#  0.96, 0.98, 1.01, 1.05, 1.08, 1.11, 1.13, 1.16, 1.18, 1.2 , 1.2 , 1.18]
# Avg inference latency: 0.51 ms/batch • 0.51 ms/sample

# %%
# Marked the days that experienced spikes during typhoons using IQR rule
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final_IQRrule_based.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).fillna(0)

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        r2_all  = r2_score(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% R²={r2_all:.3f} | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    mape = smape(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)
    mape_all = smape(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, MAPE={mape:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}, MAPE={mape_all:.2f}, R²={r2_all:.4f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final_outlier_based.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).fillna(0)

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        r2_all  = r2_score(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% R²={r2_all:.3f} | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    mape = smape(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)
    mape_all = smape(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, MAPE={mape:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}, MAPE={mape_all:.2f}, R²={r2_all:.4f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 174913, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-02 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 8304160
# Ep01 Train=0.0099 | Val=0.0018 | Val(last) RMSE=1.2 MAE=1.0 MAPE=23.55% R²=0.633 | Val(full) RMSE=1.0 MAE=0.8 MAPE=21.32% R²=0.731 | LR=0.000050 | Time=37.0s
# Ep02 Train=0.0021 | Val=0.0012 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.09% R²=0.750 | Val(full) RMSE=0.9 MAE=0.7 MAPE=17.90% R²=0.812 | LR=0.000075 | Time=36.1s
# Ep03 Train=0.0017 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.68% R²=0.760 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.88% R²=0.838 | LR=0.000100 | Time=35.7s
# Ep04 Train=0.0016 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.91% R²=0.758 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.01% R²=0.836 | LR=0.000125 | Time=36.4s
# Ep05 Train=0.0016 | Val=0.0012 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.88% R²=0.765 | Val(full) RMSE=0.8 MAE=0.7 MAPE=17.41% R²=0.826 | LR=0.000150 | Time=39.6s
# Ep06 Train=0.0016 | Val=0.0013 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.93% R²=0.751 | Val(full) RMSE=0.9 MAE=0.7 MAPE=18.31% R²=0.800 | LR=0.000175 | Time=39.2s
# Ep07 Train=0.0016 | Val=0.0010 | Val(last) RMSE=1.1 MAE=0.8 MAPE=21.07% R²=0.704 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.36% R²=0.846 | LR=0.000200 | Time=38.7s
# Ep08 Train=0.0016 | Val=0.0013 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.95% R²=0.759 | Val(full) RMSE=0.9 MAE=0.7 MAPE=18.39% R²=0.805 | LR=0.000225 | Time=38.2s
# Ep09 Train=0.0015 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.28% R²=0.740 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.69% R²=0.842 | LR=0.000250 | Time=36.7s
# Ep10 Train=0.0015 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.05% R²=0.744 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.07% R²=0.828 | LR=0.000275 | Time=37.3s
# Ep11 Train=0.0015 | Val=0.0015 | Val(last) RMSE=1.2 MAE=0.9 MAPE=22.48% R²=0.669 | Val(full) RMSE=1.0 MAE=0.8 MAPE=19.62% R²=0.758 | LR=0.000300 | Time=38.1s
# Ep12 Train=0.0016 | Val=0.0021 | Val(last) RMSE=1.1 MAE=0.9 MAPE=21.86% R²=0.703 | Val(full) RMSE=1.1 MAE=0.9 MAPE=21.95% R²=0.709 | LR=0.000325 | Time=37.7s
# Ep13 Train=0.0015 | Val=0.0026 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.11% R²=0.746 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.21% R²=0.595 | LR=0.000350 | Time=33.8s
# Ep14 Train=0.0016 | Val=0.0012 | Val(last) RMSE=1.0 MAE=0.8 MAPE=21.28% R²=0.731 | Val(full) RMSE=0.9 MAE=0.7 MAPE=18.06% R²=0.823 | LR=0.000375 | Time=34.3s
# Ep15 Train=0.0015 | Val=0.0012 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.79% R²=0.769 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.28% R²=0.830 | LR=0.000400 | Time=32.7s
# Ep16 Train=0.0015 | Val=0.0009 | Val(last) RMSE=0.9 MAE=0.7 MAPE=18.80% R²=0.789 | Val(full) RMSE=0.7 MAE=0.6 MAPE=15.66% R²=0.865 | LR=0.000425 | Time=34.8s
# Ep17 Train=0.0014 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.45% R²=0.744 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.41% R²=0.833 | LR=0.000450 | Time=34.5s
# Ep18 Train=0.0014 | Val=0.0012 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.86% R²=0.741 | Val(full) RMSE=0.9 MAE=0.7 MAPE=17.71% R²=0.813 | LR=0.000475 | Time=36.5s
# Ep19 Train=0.0013 | Val=0.0008 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.60% R²=0.826 | Val(full) RMSE=0.7 MAE=0.5 MAPE=14.19% R²=0.884 | LR=0.000500 | Time=35.8s
# Ep20 Train=0.0012 | Val=0.0013 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.48% R²=0.761 | Val(full) RMSE=0.9 MAE=0.7 MAPE=18.53% R²=0.806 | LR=0.000500 | Time=35.4s
# Ep21 Train=0.0011 | Val=0.0007 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.47% R²=0.828 | Val(full) RMSE=0.7 MAE=0.5 MAPE=13.37% R²=0.897 | LR=0.000500 | Time=35.7s
# Ep22 Train=0.0011 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.43% R²=0.835 | Val(full) RMSE=0.6 MAE=0.5 MAPE=12.69% R²=0.909 | LR=0.000499 | Time=35.9s
# Ep23 Train=0.0010 | Val=0.0010 | Val(last) RMSE=0.9 MAE=0.7 MAPE=18.03% R²=0.807 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.46% R²=0.854 | LR=0.000498 | Time=37.2s
# Ep24 Train=0.0010 | Val=0.0007 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.98% R²=0.826 | Val(full) RMSE=0.7 MAE=0.5 MAPE=14.36% R²=0.891 | LR=0.000497 | Time=37.8s
# Ep25 Train=0.0009 | Val=0.0007 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.47% R²=0.841 | Val(full) RMSE=0.6 MAE=0.5 MAPE=13.53% R²=0.899 | LR=0.000495 | Time=39.0s
# Ep26 Train=0.0009 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.46% R²=0.854 | Val(full) RMSE=0.6 MAE=0.5 MAPE=12.76% R²=0.904 | LR=0.000493 | Time=37.1s
# Ep27 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.7 MAE=0.6 MAPE=14.42% R²=0.868 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.41% R²=0.922 | LR=0.000491 | Time=36.1s
# Ep28 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=14.86% R²=0.862 | Val(full) RMSE=0.5 MAE=0.4 MAPE=11.22% R²=0.927 | LR=0.000488 | Time=36.2s
# Ep29 Train=0.0009 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.99% R²=0.853 | Val(full) RMSE=0.6 MAE=0.5 MAPE=12.35% R²=0.914 | LR=0.000485 | Time=35.8s
# Ep30 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.10% R²=0.858 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.81% R²=0.918 | LR=0.000481 | Time=36.3s
# Ep31 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.7 MAE=0.6 MAPE=14.46% R²=0.872 | Val(full) RMSE=0.5 MAE=0.4 MAPE=11.27% R²=0.927 | LR=0.000477 | Time=37.2s
# Ep32 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.34% R²=0.862 | Val(full) RMSE=0.6 MAE=0.5 MAPE=12.24% R²=0.918 | LR=0.000473 | Time=37.0s
# Ep33 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.69% R²=0.853 | Val(full) RMSE=0.6 MAE=0.4 MAPE=12.14% R²=0.916 | LR=0.000468 | Time=37.2s
# Ep34 Train=0.0009 | Val=0.0007 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.91% R²=0.832 | Val(full) RMSE=0.6 MAE=0.5 MAPE=13.40% R²=0.899 | LR=0.000463 | Time=36.5s
# Ep35 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=14.85% R²=0.859 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.67% R²=0.922 | LR=0.000458 | Time=36.4s
# Ep36 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.39% R²=0.857 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.62% R²=0.923 | LR=0.000452 | Time=35.2s
# Ep37 Train=0.0009 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.63% R²=0.852 | Val(full) RMSE=0.6 MAE=0.5 MAPE=12.97% R²=0.903 | LR=0.000446 | Time=36.8s
# Ep38 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.30% R²=0.860 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.51% R²=0.925 | LR=0.000440 | Time=37.5s
# Ep39 Train=0.0009 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=14.63% R²=0.863 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.51% R²=0.915 | LR=0.000434 | Time=35.2s
# Ep40 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.27% R²=0.856 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.68% R²=0.919 | LR=0.000427 | Time=33.2s
# Ep41 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.7 MAE=0.6 MAPE=14.46% R²=0.868 | Val(full) RMSE=0.5 MAE=0.4 MAPE=11.06% R²=0.929 | LR=0.000420 | Time=33.8s
# Ep42 Train=0.0008 | Val=0.0005 | Val(last) RMSE=0.7 MAE=0.5 MAPE=14.37% R²=0.877 | Val(full) RMSE=0.5 MAE=0.4 MAPE=11.28% R²=0.931 | LR=0.000412 | Time=32.4s
# Ep43 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.7 MAE=0.5 MAPE=14.24% R²=0.873 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.00% R²=0.924 | LR=0.000405 | Time=31.9s
# Ep44 Train=0.0008 | Val=0.0005 | Val(last) RMSE=0.7 MAE=0.6 MAPE=14.96% R²=0.866 | Val(full) RMSE=0.5 MAE=0.4 MAPE=11.22% R²=0.927 | LR=0.000397 | Time=33.8s
# Ep45 Train=0.0008 | Val=0.0005 | Val(last) RMSE=0.7 MAE=0.6 MAPE=14.64% R²=0.870 | Val(full) RMSE=0.5 MAE=0.4 MAPE=10.98% R²=0.930 | LR=0.000389 | Time=34.4s
# Ep46 Train=0.0008 | Val=0.0005 | Val(last) RMSE=0.7 MAE=0.6 MAPE=14.31% R²=0.869 | Val(full) RMSE=0.5 MAE=0.4 MAPE=10.95% R²=0.928 | LR=0.000381 | Time=33.5s
# Ep47 Train=0.0008 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=17.05% R²=0.837 | Val(full) RMSE=0.6 MAE=0.5 MAPE=13.81% R²=0.905 | LR=0.000372 | Time=31.5s
# Ep48 Train=0.0008 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.04% R²=0.853 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.18% R²=0.925 | LR=0.000363 | Time=31.1s
# Ep49 Train=0.0008 | Val=0.0004 | Val(last) RMSE=0.7 MAE=0.5 MAPE=14.34% R²=0.873 | Val(full) RMSE=0.5 MAE=0.4 MAPE=10.53% R²=0.936 | LR=0.000355 | Time=34.3s
# Ep50 Train=0.0008 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.27% R²=0.862 | Val(full) RMSE=0.5 MAE=0.4 MAPE=11.26% R²=0.927 | LR=0.000346 | Time=32.3s
# Ep51 Train=0.0008 | Val=0.0004 | Val(last) RMSE=0.7 MAE=0.5 MAPE=14.16% R²=0.877 | Val(full) RMSE=0.5 MAE=0.4 MAPE=10.41% R²=0.939 | LR=0.000337 | Time=32.3s
# Ep52 Train=0.0008 | Val=0.0004 | Val(last) RMSE=0.7 MAE=0.5 MAPE=13.98% R²=0.877 | Val(full) RMSE=0.5 MAE=0.4 MAPE=10.11% R²=0.940 | LR=0.000327 | Time=33.2s
# Ep53 Train=0.0008 | Val=0.0004 | Val(last) RMSE=0.7 MAE=0.6 MAPE=14.83% R²=0.863 | Val(full) RMSE=0.5 MAE=0.4 MAPE=10.47% R²=0.933 | LR=0.000318 | Time=32.5s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (front-weighted MSE): 0.0004
#
# Final Test Metrics (last step, m/s): MSE=0.48, RMSE=0.69, MAE=0.54, MAPE=9.20, R²=0.7443, Adj R²=0.7439
# Final Test Metrics (full 24h path): RMSE=0.49, MAE=0.38, MAPE=6.48, R²=0.9325
# Hourly-averaged RMSE by lead hour (0→23):
# [0.3 , 0.29, 0.35, 0.42, 0.46, 0.47, 0.46, 0.44, 0.43, 0.44, 0.45, 0.46,
#  0.48, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.56, 0.57, 0.57, 0.59, 0.63, 0.67]
# Avg inference latency: 0.44 ms/batch • 0.44 ms/sample

# %%
# no outlier detection (typhoon)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final_rolling_mean_7d.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).fillna(0)

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        r2_all  = r2_score(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% R²={r2_all:.3f} | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    mape = smape(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)
    mape_all = smape(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, MAPE={mape:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}, MAPE={mape_all:.2f}, R²={r2_all:.4f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 174913, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-02 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 8303456
# Ep01 Train=0.0103 | Val=0.0032 | Val(last) RMSE=1.6 MAE=1.2 MAPE=29.36% R²=0.382 | Val(full) RMSE=1.4 MAE=1.1 MAPE=27.08% R²=0.494 | LR=0.000050 | Time=39.8s
# Ep02 Train=0.0032 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.65% R²=0.450 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.28% R²=0.625 | LR=0.000075 | Time=37.2s
# Ep03 Train=0.0027 | Val=0.0024 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.49% R²=0.472 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.57% R²=0.623 | LR=0.000100 | Time=37.7s
# Ep04 Train=0.0027 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.72% R²=0.454 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.34% R²=0.626 | LR=0.000125 | Time=34.1s
# Ep05 Train=0.0026 | Val=0.0025 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.56% R²=0.428 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.00% R²=0.606 | LR=0.000150 | Time=39.4s
# Ep06 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.47% R²=0.460 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.24% R²=0.626 | LR=0.000175 | Time=35.6s
# Ep07 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.30% R²=0.432 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.45% R²=0.624 | LR=0.000200 | Time=33.1s
# Ep08 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.37% R²=0.470 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.60% R²=0.623 | LR=0.000225 | Time=32.6s
# Ep09 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.2 MAPE=27.82% R²=0.456 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.55% R²=0.621 | LR=0.000250 | Time=35.3s
# Ep10 Train=0.0026 | Val=0.0024 | Val(last) RMSE=1.6 MAE=1.2 MAPE=29.08% R²=0.348 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.80% R²=0.593 | LR=0.000275 | Time=33.9s
# Ep11 Train=0.0026 | Val=0.0024 | Val(last) RMSE=1.5 MAE=1.2 MAPE=27.86% R²=0.453 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.72% R²=0.616 | LR=0.000300 | Time=33.6s
# Ep12 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.2 MAPE=28.05% R²=0.450 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.45% R²=0.627 | LR=0.000325 | Time=35.0s
# Ep13 Train=0.0026 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.34% R²=0.467 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.19% R²=0.631 | LR=0.000350 | Time=37.1s
# Ep14 Train=0.0025 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.2 MAPE=27.88% R²=0.455 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.98% R²=0.632 | LR=0.000375 | Time=36.7s
# Ep15 Train=0.0025 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.39% R²=0.472 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.71% R²=0.644 | LR=0.000400 | Time=34.4s
# Ep16 Train=0.0025 | Val=0.0023 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.72% R²=0.460 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.09% R²=0.633 | LR=0.000425 | Time=35.9s
# Ep17 Train=0.0025 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.59% R²=0.464 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.98% R²=0.635 | LR=0.000450 | Time=33.5s
# Ep18 Train=0.0023 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.79% R²=0.483 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.50% R²=0.668 | LR=0.000475 | Time=38.5s
# Ep19 Train=0.0022 | Val=0.0021 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.61% R²=0.488 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.59% R²=0.657 | LR=0.000500 | Time=37.5s
# Ep20 Train=0.0022 | Val=0.0021 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.94% R²=0.474 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.80% R²=0.648 | LR=0.000500 | Time=36.8s
# Ep21 Train=0.0022 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.84% R²=0.484 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.45% R²=0.667 | LR=0.000500 | Time=39.8s
# Ep22 Train=0.0022 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.65% R²=0.490 | Val(full) RMSE=1.2 MAE=0.8 MAPE=21.11% R²=0.675 | LR=0.000499 | Time=37.3s
# Ep23 Train=0.0022 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.33% R²=0.492 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.91% R²=0.677 | LR=0.000498 | Time=35.0s
# Ep24 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.50% R²=0.491 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.32% R²=0.673 | LR=0.000497 | Time=34.9s
# Ep25 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.44% R²=0.495 | Val(full) RMSE=1.2 MAE=0.8 MAPE=21.08% R²=0.674 | LR=0.000495 | Time=32.8s
# Ep26 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.56% R²=0.487 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.10% R²=0.669 | LR=0.000493 | Time=38.7s
# Ep27 Train=0.0021 | Val=0.0022 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.85% R²=0.469 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.45% R²=0.632 | LR=0.000491 | Time=41.6s
# Ep28 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.40% R²=0.487 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.97% R²=0.673 | LR=0.000488 | Time=36.5s
# Ep29 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.22% R²=0.461 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.28% R²=0.666 | LR=0.000485 | Time=36.1s
# Ep30 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.52% R²=0.488 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.95% R²=0.672 | LR=0.000481 | Time=35.8s
# Ep31 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.46% R²=0.491 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.11% R²=0.666 | LR=0.000477 | Time=35.0s
# Ep32 Train=0.0021 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.30% R²=0.495 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.75% R²=0.681 | LR=0.000473 | Time=36.7s
# Ep33 Train=0.0021 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.36% R²=0.496 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.69% R²=0.683 | LR=0.000468 | Time=36.4s
# Ep34 Train=0.0021 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.36% R²=0.495 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.66% R²=0.682 | LR=0.000463 | Time=36.9s
# Ep35 Train=0.0021 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.48% R²=0.484 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.81% R²=0.680 | LR=0.000458 | Time=38.3s
# Ep36 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.59% R²=0.489 | Val(full) RMSE=1.2 MAE=0.8 MAPE=21.17% R²=0.673 | LR=0.000452 | Time=34.3s
# Ep37 Train=0.0020 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.75% R²=0.480 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.10% R²=0.668 | LR=0.000446 | Time=33.5s
# Ep38 Train=0.0021 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.70% R²=0.480 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.24% R²=0.665 | LR=0.000440 | Time=34.5s
# Ep39 Train=0.0020 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.39% R²=0.497 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.14% R²=0.669 | LR=0.000434 | Time=32.0s
# Ep40 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.54% R²=0.486 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.94% R²=0.678 | LR=0.000427 | Time=33.8s
# Ep41 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.47% R²=0.491 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.94% R²=0.679 | LR=0.000420 | Time=32.6s
# Ep42 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.51% R²=0.492 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.95% R²=0.678 | LR=0.000412 | Time=36.4s
# Ep43 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.58% R²=0.486 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.82% R²=0.679 | LR=0.000405 | Time=38.2s
# Ep44 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.47% R²=0.494 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.88% R²=0.680 | LR=0.000397 | Time=35.5s
# Ep45 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.41% R²=0.497 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.69% R²=0.684 | LR=0.000389 | Time=35.1s
# Ep46 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.68% R²=0.490 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.69% R²=0.682 | LR=0.000381 | Time=38.5s
# Ep47 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.74% R²=0.477 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.80% R²=0.676 | LR=0.000372 | Time=34.7s
# Ep48 Train=0.0020 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.40% R²=0.488 | Val(full) RMSE=1.2 MAE=0.8 MAPE=21.02% R²=0.670 | LR=0.000363 | Time=33.3s
# Ep49 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.57% R²=0.484 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.69% R²=0.682 | LR=0.000355 | Time=35.9s
# Ep50 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.39% R²=0.489 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.89% R²=0.675 | LR=0.000346 | Time=36.1s
# Ep51 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.37% R²=0.496 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.78% R²=0.684 | LR=0.000337 | Time=35.6s
# Ep52 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.41% R²=0.491 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.56% R²=0.684 | LR=0.000327 | Time=36.1s
# Ep53 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.26% R²=0.495 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.51% R²=0.684 | LR=0.000318 | Time=40.9s
# Ep54 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.17% R²=0.497 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.56% R²=0.684 | LR=0.000308 | Time=43.9s
# Ep55 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.51% R²=0.493 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.73% R²=0.683 | LR=0.000299 | Time=38.3s
# Ep56 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.27% R²=0.491 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.57% R²=0.687 | LR=0.000289 | Time=33.9s
# Ep57 Train=0.0020 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.31% R²=0.498 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.46% R²=0.689 | LR=0.000279 | Time=35.3s
# Ep58 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.68% R²=0.487 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.87% R²=0.681 | LR=0.000270 | Time=35.6s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (front-weighted MSE): 0.0013
#
# Final Test Metrics (last step, m/s): MSE=1.38, RMSE=1.18, MAE=0.92, MAPE=15.48, R²=0.2592, Adj R²=0.2582
# Final Test Metrics (full 24h path): RMSE=0.93, MAE=0.70, MAPE=11.90, R²=0.6811
# Hourly-averaged RMSE by lead hour (0→23):
# [0.32, 0.35, 0.46, 0.57, 0.67, 0.75, 0.8 , 0.84, 0.88, 0.9 , 0.92, 0.94,
#  0.96, 0.98, 1.01, 1.03, 1.06, 1.09, 1.12, 1.14, 1.16, 1.17, 1.17, 1.17]
# Avg inference latency: 0.52 ms/batch • 0.52 ms/sample

# %%
# Centered and causal roll mean: this is the crucial fix that keeps the validation distribution aligned with real-world conditions, avoiding false optimism from “future leaks.” 
# THis only uses rolling mean in center during training, and causal (past only) during validation and testing.

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final_rolling_mean_7d.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).copy()

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # ----------------------------
    # Compute both centered and causal low-frequency columns
    # - centered (peeks into future): center=True -> used only for training rows
    # - causal  (past only): center=False -> used for val/test rows (no leakage)
    # ----------------------------
    roll_window = 2016  # ~7 days at 5-min cadence
    df['WS50M_low_freq_centered'] = df['WS50M'].rolling(window=roll_window, min_periods=1, center=True).mean()
    df['WS50M_low_freq_causal']  = df['WS50M'].rolling(window=roll_window, min_periods=1, center=False).mean()

    # ----------------------------
    # Splits (you had these dates)
    # ----------------------------
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # We'll create the column `WS50M_low_freq_7d` such that:
    # - for training rows (<= train_end) it equals the centered version (gives training benefit)
    # - for val/test rows (> train_end) it equals the causal version (no future peek)
    df['WS50M_low_freq_7d'] = df['WS50M_low_freq_centered'].copy()
    df.loc[df.index > train_end, 'WS50M_low_freq_7d'] = df.loc[df.index > train_end, 'WS50M_low_freq_causal']

    # Optionally drop intermediate columns to keep df tidy (but not necessary)
    df.drop(columns=['WS50M_low_freq_centered', 'WS50M_low_freq_causal'], inplace=True)

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback (7 days)
    H = 1 * 24 * 12   # horizon (24h)
    times = df.index[W + H - 1 :]

    print(df.head())
    
    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    # NOTE: scaler fitted on training rows (which include centered low_freq for those rows)
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array (features + target)
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        r2_all  = r2_score(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% R²={r2_all:.3f} | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    mape = smape(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)
    mape_all = smape(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, MAPE={mape:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}, MAPE={mape_all:.2f}, R²={r2_all:.4f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
#                      HoD  DoY  MoY     WS50M      WD50M         PS       RH2M  \
# DATETIME
# 2013-12-26 00:00:00    0  360   12  2.637059  51.823529  99.704118  94.628824
# 2013-12-26 00:05:00    0  360   12  2.637083  50.567892  99.698407  94.616103
# 2013-12-26 00:10:00    0  360   12  2.637108  49.312255  99.692696  94.603382
# 2013-12-26 00:15:00    0  360   12  2.637132  48.056618  99.686985  94.590662
# 2013-12-26 00:20:00    0  360   12  2.637157  46.800980  99.681275  94.577941
#
#                         T2MDEW        T2M       QV2M  AIR_DENSITY  \
# DATETIME
# 2013-12-26 00:00:00  24.226765  25.137647  19.081176     0.104301
# 2013-12-26 00:05:00  24.219020  25.131838  19.072843     0.104302
# 2013-12-26 00:10:00  24.211275  25.126029  19.064510     0.104303
# 2013-12-26 00:15:00  24.203529  25.120221  19.056176     0.104304
# 2013-12-26 00:20:00  24.195784  25.114412  19.047843     0.104305
#
#                      WS50M_low_freq_7d    TARGET
# DATETIME
# 2013-12-26 00:00:00           5.109863  2.637059
# 2013-12-26 00:05:00           5.112163  2.637083
# 2013-12-26 00:10:00           5.114460  2.637108
# 2013-12-26 00:15:00           5.116752  2.637132
# 2013-12-26 00:20:00           5.119042  2.637157
# Train windows: 174913, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-02 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 8303456
# Ep01 Train=0.0092 | Val=0.0167 | Val(last) RMSE=2.8 MAE=2.1 MAPE=44.97% R²=-0.933 | Val(full) RMSE=3.2 MAE=2.4 MAPE=51.86% R²=-1.433 | LR=0.000050 | Time=37.6s
# Ep02 Train=0.0021 | Val=0.0139 | Val(last) RMSE=3.0 MAE=2.3 MAPE=46.86% R²=-1.172 | Val(full) RMSE=2.9 MAE=2.2 MAPE=45.64% R²=-1.116 | LR=0.000075 | Time=36.2s
# Ep03 Train=0.0016 | Val=0.0151 | Val(last) RMSE=3.1 MAE=2.3 MAPE=46.80% R²=-1.313 | Val(full) RMSE=3.1 MAE=2.3 MAPE=46.20% R²=-1.309 | LR=0.000100 | Time=33.9s
# Ep04 Train=0.0017 | Val=0.0143 | Val(last) RMSE=2.9 MAE=2.2 MAPE=45.69% R²=-1.115 | Val(full) RMSE=3.0 MAE=2.3 MAPE=45.73% R²=-1.154 | LR=0.000125 | Time=33.7s
# Ep05 Train=0.0016 | Val=0.0130 | Val(last) RMSE=2.8 MAE=2.2 MAPE=44.64% R²=-0.973 | Val(full) RMSE=2.9 MAE=2.1 MAPE=43.96% R²=-1.002 | LR=0.000150 | Time=37.3s
# Ep06 Train=0.0016 | Val=0.0107 | Val(last) RMSE=2.6 MAE=2.0 MAPE=44.02% R²=-0.681 | Val(full) RMSE=2.6 MAE=2.0 MAPE=43.24% R²=-0.636 | LR=0.000175 | Time=38.5s
# Ep19 Train=0.0014 | Val=0.0105 | Val(last) RMSE=2.6 MAE=2.0 MAPE=42.80% R²=-0.619 | Val(full) RMSE=2.6 MAE=1.9 MAPE=41.37% R²=-0.609 | LR=0.000500 | Time=36.2s
# Ep20 Train=0.0012 | Val=0.0114 | Val(last) RMSE=2.6 MAE=2.0 MAPE=43.80% R²=-0.637 | Val(full) RMSE=2.7 MAE=2.0 MAPE=43.72% R²=-0.732 | LR=0.000500 | Time=35.6s
# Ep21 Train=0.0011 | Val=0.0124 | Val(last) RMSE=2.8 MAE=2.1 MAPE=46.63% R²=-0.938 | Val(full) RMSE=2.8 MAE=2.1 MAPE=45.23% R²=-0.932 | LR=0.000500 | Time=36.6s
# Ep22 Train=0.0010 | Val=0.0119 | Val(last) RMSE=2.9 MAE=2.2 MAPE=47.84% R²=-1.026 | Val(full) RMSE=2.8 MAE=2.1 MAPE=46.90% R²=-0.853 | LR=0.000499 | Time=37.1s
# Ep23 Train=0.0010 | Val=0.0141 | Val(last) RMSE=3.0 MAE=2.3 MAPE=50.44% R²=-1.156 | Val(full) RMSE=3.0 MAE=2.2 MAPE=48.52% R²=-1.193 | LR=0.000498 | Time=37.2s
# Ep24 Train=0.0009 | Val=0.0132 | Val(last) RMSE=2.8 MAE=2.1 MAPE=53.01% R²=-0.877 | Val(full) RMSE=2.9 MAE=2.2 MAPE=50.21% R²=-1.047 | LR=0.000497 | Time=37.5s
# Ep25 Train=0.0009 | Val=0.0130 | Val(last) RMSE=2.8 MAE=2.2 MAPE=52.92% R²=-0.959 | Val(full) RMSE=2.9 MAE=2.2 MAPE=50.40% R²=-1.010 | LR=0.000495 | Time=39.1s
# Ep26 Train=0.0009 | Val=0.0128 | Val(last) RMSE=2.8 MAE=2.1 MAPE=50.15% R²=-0.891 | Val(full) RMSE=2.8 MAE=2.1 MAPE=48.89% R²=-0.982 | LR=0.000493 | Time=45.0s
# Ep27 Train=0.0009 | Val=0.0116 | Val(last) RMSE=2.7 MAE=2.0 MAPE=50.46% R²=-0.719 | Val(full) RMSE=2.7 MAE=2.1 MAPE=49.34% R²=-0.783 | LR=0.000491 | Time=36.9s
# Ep28 Train=0.0009 | Val=0.0130 | Val(last) RMSE=2.7 MAE=2.1 MAPE=50.54% R²=-0.752 | Val(full) RMSE=2.9 MAE=2.2 MAPE=50.77% R²=-1.004 | LR=0.000488 | Time=37.0s
# Ep29 Train=0.0009 | Val=0.0118 | Val(last) RMSE=2.6 MAE=2.0 MAPE=48.51% R²=-0.656 | Val(full) RMSE=2.7 MAE=2.1 MAPE=47.88% R²=-0.803 | LR=0.000485 | Time=36.1s
# Ep30 Train=0.0009 | Val=0.0142 | Val(last) RMSE=2.7 MAE=2.1 MAPE=50.41% R²=-0.780 | Val(full) RMSE=3.0 MAE=2.2 MAPE=51.84% R²=-1.163 | LR=0.000481 | Time=36.4s
# Ep31 Train=0.0009 | Val=0.0132 | Val(last) RMSE=2.7 MAE=2.1 MAPE=49.36% R²=-0.763 | Val(full) RMSE=2.9 MAE=2.2 MAPE=50.49% R²=-1.037 | LR=0.000477 | Time=36.3s
# Ep32 Train=0.0009 | Val=0.0129 | Val(last) RMSE=2.7 MAE=2.1 MAPE=49.08% R²=-0.780 | Val(full) RMSE=2.8 MAE=2.2 MAPE=50.69% R²=-0.980 | LR=0.000473 | Time=33.7s
# Ep33 Train=0.0009 | Val=0.0125 | Val(last) RMSE=2.7 MAE=2.1 MAPE=50.99% R²=-0.833 | Val(full) RMSE=2.8 MAE=2.1 MAPE=49.43% R²=-0.930 | LR=0.000468 | Time=36.8s
# Ep34 Train=0.0009 | Val=0.0125 | Val(last) RMSE=2.6 MAE=2.0 MAPE=46.57% R²=-0.662 | Val(full) RMSE=2.8 MAE=2.1 MAPE=47.41% R²=-0.928 | LR=0.000463 | Time=33.9s
# Ep35 Train=0.0009 | Val=0.0127 | Val(last) RMSE=2.6 MAE=2.0 MAPE=49.14% R²=-0.666 | Val(full) RMSE=2.8 MAE=2.1 MAPE=49.77% R²=-0.945 | LR=0.000458 | Time=38.7s
# Ep36 Train=0.0009 | Val=0.0129 | Val(last) RMSE=2.7 MAE=2.1 MAPE=48.90% R²=-0.736 | Val(full) RMSE=2.8 MAE=2.1 MAPE=49.71% R²=-0.981 | LR=0.000452 | Time=36.4s
# Ep37 Train=0.0009 | Val=0.0132 | Val(last) RMSE=2.8 MAE=2.1 MAPE=52.63% R²=-0.881 | Val(full) RMSE=2.9 MAE=2.2 MAPE=51.33% R²=-1.037 | LR=0.000446 | Time=36.7s
# Ep38 Train=0.0009 | Val=0.0122 | Val(last) RMSE=2.5 MAE=1.9 MAPE=43.82% R²=-0.536 | Val(full) RMSE=2.7 MAE=2.1 MAPE=46.11% R²=-0.843 | LR=0.000440 | Time=38.6s
# Ep39 Train=0.0009 | Val=0.0134 | Val(last) RMSE=2.7 MAE=2.1 MAPE=48.24% R²=-0.831 | Val(full) RMSE=2.9 MAE=2.2 MAPE=49.10% R²=-1.042 | LR=0.000434 | Time=36.7s
# Ep40 Train=0.0009 | Val=0.0136 | Val(last) RMSE=2.7 MAE=2.1 MAPE=48.07% R²=-0.804 | Val(full) RMSE=2.9 MAE=2.2 MAPE=50.76% R²=-1.082 | LR=0.000427 | Time=35.8s
# Ep41 Train=0.0009 | Val=0.0130 | Val(last) RMSE=2.5 MAE=1.9 MAPE=48.20% R²=-0.541 | Val(full) RMSE=2.8 MAE=2.1 MAPE=51.02% R²=-0.965 | LR=0.000420 | Time=36.2s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (front-weighted MSE): 0.0066
#
# Final Test Metrics (last step, m/s): MSE=4.30, RMSE=2.07, MAE=1.68, MAPE=30.80, R²=-1.3032, Adj R²=-1.3063
# Final Test Metrics (full 24h path): RMSE=2.01, MAE=1.66, MAPE=30.13, R²=-0.9649
# Hourly-averaged RMSE by lead hour (0→23):
# [1.83, 1.84, 1.91, 1.97, 1.99, 1.98, 1.96, 1.95, 1.94, 1.95, 1.97, 2.  ,
#  2.03, 2.06, 2.08, 2.09, 2.08, 2.08, 2.08, 2.09, 2.09, 2.08, 2.07, 2.07]
# Avg inference latency: 0.55 ms/batch • 0.55 ms/sample

# %%
# This one uses centered rolling mean for training, and low frequency = WS50M for validation and testing.

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final_rolling_mean_7d.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).copy()

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # ----------------------------
    # Compute both centered and causal low-frequency columns
    # - centered (peeks into future): center=True -> used only for training rows
    # - causal  (past only): center=False -> used for val/test rows (no leakage)
    # ----------------------------
    roll_window = 2016  # ~7 days at 5-min cadence
    df['WS50M_low_freq_centered'] = df['WS50M'].rolling(window=roll_window, min_periods=1, center=True).mean()
    df['WS50M_low_freq_causal']  = df['WS50M'].rolling(window=roll_window, min_periods=1, center=False).mean()

    # ----------------------------
    # Splits (you had these dates)
    # ----------------------------
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # We'll create the column `WS50M_low_freq_7d` such that:
    # - for training rows (<= train_end) it equals the centered version (gives training benefit)
    # - for val/test rows (> train_end) it equals the causal version (no future peek)
    df['WS50M_low_freq_7d'] = df['WS50M_low_freq_centered'].copy()
    df.loc[df.index > train_end, 'WS50M_low_freq_7d'] = df.loc[df.index > train_end, 'WS50M']

    # Optionally drop intermediate columns to keep df tidy (but not necessary)
    df.drop(columns=['WS50M_low_freq_centered', 'WS50M_low_freq_causal'], inplace=True)

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback (7 days)
    H = 1 * 24 * 12   # horizon (24h)
    times = df.index[W + H - 1 :]

    print(df.head())
    
    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    # NOTE: scaler fitted on training rows (which include centered low_freq for those rows)
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array (features + target)
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        r2_all  = r2_score(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% R²={r2_all:.3f} | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    mape = smape(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)
    mape_all = smape(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, MAPE={mape:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}, MAPE={mape_all:.2f}, R²={r2_all:.4f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
#                      HoD  DoY  MoY     WS50M      WD50M         PS       RH2M  \
# DATETIME
# 2013-12-26 00:00:00    0  360   12  2.637059  51.823529  99.704118  94.628824
# 2013-12-26 00:05:00    0  360   12  2.637083  50.567892  99.698407  94.616103
# 2013-12-26 00:10:00    0  360   12  2.637108  49.312255  99.692696  94.603382
# 2013-12-26 00:15:00    0  360   12  2.637132  48.056618  99.686985  94.590662
# 2013-12-26 00:20:00    0  360   12  2.637157  46.800980  99.681275  94.577941
#
#                         T2MDEW        T2M       QV2M  AIR_DENSITY  \
# DATETIME
# 2013-12-26 00:00:00  24.226765  25.137647  19.081176     0.104301
# 2013-12-26 00:05:00  24.219020  25.131838  19.072843     0.104302
# 2013-12-26 00:10:00  24.211275  25.126029  19.064510     0.104303
# 2013-12-26 00:15:00  24.203529  25.120221  19.056176     0.104304
# 2013-12-26 00:20:00  24.195784  25.114412  19.047843     0.104305
#
#                      WS50M_low_freq_7d    TARGET
# DATETIME
# 2013-12-26 00:00:00           5.109863  2.637059
# 2013-12-26 00:05:00           5.112163  2.637083
# 2013-12-26 00:10:00           5.114460  2.637108
# 2013-12-26 00:15:00           5.116752  2.637132
# 2013-12-26 00:20:00           5.119042  2.637157
# Train windows: 174913, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-02 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 8303456
# Ep01 Train=0.

# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (front-weighted MSE): 0.0171
#
# Final Test Metrics (last step, m/s): MSE=8.97, RMSE=2.99, MAE=2.42, MAPE=39.87, R²=-3.8006, Adj R²=-3.8069
# Final Test Metrics (full 24h path): RMSE=3.23, MAE=2.50, MAPE=39.94, R²=-14.8055
# Hourly-averaged RMSE by lead hour (0→23):
# [2.72, 2.78, 2.86, 2.95, 3.04, 3.12, 3.19, 3.26, 3.33, 3.4 , 3.46, 3.48,
#  3.5 , 3.51, 3.51, 3.48, 3.46, 3.4 , 3.32, 3.21, 3.12, 3.06, 3.02, 3.  ]
# Avg inference latency: 0.61 ms/batch • 0.61 ms/sample

# %%
# this one uses centered rolling mean for training and validation, and causal for testing.
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset (the CSV that already contains WS50M_low_freq_7d may be overridden below)
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final_rolling_mean_7d.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).copy()

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # ----------------------------
    # Splits (you had these dates)
    # ----------------------------
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # ----------------------------
    # Create both centered and causal low-frequency columns,
    # then set WS50M_low_freq_7d = centered for train+val (<= val_end),
    # and = causal for test (> val_end)
    # ----------------------------
    roll_window = 2016  # ~7 days at 5-min cadence
    # centered uses future points within window
    df['WS50M_low_freq_centered'] = df['WS50M'].rolling(window=roll_window, min_periods=1, center=True).mean()
    # causal uses only past points
    df['WS50M_low_freq_causal']  = df['WS50M'].rolling(window=roll_window, min_periods=1, center=False).mean()

    # Overwrite the working feature so train+val get centered, test gets causal
    df['WS50M_low_freq_7d'] = df['WS50M_low_freq_centered'].copy()
    df.loc[df.index > val_end, 'WS50M_low_freq_7d'] = df.loc[df.index > val_end, 'WS50M_low_freq_causal']

    # drop helper cols to keep df tidy
    df.drop(columns=['WS50M_low_freq_centered', 'WS50M_low_freq_causal'], inplace=True)

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        r2_all  = r2_score(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% R²={r2_all:.3f} | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    mape = smape(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)
    mape_all = smape(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, MAPE={mape:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}, MAPE={mape_all:.2f}, R²={r2_all:.4f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 174913, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-02 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 8303456
# Ep01 Train=0.0092 | Val=0.0023 | Val(last) RMSE=1.3 MAE=1.0 MAPE=24.09% R²=0.609 | Val(full) RMSE=1.2 MAE=0.9 MAPE=24.02% R²=0.655 | LR=0.000050 | Time=39.9s
# Ep02 Train=0.0021 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.16% R²=0.742 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.18% R²=0.830 | LR=0.000075 | Time=37.3s
# Ep03 Train=0.0016 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.89% R²=0.761 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.11% R²=0.836 | LR=0.000100 | Time=41.2s
# Ep04 Train=0.0017 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.16% R²=0.746 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.24% R²=0.830 | LR=0.000125 | Time=38.5s
# Ep05 Train=0.0016 | Val=0.0011 | Val(last) RMSE=1.1 MAE=0.8 MAPE=20.77% R²=0.724 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.20% R²=0.831 | LR=0.000150 | Time=38.4s
# Ep06 Train=0.0016 | Val=0.0016 | Val(last) RMSE=1.1 MAE=0.9 MAPE=21.44% R²=0.702 | Val(full) RMSE=1.0 MAE=0.8 MAPE=19.82% R²=0.756 | LR=0.000175 | Time=36.8s
# Ep07 Train=0.0016 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.16% R²=0.753 | Val(full) RMSE=0.8 MAE=0.7 MAPE=17.55% R²=0.828 | LR=0.000200 | Time=38.6s
# Ep08 Train=0.0016 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.00% R²=0.751 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.50% R²=0.845 | LR=0.000225 | Time=38.1s
# Ep09 Train=0.0016 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.84% R²=0.766 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.30% R²=0.851 | LR=0.000250 | Time=41.2s
# Ep10 Train=0.0016 | Val=0.0018 | Val(last) RMSE=1.1 MAE=0.8 MAPE=21.05% R²=0.727 | Val(full) RMSE=1.0 MAE=0.8 MAPE=20.47% R²=0.749 | LR=0.000275 | Time=36.6s
# Ep11 Train=0.0016 | Val=0.0017 | Val(last) RMSE=1.1 MAE=0.8 MAPE=21.08% R²=0.729 | Val(full) RMSE=1.0 MAE=0.8 MAPE=19.48% R²=0.765 | LR=0.000300 | Time=35.5s
# Ep12 Train=0.0016 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.85% R²=0.764 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.77% R²=0.847 | LR=0.000325 | Time=37.8s
# Ep13 Train=0.0016 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.7 MAPE=19.46% R²=0.767 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.52% R²=0.845 | LR=0.000350 | Time=47.7s
# Ep14 Train=0.0016 | Val=0.0009 | Val(last) RMSE=0.9 MAE=0.7 MAPE=18.79% R²=0.787 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.10% R²=0.856 | LR=0.000375 | Time=36.5s
# Ep15 Train=0.0017 | Val=0.0012 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.93% R²=0.749 | Val(full) RMSE=0.8 MAE=0.7 MAPE=17.59% R²=0.827 | LR=0.000400 | Time=36.8s
# Ep16 Train=0.0016 | Val=0.0023 | Val(last) RMSE=1.3 MAE=1.1 MAPE=24.97% R²=0.575 | Val(full) RMSE=1.2 MAE=1.0 MAPE=23.13% R²=0.657 | LR=0.000425 | Time=36.4s
# Ep17 Train=0.0015 | Val=0.0009 | Val(last) RMSE=0.9 MAE=0.7 MAPE=19.10% R²=0.785 | Val(full) RMSE=0.7 MAE=0.6 MAPE=15.77% R²=0.863 | LR=0.000450 | Time=37.7s
# Ep18 Train=0.0014 | Val=0.0009 | Val(last) RMSE=0.9 MAE=0.7 MAPE=19.09% R²=0.782 | Val(full) RMSE=0.8 MAE=0.6 MAPE=15.88% R²=0.860 | LR=0.000475 | Time=36.3s
# Ep19 Train=0.0014 | Val=0.0008 | Val(last) RMSE=0.9 MAE=0.7 MAPE=17.77% R²=0.799 | Val(full) RMSE=0.7 MAE=0.6 MAPE=14.67% R²=0.874 | LR=0.000500 | Time=36.1s
# Ep20 Train=0.0012 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.7 MAPE=18.69% R²=0.770 | Val(full) RMSE=0.8 MAE=0.6 MAPE=15.67% R²=0.851 | LR=0.000500 | Time=38.4s
# Ep21 Train=0.0011 | Val=0.0007 | Val(last) RMSE=0.9 MAE=0.7 MAPE=18.23% R²=0.790 | Val(full) RMSE=0.7 MAE=0.5 MAPE=13.96% R²=0.889 | LR=0.000500 | Time=38.8s
# Ep22 Train=0.0010 | Val=0.0007 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.27% R²=0.844 | Val(full) RMSE=0.7 MAE=0.5 MAPE=12.92% R²=0.896 | LR=0.000499 | Time=41.4s
# Ep23 Train=0.0010 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.27% R²=0.843 | Val(full) RMSE=0.6 MAE=0.5 MAPE=13.22% R²=0.902 | LR=0.000498 | Time=35.6s
# Ep24 Train=0.0009 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.73% R²=0.838 | Val(full) RMSE=0.6 MAE=0.5 MAPE=12.69% R²=0.908 | LR=0.000497 | Time=37.3s
# Ep25 Train=0.0009 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.04% R²=0.854 | Val(full) RMSE=0.6 MAE=0.5 MAPE=11.89% R²=0.913 | LR=0.000495 | Time=35.2s
# Ep26 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.24% R²=0.861 | Val(full) RMSE=0.6 MAE=0.4 MAPE=12.04% R²=0.915 | LR=0.000493 | Time=36.1s
# Ep27 Train=0.0009 | Val=0.0007 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.63% R²=0.830 | Val(full) RMSE=0.7 MAE=0.5 MAPE=12.96% R²=0.887 | LR=0.000491 | Time=40.5s
# Ep28 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.25% R²=0.838 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11.47% R²=0.918 | LR=0.000488 | Time=36.1s
# Ep29 Train=0.0009 | Val=0.0007 | Val(last) RMSE=0.9 MAE=0.7 MAPE=17.08% R²=0.796 | Val(full) RMSE=0.7 MAE=0.5 MAPE=13.19% R²=0.889 | LR=0.000485 | Time=37.4s
# Ep30 Train=0.0009 | Val=0.0005 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15.04% R²=0.858 | Val(full) RMSE=0.6 MAE=0.4 MAPE=11
Train=0.0008 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.97% R²=0.902 | Val(full) RMSE=0.4 MAE=0.3 MAPE=9.15% R²=0.954 | LR=0.000230 | Time=38.8s
# Ep63 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.7 MAE=0.5 MAPE=13.13% R²=0.894 | Val(full) RMSE=0.5 MAE=0.3 MAPE=9.30% R²=0.950 | LR=0.000221 | Time=38.5s
# Ep64 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=13.03% R²=0.900 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.97% R²=0.954 | LR=0.000211 | Time=41.2s
# Ep65 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=13.07% R²=0.899 | Val(full) RMSE=0.5 MAE=0.3 MAPE=9.38% R²=0.950 | LR=0.000201 | Time=41.5s
# Ep66 Train=0.0007 | Val=0.0004 | Val(last) RMSE=0.7 MAE=0.5 MAPE=13.58% R²=0.891 | Val(full) RMSE=0.5 MAE=0.4 MAPE=9.99% R²=0.944 | LR=0.000192 | Time=39.4s
# Ep67 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=13.15% R²=0.899 | Val(full) RMSE=0.5 MAE=0.4 MAPE=9.41% R²=0.950 | LR=0.000182 | Time=38.1s
# Ep68 Train=0.0007 | Val=0.0004 | Val(last) RMSE=0.6 MAE=0.5 MAPE=13.05% R²=0.900 | Val(full) RMSE=0.5 MAE=0.4 MAPE=9.87% R²=0.946 | LR=0.000173 | Time=37.8s
# Ep69 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=13.41% R²=0.897 | Val(full) RMSE=0.5 MAE=0.3 MAPE=9.81% R²=0.949 | LR=0.000163 | Time=38.4s
# Ep70 Train=0.0007 | Val=0.0004 | Val(last) RMSE=0.7 MAE=0.5 MAPE=14.52% R²=0.883 | Val(full) RMSE=0.5 MAE=0.4 MAPE=10.79% R²=0.940 | LR=0.000154 | Time=38.3s
# Ep71 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.88% R²=0.901 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.82% R²=0.958 | LR=0.000145 | Time=38.2s
# Ep72 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.7 MAE=0.5 MAPE=13.38% R²=0.893 | Val(full) RMSE=0.5 MAE=0.4 MAPE=9.53% R²=0.947 | LR=0.000137 | Time=40.7s
# Ep73 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.89% R²=0.901 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.74% R²=0.958 | LR=0.000128 | Time=38.0s
# Ep74 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=13.08% R²=0.900 | Val(full) RMSE=0.4 MAE=0.3 MAPE=9.18% R²=0.954 | LR=0.000119 | Time=38.1s
# Ep75 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.80% R²=0.905 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.61% R²=0.961 | LR=0.000111 | Time=38.8s
# Ep76 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.68% R²=0.902 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.57% R²=0.960 | LR=0.000103 | Time=41.0s
# Ep77 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.59% R²=0.904 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.48% R²=0.958 | LR=0.000095 | Time=40.4s
# Ep78 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=13.05% R²=0.898 | Val(full) RMSE=0.4 MAE=0.3 MAPE=9.40% R²=0.951 | LR=0.000088 | Time=37.0s
# Ep79 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.7 MAE=0.5 MAPE=13.62% R²=0.892 | Val(full) RMSE=0.4 MAE=0.3 MAPE=9.54% R²=0.952 | LR=0.000080 | Time=35.5s
# Ep80 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.73% R²=0.900 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.50% R²=0.958 | LR=0.000073 | Time=37.5s
# Ep81 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.66% R²=0.905 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.51% R²=0.961 | LR=0.000066 | Time=36.1s
# Ep82 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.77% R²=0.904 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.32% R²=0.962 | LR=0.000060 | Time=35.0s
# Ep83 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.33% R²=0.911 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.06% R²=0.965 | LR=0.000054 | Time=36.9s
# Ep84 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.79% R²=0.902 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.55% R²=0.960 | LR=0.000048 | Time=35.3s
# Ep85 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.41% R²=0.910 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.08% R²=0.964 | LR=0.000042 | Time=36.0s
# Ep86 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.65% R²=0.903 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.13% R²=0.963 | LR=0.000037 | Time=38.5s
# Ep87 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.95% R²=0.901 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.47% R²=0.960 | LR=0.000032 | Time=37.0s
# Ep88 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.98% R²=0.901 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.47% R²=0.961 | LR=0.000027 | Time=36.1s
# Ep89 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.58% R²=0.907 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.23% R²=0.962 | LR=0.000023 | Time=36.0s
# Ep90 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.69% R²=0.904 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.17% R²=0.963 | LR=0.000019 | Time=34.6s
# Ep91 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.55% R²=0.906 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.01% R²=0.965 | LR=0.000015 | Time=38.8s
# Ep92 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.50% R²=0.906 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.05% R²=0.964 | LR=0.000012 | Time=37.5s
# Ep93 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.73% R²=0.905 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.36% R²=0.962 | LR=0.000009 | Time=35.9s
# Ep94 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.54% R²=0.907 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.17% R²=0.963 | LR=0.000007 | Time=37.9s
# Ep95 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.41% R²=0.909 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.06% R²=0.965 | LR=0.000005 | Time=39.1s
# Ep96 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.40% R²=0.910 | Val(full) RMSE=0.4 MAE=0.3 MAPE=7.94% R²=0.966 | LR=0.000003 | Time=37.3s
# Ep97 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.43% R²=0.910 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.01% R²=0.966 | LR=0.000002 | Time=35.7s
# Ep98 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.62% R²=0.906 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.17% R²=0.964 | LR=0.000001 | Time=35.6s
# Ep99 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.82% R²=0.903 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.46% R²=0.961 | LR=0.000000 | Time=36.9s
# Ep100 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.61% R²=0.906 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.16% R²=0.964 | LR=0.000000 | Time=38.6s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (front-weighted MSE): 0.0049
#
# Final Test Metrics (last step, m/s): MSE=2.88, RMSE=1.70, MAE=1.32, MAPE=23.65, R²=-0.5416, Adj R²=-0.5436
# Final Test Metrics (full 24h path): RMSE=1.75, MAE=1.32, MAPE=23.83, R²=0.9636
# Hourly-averaged RMSE by lead hour (0→23):
# [1.03, 1.13, 1.27, 1.44, 1.6 , 1.75, 1.86, 1.94, 1.98, 1.99, 1.98, 1.95,
#  1.92, 1.88, 1.85, 1.83, 1.82, 1.81, 1.8 , 1.78, 1.76, 1.73, 1.71, 1.7 ]
# Avg inference latency: 0.42 ms/batch • 0.42 ms/sample

# %%
# this one uses centered rolling mean for training and validation, and WS50M for testing.
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model
# ----------------------------
class CNN1D_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 channels=32, ksize=9, pool=2, p_drop=0.1, hidden=64):
        super().__init__()
        pad = (ksize - 1) // 2
        self.conv = nn.Conv1d(n_features, channels, kernel_size=ksize, padding=pad, bias=True)
        self.pool = nn.AvgPool1d(pool)
        self.bn   = nn.BatchNorm1d(channels)
        self.do   = nn.Dropout(p_drop)

        conv_T = window // pool
        if conv_T <= 0:
            raise ValueError("Pooling/window configuration invalid; pooled length <= 0.")
        self.flat_dim = channels * conv_T

        concat_dim = self.flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon)
        )

    def forward(self, x):
        B, W, F = x.shape
        h = self.conv(x.permute(0, 2, 1))  # [B,C,W]
        h = self.pool(h)                   # [B,C,W/p]
        h = self.bn(h)
        h = self.do(h)
        h = h.reshape(B, -1)               # [B, C*(W/p)]
        z = torch.cat([h, x[:, -1, :]], dim=1)  # concat last-step features
        yhat = self.head(z)                     # [B,H]
        return yhat.unsqueeze(-1)               # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset (the CSV that already contains WS50M_low_freq_7d may be overridden below)
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final_rolling_mean_7d.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).copy()

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # ----------------------------
    # Splits (you had these dates)
    # ----------------------------
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # ----------------------------
    # Create both centered and causal low-frequency columns,
    # then set WS50M_low_freq_7d = centered for train+val (<= val_end),
    # and = causal for test (> val_end)
    # ----------------------------
    roll_window = 2016  # ~7 days at 5-min cadence
    # centered uses future points within window
    df['WS50M_low_freq_centered'] = df['WS50M'].rolling(window=roll_window, min_periods=1, center=True).mean()
    # causal uses only past points
    df['WS50M_low_freq_causal']  = df['WS50M'] #.rolling(window=roll_window, min_periods=1, center=False).mean()

    # Overwrite the working feature so train+val get centered, test gets causal
    df['WS50M_low_freq_7d'] = df['WS50M_low_freq_centered'].copy()
    df.loc[df.index > val_end, 'WS50M_low_freq_7d'] = df.loc[df.index > val_end, 'WS50M_low_freq_causal']

    # drop helper cols to keep df tidy
    df.drop(columns=['WS50M_low_freq_centered', 'WS50M_low_freq_causal'], inplace=True)

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN1D_Forecaster(
        n_features=n_features, window=W, horizon=H,
        channels=64, ksize=9, pool=2, p_drop=0.2, hidden=128
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        r2_all  = r2_score(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% R²={r2_all:.3f} | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    mape = smape(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)
    mape_all = smape(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, MAPE={mape:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}, MAPE={mape_all:.2f}, R²={r2_all:.4f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 174913, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-02 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 8303456
# Ep01 Train=0.0092 | Val=0.0023 | Val(last) RMSE=1.3 MAE=1.0 MAPE=24.09% R²=0.609 | Val(full) RMSE=1.2 MAE=0.9 MAPE=24.02% R²=0.655 | LR=0.000050 | Time=38.3s
# Ep02 Train=0.0021 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.16% R²=0.742 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.18% R²=0.830 | LR=0.000075 | Time=37.4s
# Ep03 Train=0.0016 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.89% R²=0.761 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.11% R²=0.836 | LR=0.000100 | Time=38.5s
# Ep04 Train=0.0017 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.16% R²=0.746 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.24% R²=0.830 | LR=0.000125 | Time=36.4s
# Ep05 Train=0.0016 | Val=0.0011 | Val(last) RMSE=1.1 MAE=0.8 MAPE=20.77% R²=0.724 | Val(full) RMSE=0.8 MAE=0.6 MAPE=17.20% R²=0.831 | LR=0.000150 | Time=37.4s
# Ep06 Train=0.0016 | Val=0.0016 | Val(last) RMSE=1.1 MAE=0.9 MAPE=21.44% R²=0.702 | Val(full) RMSE=1.0 MAE=0.8 MAPE=19.82% R²=0.756 | LR=0.000175 | Time=37.2s
# Ep07 Train=0.0016 | Val=0.0011 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.16% R²=0.753 | Val(full) RMSE=0.8 MAE=0.7 MAPE=17.55% R²=0.828 | LR=0.000200 | Time=37.0s
# Ep08 Train=0.0016 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.8 MAPE=20.00% R²=0.751 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.50% R²=0.845 | LR=0.000225 | Time=38.0s
# Ep09 Train=0.0016 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.84% R²=0.766 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.30% R²=0.851 | LR=0.000250 | Time=39.9s
# Ep10 Train=0.0016 | Val=0.0018 | Val(last) RMSE=1.1 MAE=0.8 MAPE=21.05% R²=0.727 | Val(full) RMSE=1.0 MAE=0.8 MAPE=20.47% R²=0.749 | LR=0.000275 | Time=35.4s
# Ep11 Train=0.0016 | Val=0.0017 | Val(last) RMSE=1.1 MAE=0.8 MAPE=21.08% R²=0.729 | Val(full) RMSE=1.0 MAE=0.8 MAPE=19.48% R²=0.765 | LR=0.000300 | Time=36.5s
# Ep12 Train=0.0016 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.85% R²=0.764 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.77% R²=0.847 | LR=0.000325 | Time=33.2s
# Ep13 Train=0.0016 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.7 MAPE=19.46% R²=0.767 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.52% R²=0.845 | LR=0.000350 | Time=32.8s
# Ep14 Train=0.0016 | Val=0.0009 | Val(last) RMSE=0.9 MAE=0.7 MAPE=18.79% R²=0.787 | Val(full) RMSE=0.8 MAE=0.6 MAPE=16.10% R²=0.856 | LR=0.000375 | Time=35.8s
# Ep15 Train=0.0017 | Val=0.0012 | Val(last) RMSE=1.0 MAE=0.8 MAPE=19.93% R²=0.749 | Val(full) RMSE=0.8 MAE=0.7 MAPE=17.59% R²=0.827 | LR=0.000400 | Time=33.5s
# Ep16 Train=0.0016 | Val=0.0023 | Val(last) RMSE=1.3 MAE=1.1 MAPE=24.97% R²=0.575 | Val(full) RMSE=1.2 MAE=1.0 MAPE=23.13% R²=0.657 | LR=0.000425 | Time=34.5s
# Ep17 Train=0.0015 | Val=0.0009 | Val(last) RMSE=0.9 MAE=0.7 MAPE=19.10% R²=0.785 | Val(full) RMSE=0.7 MAE=0.6 MAPE=15.77% R²=0.863 | LR=0.000450 | Time=34.4s
# Ep18 Train=0.0014 | Val=0.0009 | Val(last) RMSE=0.9 MAE=0.7 MAPE=19.09% R²=0.782 | Val(full) RMSE=0.8 MAE=0.6 MAPE=15.88% R²=0.860 | LR=0.000475 | Time=35.2s
# Ep19 Train=0.0014 | Val=0.0008 | Val(last) RMSE=0.9 MAE=0.7 MAPE=17.77% R²=0.799 | Val(full) RMSE=0.7 MAE=0.6 MAPE=14.67% R²=0.874 | LR=0.000500 | Time=37.1s
# Ep20 Train=0.0012 | Val=0.0010 | Val(last) RMSE=1.0 MAE=0.7 MAPE=18.69% R²=0.770 | Val(full) RMSE=0.8 MAE=0.6 MAPE=15.67% R²=0.851 | LR=0.000500 | Time=33.8s
# Ep21 Train=0.0011 | Val=0.0007 | Val(last) RMSE=0.9 MAE=0.7 MAPE=18.23% R²=0.790 | Val(full) RMSE=0.7 MAE=0.5 MAPE=13.96% R²=0.889 | LR=0.000500 | Time=33.9s
# Ep22 Train=0.0010 | Val=0.0007 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.27% R²=0.844 | Val(full) RMSE=0.7 MAE=0.5 MAPE=12.92% R²=0.896 | LR=0.000499 | Time=35.0s
# Ep23 Train=0.0010 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=16.27% R²=0.843 | Val(full) RMSE=0.6 MAE=0.5 MAPE=13.22% R²=0.902 | LR=0.000498 | Time=33.7s
# Ep24 Train=0.0009 | Val=0.0006 | Val(last) RMSE=0.8 MAE=0.6 MAPE=15
R²=0.904 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.48% R²=0.958 | LR=0.000095 | Time=37.2s
# Ep78 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=13.05% R²=0.898 | Val(full) RMSE=0.4 MAE=0.3 MAPE=9.40% R²=0.951 | LR=0.000088 | Time=37.6s
# Ep79 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.7 MAE=0.5 MAPE=13.62% R²=0.892 | Val(full) RMSE=0.4 MAE=0.3 MAPE=9.54% R²=0.952 | LR=0.000080 | Time=33.8s
# Ep80 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.73% R²=0.900 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.50% R²=0.958 | LR=0.000073 | Time=33.9s
# Ep81 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.66% R²=0.905 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.51% R²=0.961 | LR=0.000066 | Time=35.2s
# Ep82 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.77% R²=0.904 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.32% R²=0.962 | LR=0.000060 | Time=34.6s
# Ep83 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.33% R²=0.911 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.06% R²=0.965 | LR=0.000054 | Time=32.8s
# Ep84 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.79% R²=0.902 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.55% R²=0.960 | LR=0.000048 | Time=32.2s
# Ep85 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.41% R²=0.910 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.08% R²=0.964 | LR=0.000042 | Time=33.0s
# Ep86 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.65% R²=0.903 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.13% R²=0.963 | LR=0.000037 | Time=34.6s
# Ep87 Train=0.0007 | Val=0.0003 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.95% R²=0.901 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.47% R²=0.960 | LR=0.000032 | Time=36.2s
# Ep88 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.98% R²=0.901 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.47% R²=0.961 | LR=0.000027 | Time=32.7s
# Ep89 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.58% R²=0.907 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.23% R²=0.962 | LR=0.000023 | Time=31.9s
# Ep90 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.69% R²=0.904 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.17% R²=0.963 | LR=0.000019 | Time=33.3s
# Ep91 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.55% R²=0.906 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.01% R²=0.965 | LR=0.000015 | Time=32.4s
# Ep92 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.50% R²=0.906 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.05% R²=0.964 | LR=0.000012 | Time=31.5s
# Ep93 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.73% R²=0.905 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.36% R²=0.962 | LR=0.000009 | Time=33.2s
# Ep94 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.54% R²=0.907 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.17% R²=0.963 | LR=0.000007 | Time=32.9s
# Ep95 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.41% R²=0.909 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.06% R²=0.965 | LR=0.000005 | Time=32.7s
# Ep96 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.40% R²=0.910 | Val(full) RMSE=0.4 MAE=0.3 MAPE=7.94% R²=0.966 | LR=0.000003 | Time=32.8s
# Ep97 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.43% R²=0.910 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.01% R²=0.966 | LR=0.000002 | Time=32.7s
# Ep98 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.62% R²=0.906 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.17% R²=0.964 | LR=0.000001 | Time=33.5s
# Ep99 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.82% R²=0.903 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.46% R²=0.961 | LR=0.000000 | Time=33.6s
# Ep100 Train=0.0007 | Val=0.0002 | Val(last) RMSE=0.6 MAE=0.5 MAPE=12.61% R²=0.906 | Val(full) RMSE=0.4 MAE=0.3 MAPE=8.16% R²=0.964 | LR=0.000000 | Time=32.4s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (front-weighted MSE): 0.3007
#
# Final Test Metrics (last step, m/s): MSE=178.61, RMSE=13.36, MAE=10.09, MAPE=106.81, R²=-94.6198, Adj R²=-94.7459
# Final Test Metrics (full 24h path): RMSE=13.48, MAE=9.82, MAPE=102.85, R²=0.9636
# Hourly-averaged RMSE by lead hour (0→23):
# [ 8.64,  9.84, 11.4 , 13.07, 14.52, 15.47, 15.87, 15.71, 15.21, 14.6 ,
#  14.01, 13.59, 13.36, 13.18, 12.96, 12.79, 12.76, 12.89, 13.16, 13.43,
#  13.64, 13.73, 13.71, 13.5 ]
# Avg inference latency: 0.86 ms/batch • 0.86 ms/sample

# %% [markdown]
# ### 2DCNN

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model: 2D CNN forecaster (two Conv2d blocks)
# ----------------------------
class CNN2D_Forecaster(nn.Module):
    """
    Input [B, W, F]
      -> Unsqueeze -> [B,1,W,F]
      -> Conv2d(k_t1 x k_f1) + ReLU -> AvgPool2d(time only) -> BN -> Dropout
      -> Conv2d(k_t2 x k_f2) + ReLU -> AvgPool2d(time only) -> BN -> Dropout
      -> Flatten
      -> Concatenate with last-step raw features [B, F]
      -> MLP head -> horizon
      -> Output [B, H, 1]
    """
    def __init__(
        self,
        n_features: int,
        window: int,
        horizon: int,
        # block 1
        channels1: int = 64,
        ksize_t1: int = 9,
        ksize_f1: int = 3,
        pool_t1: int = 2,
        # block 2
        channels2: int = 64,
        ksize_t2: int = 5,
        ksize_f2: int = 3,
        pool_t2: int = 2,
        # head/regularization
        p_drop: float = 0.2,
        hidden: int = 256,
    ):
        super().__init__()
        if pool_t1 < 1 or pool_t2 < 1:
            raise ValueError("pool_t1 and pool_t2 must be >= 1")
        if (window // (pool_t1 * pool_t2)) <= 0:
            raise ValueError("window must be >= pool_t1 * pool_t2")

        self.n_features = n_features
        self.window = window
        self.horizon = horizon

        # -------- Block 1 --------
        pad_t1 = (ksize_t1 - 1) // 2
        pad_f1 = (ksize_f1 - 1) // 2
        self.conv1 = nn.Conv2d(
            in_channels=1,
            out_channels=channels1,
            kernel_size=(ksize_t1, ksize_f1),
            padding=(pad_t1, pad_f1),
            bias=True,
        )
        self.act1  = nn.ReLU(inplace=True)
        self.pool1 = nn.AvgPool2d(kernel_size=(pool_t1, 1))  # downsample time only
        self.bn1   = nn.BatchNorm2d(channels1)
        self.do1   = nn.Dropout(p_drop)

        # -------- Block 2 --------
        pad_t2 = (ksize_t2 - 1) // 2
        pad_f2 = (ksize_f2 - 1) // 2
        self.conv2 = nn.Conv2d(
            in_channels=channels1,
            out_channels=channels2,
            kernel_size=(ksize_t2, ksize_f2),
            padding=(pad_t2, pad_f2),
            bias=True,
        )
        self.act2  = nn.ReLU(inplace=True)
        self.pool2 = nn.AvgPool2d(kernel_size=(pool_t2, 1))  # downsample time only
        self.bn2   = nn.BatchNorm2d(channels2)
        self.do2   = nn.Dropout(p_drop)

        # Flattened size after both pools
        conv_T = window // (pool_t1 * pool_t2)  # time length after two pools
        flat_dim = channels2 * conv_T * n_features

        # Head (concat flattened conv features with last-step raw features)
        concat_dim = flat_dim + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, hidden),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(hidden, horizon),
        )

        # Init
        for m in [self.conv1, self.conv2]:
            nn.init.kaiming_uniform_(m.weight, a=math.sqrt(5))
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        for m in self.head:
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: [B, W, F]
        B, W, F = x.shape
        h = x.unsqueeze(1)      # [B,1,W,F]

        # Block 1
        h = self.conv1(h)
        h = self.act1(h)
        h = self.pool1(h)
        h = self.bn1(h)
        h = self.do1(h)

        # Block 2
        h = self.conv2(h)
        h = self.act2(h)
        h = self.pool2(h)
        h = self.bn2(h)
        h = self.do2(h)

        # Flatten
        h = h.reshape(B, -1)

        # Concatenate with last-step raw features
        x_last = x[:, -1, :]      # [B,F]
        z = torch.cat([h, x_last], dim=1)

        # Head
        yhat = self.head(z)       # [B,H]
        return yhat.unsqueeze(-1) # [B,H,1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).fillna(0)

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # 2D-CNN model + optimizer + loss + scheduler
    # ----------------------------
    model = CNN2D_Forecaster(
        n_features=n_features,
        window=W,
        horizon=H,
        channels1=64, ksize_t1=9, ksize_f1=3, pool_t1=2,
        channels2=64, ksize_t2=5, ksize_f2=3, pool_t2=2,
        p_drop=0.2, hidden=256
    ).to(device)

    # (Optional) tighter BN momentum for long sequences
    for m in model.modules():
        if isinstance(m, nn.BatchNorm2d):
            m.momentum = 0.05

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()

# %% [markdown]
# ### LSTM

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# LSTM Model
# ----------------------------
class LSTM_Forecaster(nn.Module):
    def __init__(self, n_features, window, horizon,
                 enc1=256, enc2=128,
                 latent_dim=64, p_drop=0.2):
        super().__init__()
        self.n_features = n_features
        self.window = window
        self.horizon = horizon

        # Encoder
        self.enc1 = nn.LSTM(input_size=n_features, hidden_size=enc1, batch_first=True)
        self.enc2 = nn.LSTM(input_size=enc1,       hidden_size=enc2, batch_first=True)
        self.enc_ln = nn.LayerNorm(enc2)

        # Attention pooling over encoder sequence -> context
        self.attn = nn.Sequential(
            nn.Linear(enc2, enc2),
            nn.Tanh(),
            nn.Linear(enc2, 1)
        )

        # context -> latent
        self.to_latent = nn.Sequential(
            nn.Linear(enc2, latent_dim),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(latent_dim, latent_dim)
        )

        # Forecast head (TOTAL for H steps)
        # condition on [latent || last_observed_features] to anchor short-term
        f_in = latent_dim + n_features
        self.forecast = nn.Sequential(
            nn.Linear(f_in, 128),
            nn.ReLU(),
            nn.Dropout(p_drop),
            nn.Linear(128, horizon)  # -> [B, H]
        )

    def forward(self, x):
        """
        x: [B, W, F]
        return: yhat [B, H, 1]  (forecast output)
        """
        B, W, F = x.shape

        # Encode
        h1, _ = self.enc1(x)               # [B,W,enc1]
        h2, _ = self.enc2(h1)              # [B,W,enc2]
        h2 = self.enc_ln(h2)

        # Attention pooling across time
        a = self.attn(h2)                  # [B,W,1]
        a = torch.softmax(a, dim=1)
        ctx = (a * h2).sum(dim=1)          # [B,enc2]

        # Latent
        z = self.to_latent(ctx)            # [B,latent]

        # Forecast
        x_last = x[:, -1, :]               # [B,F]
        f_in = torch.cat([z, x_last], dim=1)   # [B,latent+F]
        yhat = self.forecast(f_in).unsqueeze(-1)  # [B,H,1]
        return yhat

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final_withTyphoon.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).fillna(0)

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # LSTM model
    # ----------------------------
    model = LSTM_Forecaster(n_features=n_features, window=W, horizon=H,
        enc1=256, enc2=128, latent_dim=64, p_drop=0.2
        ).to(device)

    # (Optional) tighter BN momentum for long sequences
    for m in model.modules():
        if isinstance(m, nn.BatchNorm2d):
            m.momentum = 0.05

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 174913, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-02 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 550433
# Ep01 Train=0.0067 | Val=0.0032 | Val(last) RMSE=1.6 MAE=1.2 MAPE=28.75% R²=0.384 | Val(full) RMSE=1.4 MAE=1.1 MAPE=26.33% | LR=0.000050 | Time=601.6s
# Ep02 Train=0.0024 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.23% R²=0.499 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.28% | LR=0.000075 | Time=607.9s
# Ep03 Train=0.0020 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.26% R²=0.505 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.16% | LR=0.000100 | Time=591.9s
# Ep04 Train=0.0019 | Val=0.0020 | Val(last) RMSE=1.4 MAE=1.1 MAPE=25.75% R²=0.519 | Val(full) RMSE=1.1 MAE=0.8 MAPE=21.08% | LR=0.000125 | Time=579.7s
# Ep05 Train=0.0018 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=25.99% R²=0.523 | Val(full) RMSE=1.1 MAE=0.8 MAPE=21.05% | LR=0.000150 | Time=574.5s
# Ep06 Train=0.0018 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=25.81% R²=0.528 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.88% | LR=0.000175 | Time=577.1s
# Ep07 Train=0.0017 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.0 MAPE=25.76% R²=0.537 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.48% | LR=0.000200 | Time=576.2s
# Ep08 Train=0.0017 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.0 MAPE=25.64% R²=0.546 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.34% | LR=0.000225 | Time=581.6s
# Ep09 Train=0.0017 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.0 MAPE=25.74% R²=0.535 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.41% | LR=0.000250 | Time=593.5s
# Ep10 Train=0.0017 | Val=0.0018 | Val(last) RMSE=1.4 MAE=1.1 MAPE=25.90% R²=0.532 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.70% | LR=0.000275 | Time=591.1s

# %% [markdown]
# ### TRANSFORMER

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import time, random, math
from typing import List
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# ----------------------------
# Reproducibility
# ----------------------------
def set_seed(seed: int = 1337):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(1337)

# ----------------------------
# Dataset
# ----------------------------
class LoadWindowDataset(Dataset):
    def __init__(self, data_array, window, horizon):
        self.data = data_array
        self.window, self.horizon = window, horizon
        self.n = data_array.shape[0] - window - horizon + 1
        if self.n <= 0:
            raise ValueError("Window/horizon too large for data length.")

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        x = self.data[idx: idx + self.window]                                        # [W, F]
        y_seq = self.data[idx + self.window: idx + self.window + self.horizon, -1:] # [H, 1]
        return torch.from_numpy(x).float(), torch.from_numpy(y_seq).float()

# ----------------------------
# Model: Transformer forecaster
# ----------------------------
class PositionalEncoding(nn.Module):
    """Standard sinusoidal PE (batch_first: [B, T, D])."""
    def __init__(self, d_model: int, max_len: int = 10000, dropout: float = 0.0):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        pe = torch.zeros(max_len, d_model)  # [T, D]
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)  # [T, 1]
        div_term = torch.exp(torch.arange(0, d_model, 2, dtype=torch.float32) * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # even
        pe[:, 1::2] = torch.cos(position * div_term)  # odd
        pe = pe.unsqueeze(0)  # [1, T, D]
        self.register_buffer('pe', pe, persistent=False)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: [B, T, D]
        T = x.size(1)
        x = x + self.pe[:, :T, :]
        return self.dropout(x)

class TransformerForecaster(nn.Module):
    """
    Encoder-only Transformer:
      - Input: [B, W, F]
      - Linear embed: F -> d_model
      - Add positional encodings
      - TransformerEncoder (batch_first)
      - Temporal mean pool -> [B, d_model]
      - Concatenate with raw last-step features [B, F]
      - MLP head -> horizon
      - Output: [B, H, 1]
    """
    def __init__(
        self,
        n_features: int,
        window: int,
        horizon: int,
        d_model: int = 128,
        nhead: int = 8,
        num_layers: int = 4,
        dim_feedforward: int = 256,
        p_drop: float = 0.1
    ):
        super().__init__()
        assert d_model % nhead == 0, "d_model must be divisible by nhead"
        self.n_features = n_features
        self.window = window
        self.horizon = horizon
        self.d_model = d_model

        self.input_proj = nn.Linear(n_features, d_model)
        self.pos_enc = PositionalEncoding(d_model=d_model, max_len=window, dropout=p_drop)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=p_drop,
            batch_first=True,
            activation='gelu',
            norm_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.enc_ln = nn.LayerNorm(d_model)

        # Head after pooling + concat(last-step raw features)
        concat_dim = d_model + n_features
        self.head = nn.Sequential(
            nn.Linear(concat_dim, 2 * d_model),
            nn.GELU(),
            nn.Dropout(p_drop),
            nn.Linear(2 * d_model, horizon)
        )

        # Initialize
        self._reset_parameters()

    def _reset_parameters(self):
        nn.init.xavier_uniform_(self.input_proj.weight)
        nn.init.zeros_(self.input_proj.bias)
        for m in self.head:
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: [B, W, F]
        B, W, F = x.shape
        h = self.input_proj(x)            # [B, W, D]
        h = self.pos_enc(h)               # [B, W, D]
        h = self.encoder(h)               # [B, W, D]
        h = self.enc_ln(h)

        # Temporal mean pooling
        h_pool = h.mean(dim=1)            # [B, D]

        # Skip: last-step raw features
        x_last = x[:, -1, :]              # [B, F]
        z = torch.cat([h_pool, x_last], dim=1)  # [B, D+F]

        yhat = self.head(z)               # [B, H]
        return yhat.unsqueeze(-1)         # [B, H, 1]

# ----------------------------
# Early Stopping (CPU snapshot)
# ----------------------------
class EarlyStopping:
    def __init__(self, patience=25, delta=1e-4, verbose=True):
        self.patience, self.delta, self.verbose = patience, delta, verbose
        self.best_loss = np.inf
        self.wait = 0
        self.should_stop = False
        self.best_state = None

    def step(self, val_loss, model=None):
        improved = val_loss < self.best_loss - self.delta
        if improved:
            self.best_loss = val_loss
            self.wait = 0
            if model is not None:
                self.best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.should_stop = True
                if self.verbose:
                    print(f"EarlyStopping: stop after {self.patience} epochs.")
        return improved

# ----------------------------
# Helpers
# ----------------------------
def infer_5min_freq(index: pd.DatetimeIndex) -> pd.Timedelta:
    freq = pd.infer_freq(index)
    if freq is None:
        diffs = pd.Series(index[1:] - index[:-1])
        step = diffs.mode().iloc[0] if not diffs.empty else pd.Timedelta(minutes=5)
    else:
        step = pd.Timedelta(freq)
    if step != pd.Timedelta(minutes=5):
        print(f"[WARN] Detected step={step}. Script assumes 5-minute cadence.")
    return step

def make_calendar_features(idx: pd.DatetimeIndex) -> pd.DataFrame:
    hour = idx.hour + idx.minute/60.0
    hod = hour / 24.0
    dow = idx.dayofweek.astype(float) / 7.0
    doy = (idx.dayofyear.astype(float) - 1.0) / 366.0
    cal = pd.DataFrame(index=idx)
    cal["hod_sin"] = np.sin(2*np.pi*hod); cal["hod_cos"] = np.cos(2*np.pi*hod)
    cal["dow_sin"] = np.sin(2*np.pi*dow); cal["dow_cos"] = np.cos(2*np.pi*dow)
    cal["doy_sin"] = np.sin(2*np.pi*doy); cal["doy_cos"] = np.cos(2*np.pi*doy)
    return cal

def cosine_warmup_scheduler(optimizer, warmup_epochs, total_epochs):
    def lr_lambda(epoch):
        if epoch < warmup_epochs:
            return (epoch + 1) / float(warmup_epochs)
        denom = max(float(total_epochs - warmup_epochs), 1.0)
        progress = min(max((epoch - warmup_epochs) / denom, 0.0), 1.0)
        return 0.5 * (1.0 + math.cos(math.pi * progress))
    return torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

def smape(y_true, y_pred, eps=1e-6):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return 100 * np.mean(
        2.0 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred) + eps)
    )

# ----------------------------
# Main
# ----------------------------
def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load dataset
    df = pd.read_csv(
        'Dataset/Wind/wind_forecasting_final.csv',
        parse_dates=['DATETIME'],
        index_col='DATETIME'
    ).fillna(0)

    # Target column
    target_col = 'WS50M'
    df['TARGET'] = df[target_col]

    # --- Use all the features you already have ---
    # Drop target from the features so it's only in TARGET
    feature_cols = [c for c in df.columns if c not in ['TARGET', target_col]]

    X_exo = df[feature_cols].copy()

    # Handle inf/nan
    X_exo.replace([np.inf, -np.inf], np.nan, inplace=True)
    finite_rows = np.isfinite(X_exo.to_numpy()).all(axis=1)
    finite_target = np.isfinite(df['TARGET'].to_numpy())
    valid_mask = finite_rows & finite_target

    df    = df.loc[valid_mask].copy()
    X_exo = X_exo.loc[valid_mask].copy()

    # Window end timestamps
    W = 7 * 24 * 12   # lookback
    H = 1 * 24 * 12   # horizon
    times = df.index[W + H - 1 :]

    # Splits
    train_end = pd.Timestamp('2023-12-25 23:55:00')
    val_end   = pd.Timestamp('2024-11-25 23:55:00')

    # --- Scaling ---
    train_mask_for_scaler = df.index <= train_end
    feat_scaler = MinMaxScaler()
    feat_scaler.fit(X_exo.loc[train_mask_for_scaler])
    X_feats_scaled = feat_scaler.transform(X_exo)

    tgt_scaler = MinMaxScaler()
    tgt_scaler.fit(df.loc[train_mask_for_scaler, ['TARGET']])
    y_scaled = tgt_scaler.transform(df[['TARGET']])

    # Final array
    data = np.hstack([X_feats_scaled, y_scaled])
    n_features = data.shape[1]  # all features + target

    # ----------------------------
    # Indexing with optional stride (speeds up training)
    # ----------------------------
    stride = 6  # Smaller stride for wind data (changes faster)
    all_idx = np.arange(len(times))
    train_idx = all_idx[times <= train_end][::stride]
    val_idx   = all_idx[(times > train_end) & (times <= val_end)][::stride]
    test_idx  = all_idx[times > val_end]

    print(f"Train windows: {len(train_idx)}, Validation windows: {len(val_idx)}, Test windows: {len(test_idx)}")
    if len(times) > 0:
        print(f"First window ts: {times.min()}, Last: {times.max()}")
    assert len(train_idx) > 0, "No training windows found—check train_end vs. data coverage"
    assert len(val_idx) > 0, "No validation windows found—check val_end vs. data coverage"
    assert len(test_idx) > 0, "No test windows found—does your data extend past val_end?"

    # Datasets / Loaders
    full_ds = LoadWindowDataset(data, W, H)
    train_ds = Subset(full_ds, train_idx)
    val_ds   = Subset(full_ds, val_idx)
    test_ds  = Subset(full_ds, test_idx)

    pin = (device.type == 'cuda')
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    val_loader   = DataLoader(val_ds,   batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)
    test_loader  = DataLoader(test_ds,  batch_size=32, shuffle=False,
                              num_workers=2, pin_memory=pin, persistent_workers=True)

    # ----------------------------
    # Transformer model + optimizer + loss + scheduler
    # ----------------------------
    model = TransformerForecaster(
        n_features=n_features, window=W, horizon=H,
        d_model=128, nhead=8, num_layers=4, dim_feedforward=256, p_drop=0.1
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=5e-4, weight_decay=1e-5)
    es = EarlyStopping(patience=25, delta=1e-4, verbose=True)

    # Weighted loss for wind forecasting (emphasize short-term accuracy)
    weights = torch.linspace(1.5, 0.5, steps=H, device=device).view(1, H, 1)
    def weighted_mse(pred, target):
        return ((weights * (pred - target) ** 2).mean())
    f_fn = weighted_mse

    total_epochs = 100
    warmup_epochs = 20
    sched = cosine_warmup_scheduler(opt, warmup_epochs, total_epochs)

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("No. of parameters:", n_params)

    train_losses, val_losses = [], []

    # ----------------------------
    # Training Loop
    # ----------------------------
    for ep in range(1, total_epochs + 1):
        t0 = time.time()
        model.train()
        tl = 0.0
        for Xb, Yseqb in train_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            loss = f_fn(yhat, Yseqb)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            tl += loss.item() * Xb.size(0)
        train_losses.append(tl / len(train_ds))

        # Validation
        model.eval()
        vl, preds_last_scaled, truths_last_scaled = 0.0, [], []
        preds_full_scaled, truths_full_scaled = [], []
        with torch.no_grad():
            for Xb, Yseqb in val_loader:
                Xb, Yseqb = Xb.to(device), Yseqb.to(device)
                yhat = model(Xb)
                vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
                preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
                truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
                preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
                truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
        val_loss = vl / len(val_ds)
        val_losses.append(val_loss)

        # step LR ONCE PER EPOCH
        sched.step()

        # Inverse metrics
        preds = np.concatenate(preds_last_scaled)
        truths = np.concatenate(truths_last_scaled)
        inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
        inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]
        rm  = root_mean_squared_error(inv_t, inv_p)
        mae = mean_absolute_error(inv_t, inv_p)
        r2  = r2_score(inv_t, inv_p)
        mape = smape(inv_t, inv_p)

        pf = np.concatenate(preds_full_scaled, axis=0)
        tf = np.concatenate(truths_full_scaled, axis=0)
        inv_pf = tgt_scaler.inverse_transform(pf.reshape(-1,1))[:,0]
        inv_tf = tgt_scaler.inverse_transform(tf.reshape(-1,1))[:,0]
        rm_all  = root_mean_squared_error(inv_tf, inv_pf)
        mae_all = mean_absolute_error(inv_tf, inv_pf)
        mape_all = smape(inv_tf, inv_pf)

        cur_lr = opt.param_groups[0]['lr']
        print(f"Ep{ep:02d} Train={train_losses[-1]:.4f} | Val={val_loss:.4f} | "
              f"Val(last) RMSE={rm:.1f} MAE={mae:.1f} MAPE={mape:.2f}% R²={r2:.3f} | "
              f"Val(full) RMSE={rm_all:.1f} MAE={mae_all:.1f} MAPE={mape_all:.2f}% | "
              f"LR={cur_lr:.6f} | Time={time.time()-t0:.1f}s")

        _ = es.step(val_loss, model=model)
        if es.should_stop:
            if es.best_state is not None:
                model.load_state_dict(es.best_state)
                if es.verbose:
                    print("EarlyStopping: best weights restored.")
            break

    # ----------------------------
    # Loss curves
    # ----------------------------
    plt.figure(figsize=(8,4))
    plt.plot(train_losses, label='Train'); plt.plot(val_losses, label='Val')
    plt.xlabel('Epoch'); plt.ylabel('Weighted MSE'); plt.legend(); plt.title('Loss Curves (Wind Speed)')
    plt.tight_layout(); plt.show()

    # ----------------------------
    # Testing
    # ----------------------------
    model.eval()
    preds_last_scaled, truths_last_scaled = [], []
    preds_full_scaled, truths_full_scaled = [], []
    test_vl = 0.0
    with torch.no_grad():
        for Xb, Yseqb in test_loader:
            Xb, Yseqb = Xb.to(device), Yseqb.to(device)
            yhat = model(Xb)
            test_vl += f_fn(yhat, Yseqb).item() * Xb.size(0)
            preds_last_scaled.append(yhat[:, -1, 0].cpu().numpy())
            truths_last_scaled.append(Yseqb[:, -1, 0].cpu().numpy())
            preds_full_scaled.append(yhat[:, :, 0].cpu().numpy())
            truths_full_scaled.append(Yseqb[:, :, 0].cpu().numpy())
    test_loss = test_vl / len(test_ds)

    preds = np.concatenate(preds_last_scaled)
    truths = np.concatenate(truths_last_scaled)
    inv_p = tgt_scaler.inverse_transform(preds.reshape(-1,1))[:,0]
    inv_t = tgt_scaler.inverse_transform(truths.reshape(-1,1))[:,0]

    mse = mean_squared_error(inv_t, inv_p)
    rm  = root_mean_squared_error(inv_t, inv_p)
    mae = mean_absolute_error(inv_t, inv_p)
    r2  = r2_score(inv_t, inv_p)
    n, p = len(inv_t), (n_features - 1)
    adj_r2 = 1 - (1-r2)*(n-1)/max(n-p-1, 1)

    PH = np.concatenate(preds_full_scaled, axis=0)
    TH = np.concatenate(truths_full_scaled, axis=0)
    inv_pf = tgt_scaler.inverse_transform(PH.reshape(-1,1))[:,0]
    inv_tf = tgt_scaler.inverse_transform(TH.reshape(-1,1))[:,0]
    rm_all  = root_mean_squared_error(inv_tf, inv_pf)
    mae_all = mean_absolute_error(inv_tf, inv_pf)

    # Per-lead RMSE (hourly average over 24h)
    lead_rmse = []
    for h in range(PH.shape[1]):
        inv_ph = tgt_scaler.inverse_transform(PH[:, h].reshape(-1,1))[:,0]
        inv_th = tgt_scaler.inverse_transform(TH[:, h].reshape(-1,1))[:,0]
        lead_rmse.append(root_mean_squared_error(inv_th, inv_ph))
    hourly_rmse = np.array(lead_rmse).reshape(-1, 12).mean(axis=1)

    print(f"Test Loss (front-weighted MSE): {test_loss:.4f}")
    print(f"\nFinal Test Metrics (last step, m/s): "
          f"MSE={mse:.2f}, RMSE={rm:.2f}, MAE={mae:.2f}, R²={r2:.4f}, Adj R²={adj_r2:.4f}")
    print(f"Final Test Metrics (full 24h path): RMSE={rm_all:.2f}, MAE={mae_all:.2f}")
    print("Hourly-averaged RMSE by lead hour (0→23):")
    print(np.array2string(hourly_rmse, precision=2, separator=', '))

    # Inference latency (batch=1)
    _ = model(torch.randn(1, W, n_features).to(device))
    if device.type == 'cuda':
        torch.cuda.synchronize()
    Nruns = 100
    start = torch.cuda.Event(enable_timing=True); end = torch.cuda.Event(enable_timing=True)
    total_time = 0.0
    with torch.no_grad():
        for _ in range(Nruns):
            inp = torch.randn(1, W, n_features).to(device)
            start.record(); _ = model(inp); end.record()
            if device.type == 'cuda':
                torch.cuda.synchronize()
            total_time += start.elapsed_time(end) / 1000.0
    avg_batch = total_time / Nruns
    print(f"Avg inference latency: {avg_batch*1000:.2f} ms/batch • {avg_batch*1000:.2f} ms/sample")

    # Plots
    plt.figure(figsize=(10,4))
    plt.plot(times[test_idx], inv_t, label='Actual Wind Speed')
    plt.plot(times[test_idx], inv_p, label='Predicted Wind Speed', alpha=0.7)
    plt.title("24h-Ahead Wind Speed Forecast – Last-Step (Test)")
    plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
    plt.legend(); plt.tight_layout(); plt.show()

    # Show sample forecasts
    num_show = min(3, len(test_idx))
    if num_show > 0:
        Xb, Yseqb = next(iter(DataLoader(test_ds, batch_size=num_show, shuffle=False)))
        Xb = Xb.to(device)
        with torch.no_grad():
            yhat = model(Xb).cpu().numpy()
        ytrue = Yseqb.numpy()
        for i in range(min(num_show, Xb.size(0))):
            pred_i = tgt_scaler.inverse_transform(yhat[i, :, 0].reshape(-1,1))[:,0]
            true_i = tgt_scaler.inverse_transform(ytrue[i, :, 0].reshape(-1,1))[:,0]
            end_ts = times[test_idx[i]]
            tgrid = pd.date_range(end=end_ts, periods=H, freq='5min')
            plt.figure(figsize=(10,3.5))
            plt.plot(tgrid, true_i, label='Actual Wind Speed')
            plt.plot(tgrid, pred_i, label='Predicted Wind Speed', alpha=0.8)
            plt.title(f"Full 24h Wind Speed Path – Sample {i} (ends {end_ts})")
            plt.xlabel("Timestamp"); plt.ylabel("Wind Speed (m/s)")
            plt.legend(); plt.tight_layout(); plt.show()

if __name__ == '__main__':
    main()
# Out:
# Train windows: 174721, Validation windows: 16128, Test windows: 8352
# First window ts: 2014-01-06 23:55:00, Last: 2024-12-24 23:55:00
# No. of parameters: 649248
# /home/MAIN_USER/Desktop/Classical-Forecasting/venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# Ep01 Train=0.0057 | Val=0.0025 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.32% R²=0.442 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.40% | LR=0.000050 | Time=815.3s
# Ep02 Train=0.0022 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.58% R²=0.485 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.33% | LR=0.000075 | Time=814.9s
# Ep03 Train=0.0019 | Val=0.0021 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.65% R²=0.493 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.01% | LR=0.000100 | Time=821.2s
# Ep04 Train=0.0017 | Val=0.0023 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.67% R²=0.492 | Val(full) RMSE=1.2 MAE=0.9 MAPE=23.66% | LR=0.000125 | Time=825.7s
# Ep05 Train=0.0016 | Val=0.0020 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.41% R²=0.456 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.47% | LR=0.000150 | Time=825.5s
# Ep06 Train=0.0016 | Val=0.0019 | Val(last) RMSE=1.4 MAE=1.1 MAPE=26.42% R²=0.495 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.97% | LR=0.000175 | Time=825.5s
# Ep07 Train=0.0015 | Val=0.0022 | Val(last) RMSE=1.6 MAE=1.2 MAPE=29.39% R²=0.404 | Val(full) RMSE=1.2 MAE=0.9 MAPE=22.58% | LR=0.000200 | Time=825.3s
# Ep08 Train=0.0014 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.75% R²=0.440 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.05% | LR=0.000225 | Time=825.2s
# Ep09 Train=0.0013 | Val=0.0019 | Val(last) RMSE=1.5 MAE=1.1 MAPE=27.11% R²=0.454 | Val(full) RMSE=1.1 MAE=0.8 MAPE=20.28% | LR=0.000250 | Time=825.0s
# Ep10 Train=0.0012 | Val=0.0021 | Val(last) RMSE=1.5 MAE=1.1 MAPE=26.54% R²=0.431 | Val(full) RMSE=1.2 MAE=0.8 MAPE=20.18% | LR=0.000275 | Time=825.2s
# Ep11 Train=0.0011 | Val=0.0022 | Val(last) RMSE=1.6 MAE=1.2 MAPE=29.38% R²=0.364 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.74% | LR=0.000300 | Time=825.2s
# Ep12 Train=0.0009 | Val=0.0022 | Val(last) RMSE=1.6 MAE=1.1 MAPE=27.25% R²=0.404 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.22% | LR=0.000325 | Time=827.2s
# Ep13 Train=0.0008 | Val=0.0022 | Val(last) RMSE=1.6 MAE=1.2 MAPE=27.45% R²=0.379 | Val(full) RMSE=1.2 MAE=0.9 MAPE=21.08% | LR=0.000350 | Time=825.5s
# Ep14 Train=0.0007 | Val=0.0023 | Val(last) RMSE=1.6 MAE=1.2 MAPE=28.97% R²=0.344 | Val(full) RMSE=1.3 MAE=0.9 MAPE=22.54% | LR=0.000375 | Time=825.6s
# Ep15 Train=0.0006 | Val=0.0024 | Val(last) RMSE=1.7 MAE=1.3 MAPE=30.68% R²=0.285 | Val(full) RMSE=1.3 MAE=0.9 MAPE=22.84% | LR=0.000400 | Time=825.6s
# Ep16 Train=0.0005 | Val=0.0026 | Val(last) RMSE=1.7 MAE=1.3 MAPE=30.51% R²=0.302 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.20% | LR=0.000425 | Time=826.0s
# Ep17 Train=0.0004 | Val=0.0024 | Val(last) RMSE=1.7 MAE=1.3 MAPE=30.07% R²=0.318 | Val(full) RMSE=1.3 MAE=0.9 MAPE=22.63% | LR=0.000450 | Time=826.3s
# Ep18 Train=0.0004 | Val=0.0025 | Val(last) RMSE=1.7 MAE=1.3 MAPE=31.42% R²=0.260 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.74% | LR=0.000475 | Time=825.9s
# Ep19 Train=0.0003 | Val=0.0025 | Val(last) RMSE=1.7 MAE=1.3 MAPE=31.46% R²=0.283 | Val(full) RMSE=1.3 MAE=0.9 MAPE=23.42% | LR=0.000500 | Time=825.9s
# Ep20 Train=0.0003 | Val=0.0025 | Val(last) RMSE=1.7 MAE=1.3 MAPE=30.63% R²=0.321 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.63% | LR=0.000500 | Time=825.9s
# Ep21 Train=0.0003 | Val=0.0025 | Val(last) RMSE=1.6 MAE=1.2 MAPE=30.05% R²=0.341 | Val(full) RMSE=1.3 MAE=0.9 MAPE=23.40% | LR=0.000500 | Time=825.9s
# Ep22 Train=0.0003 | Val=0.0027 | Val(last) RMSE=1.7 MAE=1.3 MAPE=33.03% R²=0.252 | Val(full) RMSE=1.4 MAE=1.0 MAPE=25.29% | LR=0.000499 | Time=826.1s
# Ep23 Train=0.0003 | Val=0.0026 | Val(last) RMSE=1.7 MAE=1.3 MAPE=33.17% R²=0.269 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.65% | LR=0.000498 | Time=825.6s
# Ep24 Train=0.0002 | Val=0.0025 | Val(last) RMSE=1.7 MAE=1.3 MAPE=31.00% R²=0.316 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.00% | LR=0.000497 | Time=825.6s
# Ep25 Train=0.0002 | Val=0.0026 | Val(last) RMSE=1.7 MAE=1.3 MAPE=32.15% R²=0.283 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.26% | LR=0.000495 | Time=825.7s
# Ep26 Train=0.0002 | Val=0.0025 | Val(last) RMSE=1.7 MAE=1.3 MAPE=31.55% R²=0.301 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.66% | LR=0.000493 | Time=825.8s
# Ep27 Train=0.0002 | Val=0.0026 | Val(last) RMSE=1.7 MAE=1.3 MAPE=32.08% R²=0.264 | Val(full) RMSE=1.3 MAE=1.0 MAPE=23.69% | LR=0.000491 | Time=825.6s
# Ep28 Train=0.0002 | Val=0.0026 | Val(last) RMSE=1.7 MAE=1.3 MAPE=32.37% R²=0.263 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.46% | LR=0.000488 | Time=825.5s
# Ep29 Train=0.0002 | Val=0.0026 | Val(last) RMSE=1.8 MAE=1.4 MAPE=34.56% R²=0.195 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.73% | LR=0.000485 | Time=825.6s
# Ep30 Train=0.0002 | Val=0.0026 | Val(last) RMSE=1.7 MAE=1.3 MAPE=32.30% R²=0.263 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.14% | LR=0.000481 | Time=825.8s
# Ep31 Train=0.0001 | Val=0.0026 | Val(last) RMSE=1.7 MAE=1.3 MAPE=32.28% R²=0.267 | Val(full) RMSE=1.3 MAE=1.0 MAPE=24.03% | LR=0.000477 | Time=825.7s
# EarlyStopping: stop after 25 epochs.
# EarlyStopping: best weights restored.
# Test Loss (front-weighted MSE): 0.0011
#
# Final Test Metrics (last step, m/s): MSE=1.05, RMSE=1.02, MAE=0.80, R²=0.4378, Adj R²=0.4358
# Final Test Metrics (full 24h path): RMSE=0.87, MAE=0.67
# Hourly-averaged RMSE by lead hour (0→23):
# [0.21, 0.36, 0.51, 0.63, 0.72, 0.78, 0.83, 0.86, 0.88, 0.9 , 0.91, 0.91,
#  0.91, 0.91, 0.92, 0.94, 0.96, 0.99, 1.  , 1.01, 1.02, 1.02, 1.02, 1.02]
# Avg inference latency: 1.49 ms/batch • 1.49 ms/sample
